# %%
import lxml.html
import requests
import re
import json
import random
import math
from IPython.display import Image

# %%
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9,lv;q=0.8',
    'cache-control': 'no-cache',
    'cookie': '__cfduid=de6bab5f9b68cb380ef4b941545ef25eb1560717279; dwac_901934c2df27fe61a1e3d786c2=P5kOg8ksRdY4FNCsE33SGW63EtPWjruw3Ic%3D|dw-only|||GBP|false|Europe%2FLondon|true; cqcid=ac4G2blima1O28eecvkX8f8Q6R; sid=P5kOg8ksRdY4FNCsE33SGW63EtPWjruw3Ic; dwanonymous_3c96516478c33a12ebf223e921102926=ac4G2blima1O28eecvkX8f8Q6R; __cq_dnt=0; dw_dnt=0; dwsid=OWc0R1QfI8VvEC2-yw3jbWhJKBdLvd2ji4MqFJ7H12Vh4DaFMTg_YkQNp1HbaKM_nvYsNmrjPDCYYVBqNU-PyA==; mt.v=2.668808714.1560717288370; locationProtocol=https%3A; _gcl_au=1.1.1180915791.1560717290; __adal_first_visit=1560717290174; _ga=GA1.2.1094295532.1560717290; _gid=GA1.2.1918252411.1560717290; _scid=e9b4b24f-5cbd-4e52-9e40-a8e2197336b6; cd_user_id=16b61ffebb163f-0a6be026537f59-37647e03-232800-16b61ffebb252e; __cq_seg=0~0.00!1~0.00!2~0.00!3~0.00!4~0.00!5~0.00!6~0.00!7~0.00!8~0.00!9~0.00; _cs_c=1; _fbp=fb.1.1560717290889.1104685392; riTrack_WRSID=1560717293029544604; cto_lwid=c2f1d4a0-58d8-4a51-9129-f4539767a8fa; dw_locale=en_GB; __cq_uuid=ccdcf580-d6ce-11e8-af72-ef24856155e0; dwsecuretoken_3c96516478c33a12ebf223e921102926=ggHn-BU4Ko_lGpii1HkrnDP-YiDUfP4psA==; __adal_session_start=1560724388629; __adal_last_visit=1560724388629; C360i=242D6DB82A99425B9532965155D13D12|eyJjcmVhdGVkIjoxNTYwNzE3MjkwNjYwLCJ1cGRhdGVkIjoxNTYwNzI0Mzg4Nzg0LCJ0YWciOiIyLTIuMjQtNiIsImNvdW50Ijo2LCJldGFnIjoiNjk2MDkyNzE3MDY1MTA0NDU5MDAwMDAwMzU5ODNiMWQwN2QxNGVjMDc0YjdlOTdkNDAyMGU0YjhjNDNlIn0=; C360i=242D6DB82A99425B9532965155D13D12|eyJjcmVhdGVkIjoxNTYwNzE3MjkwNjYwLCJ1cGRhdGVkIjoxNTYwNzI0Mzg4Nzg0LCJ0YWciOiIyLTIuMjQtNiIsImNvdW50Ijo2LCJldGFnIjoiNjk2MDkyNzE3MDY1MTA0NDU5MDAwMDAwMzU5ODNiMWQwN2QxNGVjMDc0YjdlOTdkNDAyMGU0YjhjNDNlIn0=; _cs_id=e8c4a580-fe87-a8cb-bf2f-24e89f4f7e98.1560717290.5.1560766227.1560766227.1499948428.1594881290777; _cs_s=1.0; dw=1; dw_cookies_accepted=1',
    'pragma': 'no-cache',
    'referer': 'https://www.boohoo.com',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

# %%
sitemap_req = requests.get('https://www.boohoo.com/page/sitemap.html', headers=headers)

# %%
sitemap_doc = lxml.html.fromstring(sitemap_req.text)

# %%
cat_links = sitemap_doc.xpath('.//h4[@class="sitemap-subtitle"]/a')

# %%
cat_link_arr = []

# %%
for cat_link in cat_links:
    cat_url = cat_link.xpath('.//@href')[0]
    cat_name_dirty = cat_link.xpath('.//text()')[0]
    cat_name = re.sub(r'([^\s\w]|_)+', '', cat_name_dirty).strip()
    link_dict = {
        'cat_url': cat_url,
        'cat_name': cat_name
    }
    cat_link_arr.append(link_dict)

# %%
# re.sub(r'([^\s\w]|_)+', '', '↵Style Steals↵')

# %%
# cat_link_arr

# %%
def get_sex(url_string):
    if 'womens' in url_string or 'maternity' in url_string:
        return 'women'
    else:
        return 'men'

# %%
cat_link_sex_arr = [{
    'cat_url': cat_link['cat_url'],
    'cat_name': cat_link['cat_name'],
    'cat_sex': get_sex(cat_link['cat_url'])
} for cat_link in cat_link_arr]

# %%
cat_link_sex_arr
# Out:
# [{'cat_url': 'https://www.boohoo.com/womens/sale',
#   'cat_name': 'Womens Sale',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/new-in',
#   'cat_name': 'New In Sale',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/dresses',
#   'cat_name': 'Sale Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/tops',
#   'cat_name': 'Sale Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/plus-size-curve-clothing',
#   'cat_name': 'Sale Plus Size  Curve Clothing',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/playsuits-jumpsuits',
#   'cat_name': 'Sale Playsuits  Jumpsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/skirts',
#   'cat_name': 'Sale Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/coats-jackets',
#   'cat_name': 'Sale Coats  Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/knitwear',
#   'cat_name': 'Sale Knitwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/lingerie',
#   'cat_name': 'Sale Lingerie',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/co-ords',
#   'cat_name': 'Sale Co Ord Sets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/jeans',
#   'cat_name': 'Sale Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/denim',
#   'cat_name': 'Sale Denim',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/leggings',
#   'cat_name': 'Sale Leggings',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/trousers',
#   'cat_name': 'Sale Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/shorts',
#   'cat_name': 'Sale Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/swimwear',
#   'cat_name': 'Sale Swimwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/petite-clothing',
#   'cat_name': 'Petite Sale',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/tall-clothing',
#   'cat_name': 'Sale Tall Clothing',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/maternity',
#   'cat_name': 'Maternity Sale',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/shoes',
#   'cat_name': 'Sale Shoes',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/accessories',
#   'cat_name': 'Sale Accessories',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/3-for-2',
#   'cat_name': '3 for 2',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/nightwear',
#   'cat_name': 'Sale Nightwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/onesies-loungewear',
#   'cat_name': 'Sale Onesies  Loungewear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/partywear',
#   'cat_name': 'Sale Partywear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/promo/10poundsandunder',
#   'cat_name': 'EVERYTHING 10  UNDER',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/promo/3poundsandunder',
#   'cat_name': 'Everything 3  Under',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/40-60-percent-off',
#   'cat_name': 'Dont Miss Out',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/promo/5poundsandunder',
#   'cat_name': 'EVERYTHING 5  UNDER',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/60-70-percent-off',
#   'cat_name': 'Dont Miss Out',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/last-chance',
#   'cat_name': 'Last Chance',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/over-70-percent-off',
#   'cat_name': 'Dont Miss Out',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/sale/sale-beauty',
#   'cat_name': 'Sale Beauty',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/new-in',
#   'cat_name': 'New In Clothing',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/newintoday',
#   'cat_name': 'New In Today',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/new-in',
#   'cat_name': 'New In Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/pride-collection',
#   'cat_name': 'Pride',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/womens/shoes/new-in',
#   'cat_name': 'New In Shoes',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/accessories/new-in',
#   'cat_name': 'New In Accessories',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/his-hers-tracksuits',
#   'cat_name': 'His  Hers Tracksuits',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/new-season',
#   'cat_name': 'New Season',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/backless-dresses',
#   'cat_name': 'Backless Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/bardot-dresses',
#   'cat_name': 'Bardot Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/bodycon-dresses',
#   'cat_name': 'Bodycon Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/bridesmaids',
#   'cat_name': 'Bridesmaid Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/chiffon-dresses',
#   'cat_name': 'Chiffon Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/cocktail-dresses',
#   'cat_name': 'Cocktail Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/day-dresses',
#   'cat_name': 'Day Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/wedding-guest-dresses',
#   'cat_name': 'Wedding Guest Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/evening-dresses',
#   'cat_name': 'Evening Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/homecoming-dresses',
#   'cat_name': 'Homecoming Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/lace-dresses',
#   'cat_name': 'Lace Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/little-black-dresses',
#   'cat_name': 'Black Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/maxi-dresses',
#   'cat_name': 'Maxi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/midi-dresses',
#   'cat_name': 'Midi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/mini-dresses',
#   'cat_name': 'Mini Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/party-dresses',
#   'cat_name': 'Party Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/pinafores',
#   'cat_name': 'Pinafore Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/prom-dresses',
#   'cat_name': 'Prom Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/sequin-dresses',
#   'cat_name': 'Sequin Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/shift-dresses',
#   'cat_name': 'Shift Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/shirt-dresses',
#   'cat_name': 'Shirt Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/skater-dresses',
#   'cat_name': 'Skater Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/summer-dresses',
#   'cat_name': 'Summer Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/swing-dresses',
#   'cat_name': 'Swing Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/t-shirt-dresses',
#   'cat_name': 'Tshirt Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/wrap-dresses',
#   'cat_name': 'Wrap Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/velvet-dresses',
#   'cat_name': 'Velvet Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/occasion-dresses',
#   'cat_name': 'Occasion Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/a-line-dresses',
#   'cat_name': 'ALine Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/bandage-dresses',
#   'cat_name': 'Bandage Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/blazer-dresses',
#   'cat_name': 'Blazer Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/cami-dresses',
#   'cat_name': 'Cami Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/celeb-dresses',
#   'cat_name': 'Celebrity Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/club-dresses',
#   'cat_name': 'Club Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/corset-dresses',
#   'cat_name': 'Corset Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/crochet-dresses',
#   'cat_name': 'Crochet Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/cut-out-dresses',
#   'cat_name': 'Cut Out Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/embellished-dresses',
#   'cat_name': 'Embellished Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/gatsby-dresses',
#   'cat_name': 'Gatsby Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/graduation-dresses',
#   'cat_name': 'Graduation Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/halter-neck-dresses',
#   'cat_name': 'Halter Neck Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/knee-length-dresses',
#   'cat_name': 'Knee Length Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/leather-dresses',
#   'cat_name': 'Leather Look Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/long-sleeve-dresses',
#   'cat_name': 'Long Sleeve Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/mesh-dresses',
#   'cat_name': 'Mesh Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/one-shoulder-dresses',
#   'cat_name': 'One Shoulder Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/peplum-dresses',
#   'cat_name': 'Peplum Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/plunge-dresses',
#   'cat_name': 'Plunge Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/polka-dot-dresses',
#   'cat_name': 'Polka Dot Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/printed-dresses',
#   'cat_name': 'Printed Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/satin-dresses',
#   'cat_name': 'Satin Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/sexy-dresses',
#   'cat_name': 'Sexy Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/strapless-dresses',
#   'cat_name': 'Strapless Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/tea-dresses',
#   'cat_name': 'Tea Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/tunic-dresses',
#   'cat_name': 'Tunic Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/fishtail-dresses',
#   'cat_name': 'Fishtail Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/fit-and-flare-dresses',
#   'cat_name': 'Fit  Flare Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/high-neck-dresses',
#   'cat_name': 'High Neck Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/lace-up-dresses',
#   'cat_name': 'Lace Up Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/scuba-dresses',
#   'cat_name': 'Scuba Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/slinky-dresses',
#   'cat_name': 'Slinky Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/promo/40-dresses',
#   'cat_name': 'Dont Miss Out',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/50s-dresses',
#   'cat_name': '50s Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/ball-gowns',
#   'cat_name': 'Ball Gowns',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/black-tie-dresses',
#   'cat_name': 'Black Tie Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/dip-hem-dresses',
#   'cat_name': 'Dip Hem Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/floral-dresses',
#   'cat_name': 'Floral Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/kimono-dresses',
#   'cat_name': 'Kimono Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/multiway-dresses',
#   'cat_name': 'Multiway Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/pleated-dresses',
#   'cat_name': 'Pleated Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/tassel-dress',
#   'cat_name': 'Tassel Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/wedding-dresses',
#   'cat_name': 'Wedding Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/5-pound-dresses',
#   'cat_name': '5 Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/beach-dresses',
#   'cat_name': 'Beach Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/black-bodycon-dresses',
#   'cat_name': 'Black Bodycon Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/black-lace-dresses',
#   'cat_name': 'Black Lace Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/black-maxi-dresses',
#   'cat_name': 'Black Maxi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/black-midi-dresses',
#   'cat_name': 'Black Midi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/blue-dresses',
#   'cat_name': 'Blue Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/boho-dresses',
#   'cat_name': 'Boho Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/cape-dresses',
#   'cat_name': 'Cape Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/checked-dresses',
#   'cat_name': 'Checked Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/christmas-dresses',
#   'cat_name': 'Christmas Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/cold-shoulder-dresses',
#   'cat_name': 'Cold Shoulder Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/formal-dresses',
#   'cat_name': 'Formal Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/going-out-dresses',
#   'cat_name': 'Going Out Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/green-dresses',
#   'cat_name': 'Green Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/grey-dresses',
#   'cat_name': 'Grey Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/jersey-dresses',
#   'cat_name': 'Jersey Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/lace-wedding-dresses',
#   'cat_name': 'Lace Wedding Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/long-black-dresses',
#   'cat_name': 'Long Black Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/navy-dresses',
#   'cat_name': 'Navy Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/nude-dresses',
#   'cat_name': 'Nude Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/orange-dresses',
#   'cat_name': 'Orange Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/pencil-dresses',
#   'cat_name': 'Pencil Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/pink-dresses',
#   'cat_name': 'Pink Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/purple-dresses',
#   'cat_name': 'Purple Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/red-dresses',
#   'cat_name': 'Red Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/red-prom-dresses',
#   'cat_name': 'Red Prom Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/smock-dresses',
#   'cat_name': 'Smock Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/striped-dresses',
#   'cat_name': 'Striped Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/sweatshirt-dresses',
#   'cat_name': 'Sweatshirt Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/white-dresses',
#   'cat_name': 'White Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/white-lace-dresses',
#   'cat_name': 'White Lace Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/white-maxi-dresses',
#   'cat_name': 'White Maxi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/white-shirt-dresses',
#   'cat_name': 'White Shirt Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/dresses/yellow-dresses',
#   'cat_name': 'Yellow Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/backless-tops',
#   'cat_name': 'Backless Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/bandeau-tops',
#   'cat_name': 'Bandeau Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/bardot-off-the-shoulder-tops',
#   'cat_name': 'Bardot  Off The Shoulder Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/basic-tops',
#   'cat_name': 'Jersey Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/bodysuits',
#   'cat_name': 'Bodysuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/bralets',
#   'cat_name': 'Bralets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/cami-swing-tops',
#   'cat_name': 'Cami  Swing Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/checked-shirts',
#   'cat_name': 'Checked Shirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/choker-tops',
#   'cat_name': 'Choker Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/cold-shoulder-tops',
#   'cat_name': 'Cold Shoulder Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/corset-tops',
#   'cat_name': 'Corset Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/crop-tops',
#   'cat_name': 'Crop Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/cropped-hoodies',
#   'cat_name': 'Cropped Hoodies',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/day-tops',
#   'cat_name': 'Day Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/going-out-tops',
#   'cat_name': 'Going Out Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/floral-tops',
#   'cat_name': 'Floral Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/halter-neck-tops',
#   'cat_name': 'Halter Neck Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/high-neck-tops',
#   'cat_name': 'High Neck Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/hoodies-sweats',
#   'cat_name': 'Hoodies',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/lace-tops',
#   'cat_name': 'Lace Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/lace-up-tops',
#   'cat_name': 'Lace Up Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/long-sleeve-tops',
#   'cat_name': 'Long Sleeve Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/mesh-tops',
#   'cat_name': 'Mesh Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/peplum-tops',
#   'cat_name': 'Peplum Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/plunge-tops',
#   'cat_name': 'Plunge Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/polka-dot-tops',
#   'cat_name': 'Polka Dot Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/satin-tops',
#   'cat_name': 'Satin Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/sequin-tops',
#   'cat_name': 'Sequin Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/blouses',
#   'cat_name': 'Blouses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/slogan-tees',
#   'cat_name': 'Slogan T Shirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/summer-tops',
#   'cat_name': 'Summer Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/t-shirts-vests',
#   'cat_name': 'TShirts  Vests',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/tunic-tops',
#   'cat_name': 'Tunic Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/wrap-tops',
#   'cat_name': 'Wrap Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/chiffon-tops',
#   'cat_name': 'Chiffon Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/party-tops',
#   'cat_name': 'Party Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/ruffle-tops',
#   'cat_name': 'Ruffle Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/sweatshirts',
#   'cat_name': 'Sweatshirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tops/shirts',
#   'cat_name': 'Shirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/new-in',
#   'cat_name': 'New In Plus Size  Curve Clothing',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/dresses',
#   'cat_name': 'Plus Size  Curve Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/tops',
#   'cat_name': 'Plus Size  Curve Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/playsuits-jumpsuits',
#   'cat_name': 'Plus Size  Curve Playsuits  Jumpsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/skirts-shorts',
#   'cat_name': 'Plus Size  Curve Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/coats-jackets',
#   'cat_name': 'Plus Size  Curve Coats  Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/trousers',
#   'cat_name': 'Plus Size  Curve Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/swimwear',
#   'cat_name': 'Plus Size  Curve Swimwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/accessories',
#   'cat_name': 'Plus Size  Curve Accessories',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/bridesmaid-dresses',
#   'cat_name': 'Plus Size  Curve Bridesmaid Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/jeans',
#   'cat_name': 'Plus Size  Curve Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/lingerie',
#   'cat_name': 'Plus Size  Curve Lingerie',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/nightwear',
#   'cat_name': 'Plus Size  Curve Nightwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/wedding-guest-dresses',
#   'cat_name': 'Plus Size  Curve Wedding Guest Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/curve-going-out',
#   'cat_name': 'Curve Going Out',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-bodysuits',
#   'cat_name': 'Plus Size  Curve Bodysuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-evening-dresses',
#   'cat_name': 'Plus Size  Curve Evening Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-jumpers',
#   'cat_name': 'Plus Size  Curve Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-leggings',
#   'cat_name': 'Plus Size  Curve Leggings',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-maxi-dresses',
#   'cat_name': 'Plus Size  Curve Maxi Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-occasionwear',
#   'cat_name': 'Plus Size  Curve Occasion Wear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-party-dresses',
#   'cat_name': 'Plus Size  Curve Party Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-shorts',
#   'cat_name': 'Plus Size  Curve Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/plus-size-curve-clothing/plus-curve-summer-dresses',
#   'cat_name': 'Plus Size  Curve Summer Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/kimonos',
#   'cat_name': 'Kimonos',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/biker-jackets',
#   'cat_name': 'Biker Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/blazers',
#   'cat_name': 'Blazers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/bomber-jackets',
#   'cat_name': 'Bomber Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/capes',
#   'cat_name': 'Capes',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/duster-coats',
#   'cat_name': 'Duster Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/faux-fur-coats',
#   'cat_name': 'Faux Fur Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/festival-jackets',
#   'cat_name': 'Festival Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/parkas',
#   'cat_name': 'Parka Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/trenchcoats-macs',
#   'cat_name': 'Macs',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/wool-coats',
#   'cat_name': 'Wool Look Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/puffer-jackets',
#   'cat_name': 'Puffer Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/aviator-jackets',
#   'cat_name': 'Aviator Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/black-coats',
#   'cat_name': 'Black Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/camel-coats',
#   'cat_name': 'Camel Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/down-jackets',
#   'cat_name': 'Down Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/faux-fur-hood-coats',
#   'cat_name': 'Faux Fur Hood Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/gilet',
#   'cat_name': 'Gilets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/leopard-print-coats',
#   'cat_name': 'Leopard Print Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/long-coats',
#   'cat_name': 'Long Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/military-jackets',
#   'cat_name': 'Military Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/softshell-jackets',
#   'cat_name': 'Softshell Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/suedette-jackets',
#   'cat_name': 'Suedette Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/teddy-bear-coats',
#   'cat_name': 'Teddy Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/trench-coats',
#   'cat_name': 'Trench Coats',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/waterfall-jackets',
#   'cat_name': 'Waterfall Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/waterproof-jackets',
#   'cat_name': 'Waterproof Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/windbreaker',
#   'cat_name': 'Windbreaker Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/coats-jackets/winter-jackets',
#   'cat_name': 'Winter Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/jumpers',
#   'cat_name': 'Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/cardigans',
#   'cat_name': 'Cardigans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/knitted-dresses',
#   'cat_name': 'Jumper Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/crochet-knitwear',
#   'cat_name': 'Crochet Knitwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/knitted-loungewear',
#   'cat_name': 'Knitted Loungewear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/knitted-tops',
#   'cat_name': 'Knitted Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/boyfriend-cardigan',
#   'cat_name': 'Boyfriend Cardigans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/jumpers/cropped-jumpers',
#   'cat_name': 'Cropped Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/jumpers/off-the-shoulder-jumpers',
#   'cat_name': 'Off The Shoulder Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/jumpers/oversized-jumpers',
#   'cat_name': 'Oversized Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/knitwear/jumpers/roll-neck-jumpers',
#   'cat_name': 'Roll Neck Jumpers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/playsuits-jumpsuits/jumpsuits',
#   'cat_name': 'Jumpsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/playsuits-jumpsuits/playsuits',
#   'cat_name': 'Playsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/playsuits-jumpsuits/unitards',
#   'cat_name': 'Unitards',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/camo-trousers',
#   'cat_name': 'Camo Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/cargo-trousers',
#   'cat_name': 'Cargo Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/cigarette-trousers',
#   'cat_name': 'Cigarette Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/cropped-trousers',
#   'cat_name': 'Cropped Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/culottes',
#   'cat_name': 'Culottes',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/disco-pants',
#   'cat_name': 'Disco Pants',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/flared-trousers',
#   'cat_name': 'Flared Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/floral-trousers',
#   'cat_name': 'Floral Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/harem-pants',
#   'cat_name': 'Harem Pants',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/high-waisted-trousers',
#   'cat_name': 'High Waisted Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/joggers',
#   'cat_name': 'Joggers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/lace-up-trousers',
#   'cat_name': 'Lace Up Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/leather-look-trousers',
#   'cat_name': 'Leather Look Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/leggings',
#   'cat_name': 'Leggings',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/maternity-trousers',
#   'cat_name': 'Maternity Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/paper-bag-trousers',
#   'cat_name': 'Paper Bag Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/printed-trousers',
#   'cat_name': 'Printed Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/skinny-trousers',
#   'cat_name': 'Skinny Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/tailored-trousers',
#   'cat_name': 'Tailored Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/striped-trousers',
#   'cat_name': 'Striped Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/velvet-trousers',
#   'cat_name': 'Velvet Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/wide-leg-trousers',
#   'cat_name': 'Wide Leg Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/trousers/work-trousers',
#   'cat_name': 'Work Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/a-line-skirts',
#   'cat_name': 'A Line Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/bandage-skirts',
#   'cat_name': 'Bandage Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/day-skirts',
#   'cat_name': 'Day Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/embroidered-skirts',
#   'cat_name': 'Embroidered Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/evening-skirts',
#   'cat_name': 'Evening Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/gingham-skirts',
#   'cat_name': 'Gingham Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/lace-up-skirts',
#   'cat_name': 'Lace Up Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/leather-skirts',
#   'cat_name': 'Leather Look Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/maxi-skirts',
#   'cat_name': 'Maxi Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/midi-skirts',
#   'cat_name': 'Midi Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/mini-skirts',
#   'cat_name': 'Mini Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/pencil-skirts',
#   'cat_name': 'Pencil Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/pleated-skirts',
#   'cat_name': 'Pleated Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/sequin-skirts',
#   'cat_name': 'Sequin Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/skater-skirts',
#   'cat_name': 'Skater Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/summer-skirts',
#   'cat_name': 'Summer Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/tartan-skirts',
#   'cat_name': 'Tartan Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/tennis-skirts',
#   'cat_name': 'Tennis Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/tulle-skirts',
#   'cat_name': 'Tulle Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/skirts/wrap-skirts',
#   'cat_name': 'Wrap Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/bandage-bikini',
#   'cat_name': 'Bandage Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/bikini-bottoms',
#   'cat_name': 'Bikini Bottoms',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/bikini-tops',
#   'cat_name': 'Bikini Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/bikinis',
#   'cat_name': 'Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/brazilian-bikini',
#   'cat_name': 'Brazilian Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/crochet-bikini',
#   'cat_name': 'Crochet Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/dd-swimwear',
#   'cat_name': 'Fuller Bust Swimwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/halter-neck-bikini',
#   'cat_name': 'Halter Neck Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/high-leg-bikini',
#   'cat_name': 'High Leg Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/mix-match',
#   'cat_name': 'Mix  Match',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/push-up-bikini',
#   'cat_name': 'Push Up Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/sexy-bikinis',
#   'cat_name': 'Sexy Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/swimsuits',
#   'cat_name': 'Swimsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/thong-bikini',
#   'cat_name': 'Thong Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/triangle-bikini',
#   'cat_name': 'Triangle Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/swimwear/underwire-swimsuits',
#   'cat_name': 'Underwire Bikinis',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/bodies',
#   'cat_name': 'Lingerie Bodies',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/bras',
#   'cat_name': 'Bras',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/briefs-thongs',
#   'cat_name': 'Thongs',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/nightwear/teddies-babydolls',
#   'cat_name': 'Teddies',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/bridal-lingerie',
#   'cat_name': 'Bridal Lingerie',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/lingerie-sets-2',
#   'cat_name': 'Matching Sets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/stick-on-bras',
#   'cat_name': 'Stick On Bras',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/bralettes',
#   'cat_name': 'Bralettes',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/knickers',
#   'cat_name': 'Knickers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/lingerie-accessories',
#   'cat_name': 'Lingerie Accessories',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/push-up-bras',
#   'cat_name': 'Push Up Bras',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/shapewear',
#   'cat_name': 'Shapewear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/lingerie/strapless-bras',
#   'cat_name': 'Strapless Bras',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/occasion-wear/bridal/bride-pyjamas',
#   'cat_name': 'Bride Pyjamas',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/nightwear/dressing-gowns',
#   'cat_name': 'Dressing Gowns',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/nightwear/nighties',
#   'cat_name': 'Nighties',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/onesies-loungewear/onesies',
#   'cat_name': 'Onesies  Loungewear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/nightwear/pyjamas',
#   'cat_name': 'Pyjamas',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/nightwear/slippers',
#   'cat_name': 'Slippers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/boyfriend-jeans',
#   'cat_name': 'Boyfriend Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/flare-jeans',
#   'cat_name': 'Flare Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/high-waisted',
#   'cat_name': 'High Waisted Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/jeggings',
#   'cat_name': 'Jeggings',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/mom-jeans',
#   'cat_name': 'Mom Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/ripped-jeans',
#   'cat_name': 'Ripped Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/skinny-jeans',
#   'cat_name': 'Skinny Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/straight-leg',
#   'cat_name': 'Straight Leg Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/wide-leg-jeans',
#   'cat_name': 'Wide Leg Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/black-jeans',
#   'cat_name': 'Black Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/embroidered-jeans',
#   'cat_name': 'embroidered jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/low-rise-jeans',
#   'cat_name': 'Low Rise Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/mid-rise-jeans',
#   'cat_name': 'Mid Rise Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/jeans/power-shape-jeans',
#   'cat_name': 'Power Shape Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/jackets',
#   'cat_name': 'Denim Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/dresses',
#   'cat_name': 'Denim Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/tops',
#   'cat_name': 'Denim Shirts  Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/dungarees-denim-playsuits',
#   'cat_name': 'Dungarees',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/shorts',
#   'cat_name': 'Denim Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/skirts',
#   'cat_name': 'Denim Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/denim/overalls',
#   'cat_name': 'Overalls',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/suits-separates/matching-blazers',
#   'cat_name': 'Matching Blazers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/suits-separates/matching-dusters',
#   'cat_name': 'Matching Dusters',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/suits-separates/matching-trousers',
#   'cat_name': 'Matching Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/suits-separates/matching-sets',
#   'cat_name': 'Matching Sets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/casual-shorts',
#   'cat_name': 'Casual Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/cycling-shorts',
#   'cat_name': 'Cycling Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/flippy-shorts',
#   'cat_name': 'Summer Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/going-out-shorts',
#   'cat_name': 'Going Out Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/high-waisted-shorts',
#   'cat_name': 'High Waisted Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/hotpants',
#   'cat_name': 'Hotpants',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/runner-shorts',
#   'cat_name': 'Running Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/shorts/skorts',
#   'cat_name': 'Skorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/dresses',
#   'cat_name': 'Petite Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/tops',
#   'cat_name': 'Petite Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/playsuits-jumpsuits',
#   'cat_name': 'Petite Playsuits  Jumpsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/jeans',
#   'cat_name': 'Petite Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/coats-jackets',
#   'cat_name': 'Petite Coats  Jackets',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/knitwear',
#   'cat_name': 'Petite Knitwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/trousers',
#   'cat_name': 'Petite Trousers',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/shorts',
#   'cat_name': 'Petite Shorts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/skirts',
#   'cat_name': 'Petite Skirts',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/petite-clothing/swimwear-beachwear',
#   'cat_name': 'Petite Swimwear',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tall-clothing/bottoms',
#   'cat_name': 'Tall Bottoms',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tall-clothing/dresses',
#   'cat_name': 'Tall Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tall-clothing/jeans',
#   'cat_name': 'Tall Jeans',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tall-clothing/playsuits-jumpsuits',
#   'cat_name': 'Tall Playsuits  Jumpsuits',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/womens/tall-clothing/tops',
#   'cat_name': 'Tall Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/maternity/tops',
#   'cat_name': 'Maternity Tops',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/maternity/dresses',
#   'cat_name': 'Maternity Dresses',
#   'cat_sex': 'women'},
#  {'cat_url': 'https://www.boohoo.com/maternity/jeans',
#   'cat_name': 'Maternity Jeans',
# ...
#  {'cat_url': 'https://www.boohoo.com/mens/jeans/mens-stretch-jeans',
#   'cat_name': 'Mens Stretch Jeans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/jeans/mens-super-skinny-jeans',
#   'cat_name': 'Mens Super Skinny Jeans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/jeans/spray-on-skinny-jeans',
#   'cat_name': 'Spray on Skinny Jeans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/jeans/tapered-jeans',
#   'cat_name': 'Tapered Jeans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-blazers-overcoats',
#   'cat_name': 'Mens Blazers  Overcoats',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/bomber-jackets',
#   'cat_name': 'Bomber Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-casual-jackets',
#   'cat_name': 'Mens Casual Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-coach-field-jackets',
#   'cat_name': 'Mens Coach  Field Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-denim-jackets',
#   'cat_name': 'Mens Denim Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/harrington-jackets',
#   'cat_name': 'Harrington Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-parkas-cagoules',
#   'cat_name': 'Mens Parkas  Cagoules',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-puffer-jackets',
#   'cat_name': 'Mens Puffer Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/coats-jackets/mens-winter-jackets',
#   'cat_name': 'Mens Winter Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/hoodies-sweats/hoodies',
#   'cat_name': 'Hoodies',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/hoodies-sweats/sweatshirts',
#   'cat_name': 'Sweatshirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/mens-long-sleeve-shirts',
#   'cat_name': 'Mens Long Sleeve Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/checked-shirts',
#   'cat_name': 'Checked Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/mens-printed-shirts',
#   'cat_name': 'Mens Printed Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/mens-short-sleeve-shirts',
#   'cat_name': 'Mens Short Sleeve Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/smart-plain-shirts',
#   'cat_name': 'Smart  Plain Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/black-shirts',
#   'cat_name': 'Mens Black Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/casual-shirts',
#   'cat_name': 'Mens Casual Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/mens-denim-shirts',
#   'cat_name': 'Mens Denim Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/grandad-shirts',
#   'cat_name': 'Mens Grandad Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/hawaiian-shirts',
#   'cat_name': 'Mens Hawaiian Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shirts/white-shirts',
#   'cat_name': 'Mens White Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/jumpers-cardigans/cardigans',
#   'cat_name': 'Cardigans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/jumpers-cardigans/jumpers',
#   'cat_name': 'Mens Jumpers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/trousers/mens-cargo-trousers',
#   'cat_name': 'Mens Cargo Trousers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/trousers/mens-chinos',
#   'cat_name': 'Mens Chinos',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/trousers/mens-cropped-trousers',
#   'cat_name': 'Mens Cropped Trousers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/trousers/mens-slim-fit-trousers',
#   'cat_name': 'Mens Slim Fit Trousers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/trousers/mens-suit-trousers',
#   'cat_name': 'Mens Suit Trousers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shorts/mens-chino-shorts',
#   'cat_name': 'Mens Chino Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shorts/mens-denim-shorts',
#   'cat_name': 'Mens Denim Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shorts/mens-jersey-shorts',
#   'cat_name': 'Mens Jersey Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shorts/cargo-shorts',
#   'cat_name': 'Mens Cargo Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/mens-trainers',
#   'cat_name': 'Trainers  HiTops',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/mens-boots',
#   'cat_name': 'Boots',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/mens-smart-shoes',
#   'cat_name': 'Shoes  Loafers',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/mens-sliders-sandals-flip-flops',
#   'cat_name': 'Sandals  Sliders',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/brogues',
#   'cat_name': 'Mens Brogues',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/shoes/boots/chelsea-boots',
#   'cat_name': 'Mens Chelsea Boots',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/mens-jewellery-watches',
#   'cat_name': 'Jewellery  Watches',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/bags-wallets',
#   'cat_name': 'Bags  Wallets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/belts',
#   'cat_name': 'Belts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/mens-grooming',
#   'cat_name': 'Mens Grooming',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/caps-hats-and-beanies',
#   'cat_name': 'Mens Hats  Caps',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/mens-sunglasses',
#   'cat_name': 'Sunglasses',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/suit-accessories',
#   'cat_name': 'Suit Accessories',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/mens-underwear-socks',
#   'cat_name': 'Underwear  Socks',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/cold-weather-accessories',
#   'cat_name': 'Gloves Hats  Scarves',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/accessories/beauty',
#   'cat_name': 'Mens Beauty Products',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/white-clothing',
#   'cat_name': 'Mens White Clothing',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/animal-print',
#   'cat_name': 'Mens Animal Print Clothing',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/boohooman-by-quavo',
#   'cat_name': 'boohooMAN By Quavo',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/mens-tv-ad',
#   'cat_name': 'Mens Summer Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/disney',
#   'cat_name': 'Disney boohoo',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/neon',
#   'cat_name': 'Mens Neon Clothes',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/longline',
#   'cat_name': 'Longline',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/muscle-fit',
#   'cat_name': 'Muscle Fit',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/atlantic',
#   'cat_name': 'Atlantic',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-on-the-road',
#   'cat_name': 'BoohooMAN On The Road',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/christmas-shop',
#   'cat_name': 'Christmas Shop',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/editors-picks',
#   'cat_name': 'Editors Picks',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/partywear',
#   'cat_name': 'Mens Partywear',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-x-philip-normal',
#   'cat_name': 'Philip Normal X boohooMAN',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/tyga-x-boohooman',
#   'cat_name': 'Tyga X boohooMAN',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-x-tyga--tears-of-joy-collection',
#   'cat_name': 'boohooMAN x Tyga Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-x-rae-sremmurd',
#   'cat_name': 'Rae Sremmurd X boohooMAN',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-x-kem',
#   'cat_name': 'boohooMAN x Kem',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/mens-airport-shop',
#   'cat_name': 'Mens Airport Shop',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/florals',
#   'cat_name': 'Florals',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/world-cup',
#   'cat_name': 'World Cup',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/football-finals',
#   'cat_name': 'Football Finals',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/pastels',
#   'cat_name': 'Pastels',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/festival-fashion',
#   'cat_name': 'Festival Fashion',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-by-french-montana',
#   'cat_name': 'boohooMAN by French Montana',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/boohooman-by-dele',
#   'cat_name': 'boohooMAN by Dele',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/back-to-school',
#   'cat_name': 'Back to School',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/collections/streetwear-essentials',
#   'cat_name': 'Streetwear Essentials',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/halloween',
#   'cat_name': 'Halloween',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/mens-date-night',
#   'cat_name': 'Mens Date Night Outfits',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/josh-collection',
#   'cat_name': 'Josh Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/wes-collection',
#   'cat_name': 'Wes Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/promotion/mens-promotions-3',
#   'cat_name': 'Dont Miss Out',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/mens-occasionwear',
#   'cat_name': 'Mens Occasionwear',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/tie-dye',
#   'cat_name': 'Mens TieDye Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/winter-essentials',
#   'cat_name': 'Mens Winter Essentials',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/man-certified',
#   'cat_name': 'MAN Certified',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/borg-and-faux-fur',
#   'cat_name': 'Borg and Faux Fur',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/slim-fit',
#   'cat_name': 'Mens Slim Fit',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/utility',
#   'cat_name': 'Utility Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/man-care-label-collection',
#   'cat_name': 'MAN Care Label Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/looks/mens-checks',
#   'cat_name': 'Mens Checks',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/boohooman-abode',
#   'cat_name': 'boohooMAN x ABODE',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/promotions/email',
#   'cat_name': 'Shirts  Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/rainbow',
#   'cat_name': 'Mens Rainbow Collection',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/collections/stripes',
#   'cat_name': 'Mens Striped Clothing',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-coats-jackets',
#   'cat_name': 'Mens Big  Tall Coats and Jackets',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-hoodies-sweatshirts',
#   'cat_name': 'Mens Big  Tall Hoodies and Sweats',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-jeans',
#   'cat_name': 'Mens Big  Tall Jeans',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-joggers-tracksuits',
#   'cat_name': 'Mens Big  Tall Joggers and Tracksuits',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-newin',
#   'cat_name': 'Mens Big  Tall New In',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-shirts',
#   'cat_name': 'Mens Big  Tall Shirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-shorts',
#   'cat_name': 'Mens Big  Tall Shorts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/big-tall/big-tall-t-shirts',
#   'cat_name': 'Mens Big  Tall TShirts',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/promotion/mens-promotions-2',
#   'cat_name': 'Up To 70 Off Mens TShirts  Vests',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/t-shirts-vests',
#   'cat_name': 'Mens TShirts  Vests Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/shirts',
#   'cat_name': 'Mens Shirts Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/jumpers-cardigans',
#   'cat_name': 'Mens Jumpers  Cardigans Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/hoodies-sweats',
#   'cat_name': 'Mens Hoodies  Sweatshirts Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/jeans',
#   'cat_name': 'Mens Jeans Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/trousers',
#   'cat_name': 'Mens Trousers Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/onesies-loungewear',
#   'cat_name': 'Mens Onesies  Loungewear Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/big-tall',
#   'cat_name': 'Big  Tall Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/tracksuits',
#   'cat_name': 'Mens Tracksuits Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/accessories',
#   'cat_name': 'Mens Accessories Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/shoes',
#   'cat_name': 'Mens Sale Shoes',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/coats-jackets',
#   'cat_name': 'Mens Coats  Jackets Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/shorts',
#   'cat_name': 'Mens Shorts Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/summer-sale',
#   'cat_name': 'Summer Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/bottoms',
#   'cat_name': 'Mens Bottoms Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/christmas',
#   'cat_name': 'Mens Christmas Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/footwear-accessories',
#   'cat_name': 'Mens Footwear  Accessories Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/sets',
#   'cat_name': 'Mens CoOrds  Twin Sets Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/sale/tops',
#   'cat_name': 'Mens Tops Sale',
#   'cat_sex': 'men'},
#  {'cat_url': 'https://www.boohoo.com/mens/christmas-jumpers',
#   'cat_name': 'Mens Christmas Jumpers',
#   'cat_sex': 'men'}]

# %%
cat_page_req = requests.get('https://www.boohoo.com/womens/skirts/midi-skirts', headers=headers)

# %%
cat_page_doc = lxml.html.fromstring(cat_page_req.text)

# %%
prod_count_match = cat_page_doc.xpath('.//div[contains(@class, "js-product-count")]/text()')

# %%
prod_count_string = prod_count_match[0].strip()

# %%
prod_count = int(re.sub("\D", "", prod_count_string))

# %%
prod_count
# Out:
# 271

# %%
page_count = math.ceil(prod_count / 60)

# %%
page_count
# Out:
# 5

# %%
prod_arr = []

# %%
for k in range(0,page_count):
    print(k * 60)
    req_url = 'https://www.boohoo.com/womens/skirts/midi-skirts' + '?sz=60&start=' + str(k * 60)
    cat_page_req = requests.get(req_url, headers=headers)
    cat_page_doc = lxml.html.fromstring(cat_page_req.text)
    product_tiles = cat_page_doc.xpath('.//div[@class="product-tile"]')
    for product_tile in product_tiles:
        prod_url = product_tile.xpath('.//a[contains(@class, "name-link")]/@href')[0]
        prod_name = product_tile.xpath('.//a[contains(@class, "name-link")]/text()')[0]
        prod_arr.append({
            'prod_url': 'https://www.boohoo.com' + prod_url,
            'prod_name': prod_name.strip()
        })
# Out:
# 0
# 60
# 120
# 180
# 240

# %%
len(prod_arr)
# Out:
# 271

# %%
prod_arr
# Out:
# [{'prod_url': 'https://www.boohoo.com/petite-leopard-print-pleated-midi-skirt/PZZ76492.html',
#   'prod_name': 'Petite Leopard Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-leopard-print-satin-wrap-midi-skirt/PZZ78489.html',
#   'prod_name': 'Petite Leopard Print Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/woven-lace-top-contrast-midi-skirt-co-ord/DZZ63861.html',
#   'prod_name': 'Woven Lace Top & Contrast Midi Skirt Co-Ord'},
#  {'prod_url': 'https://www.boohoo.com/boutique--jacquard-top-midi-skirt-co-ord-set/DZZ86684.html',
#   'prod_name': 'Boutique Jacquard Top Midi Skirt Co-Ord Set'},
#  {'prod_url': 'https://www.boohoo.com/tall--boutique-tulle-mesh-midi-skirt/TZZ99593.html',
#   'prod_name': 'Tall Boutique Tulle Mesh Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-satin-wrap-midaxi-skirt/DZZ07101.html',
#   'prod_name': 'Leopard Print Satin Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-midi-tube-skirt/PZZ75751.html',
#   'prod_name': 'Plus Midi Tube Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-leopard-ruffle-wrap-midi-skirt/DZZ09090.html',
#   'prod_name': 'Satin Leopard Ruffle Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-leopard-satin-ruffle-wrap-skirt/PZZ76485.html',
#   'prod_name': 'Plus Leopard Satin Ruffle Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/mock-horn-button-through-midi-skirt/DZZ14874.html',
#   'prod_name': 'Mock Horn Button Through Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-satin-wrap-midi-skirt/FZZ99211.html',
#   'prod_name': 'Leopard Print Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-box-pleat-midi-skirt/AZZ00727.html',
#   'prod_name': 'Basic Box Pleat Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/woven-contrast-stripe-midi-skirt/DZZ10826.html',
#   'prod_name': 'Woven Contrast Stripe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/2-pack-leather-look-and-jersey-midi-skirt/DZZ60238.html',
#   'prod_name': '2 Pack Leather Look And Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-tie-front-animal-ruffle-midaxi-skirt/PZZ73173.html',
#   'prod_name': 'Petite Tie Front Animal Ruffle Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-snake-print-midi-skirt/PZZ76517.html',
#   'prod_name': 'Petite Satin Snake Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-snake-print-ruffle-skirt/PZZ77589.html',
#   'prod_name': 'Plus Snake Print Ruffle Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-satin-wrap-midaxi-skirt/DZZ03058.html',
#   'prod_name': 'Leopard Satin Wrap Midaxi skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus--floral-print-scuba-midi-skirt/PZZ88477.html',
#   'prod_name': 'Plus Floral Print Scuba Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/floral-wrap-ruffle-midi-skirt/FZZ93773.html',
#   'prod_name': 'Floral Wrap Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-jersey-animal-print-midi-skater-skirt/PZZ75574.html',
#   'prod_name': 'Plus Jersey Animal Print Midi Skater Skirt'},
#  {'prod_url': 'https://www.boohoo.com/amaya-2-pack-leather-look-jersey-midi-skirt/DZZ72054.html',
#   'prod_name': 'Amaya 2 Pack Leather Look & Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pleated-chain-print-midi-skirt/DZZ02027.html',
#   'prod_name': 'Pleated Chain Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-jersey-animal-print-midi-skater-skirt/PZZ75575.html',
#   'prod_name': 'Plus Jersey Animal Print Midi Skater Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-high-waist-slinky-fitted-midaxi-skirt/DZZ25576.html',
#   'prod_name': 'Basic High Waist Slinky Fitted Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/square-neck-strappy-midi-skirt-co-ord-set/DZZ21420.html',
#   'prod_name': 'Square Neck Strappy Midi Skirt Co-ord Set'},
#  {'prod_url': 'https://www.boohoo.com/chiffon-pleated-midi-skirt/DZZ71277.html',
#   'prod_name': 'Chiffon Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ96094.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/geo-print-satin-wrap-midaxi-skirt/DZZ00172.html',
#   'prod_name': 'Geo Print Satin Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-satin-wrap-midi-skirt/DZZ03064.html',
#   'prod_name': 'Leopard Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-pleated-snake-print-midi-skirt/TZZ95493.html',
#   'prod_name': 'Tall Pleated Snake Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pleated-midi-skirt/FZZ95019.html',
#   'prod_name': 'Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-leopard-print-pleated-midi-skirt/TZZ95492.html',
#   'prod_name': 'Tall Leopard Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-slinky-pleated-midi-skirt/PZZ73049.html',
#   'prod_name': 'Petite Slinky Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/slinky-ruched-bum-detail-midi-skirt/FZZ89871.html',
#   'prod_name': 'Slinky Ruched Bum Detail Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jersey-midaxi-skirt/FZZ97723.html',
#   'prod_name': 'Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/anna-corset-waist-front-split-midi-skirt/DZZ44564.html',
#   'prod_name': 'Anna Corset Waist Front Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/crop-top-full-midi-skirt-co-ord-set/DZZ81227.html',
#   'prod_name': 'Crop Top & Full Midi Skirt Co-Ord Set'},
#  {'prod_url': 'https://www.boohoo.com/leopard-wrap-satin-midi-skirt/DZZ03063.html',
#   'prod_name': 'Leopard Wrap Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-pleated-midi-skirt/FZZ95329.html',
#   'prod_name': 'Polka Dot Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/monochrome-check-midi-skirt/DZZ63812.html',
#   'prod_name': 'Monochrome Check Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/bandage-skirt-and-crop-top-co-ord-set/DZZ21657.html',
#   'prod_name': 'Bandage Skirt and Crop Top Co-ord Set'},
#  {'prod_url': 'https://www.boohoo.com/lace-trim-side-split-slip-midi-skirt/FZZ87235.html',
#   'prod_name': 'Lace Trim Side Split Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/neon-luxe-satin-bias-cut-midi-skirt/FZZ95015.html',
#   'prod_name': 'Neon Luxe Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/square-neck-top-midi-skirt/FZZ93660.html',
#   'prod_name': 'Square Neck Top & Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/all-over-ruched-midi-skirt/DZZ25692.html',
#   'prod_name': 'All Over Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/midi-pencil-skirt/FZZ93071.html',
#   'prod_name': 'Midi Pencil Skirt'},
#  {'prod_url': 'https://www.boohoo.com/star-print-satin-bias-cut-midi-skirt/FZZ90529.html',
#   'prod_name': 'Star Print Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-box-pleat-midi-skirt/DZZ75073.html',
#   'prod_name': 'Basic Box Pleat Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-pleated-midi-skirt/DZZ00438.html',
#   'prod_name': 'Satin Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-tie-waist-twill-midi-skirt/TZZ95027.html',
#   'prod_name': 'Tall Tie Waist Twill Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-leopard-print-bias-cut-midi-skirt/PZZ77051.html',
#   'prod_name': 'Petite Leopard Print Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-chain-print-pleated-midi-skirt/PZZ71370.html',
#   'prod_name': 'Petite Chain Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/button-front-stretch-midi-denim-skirt/FZZ92953.html',
#   'prod_name': 'Button Front Stretch Midi Denim Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-wrap-midi-skirt/FZZ89113.html',
#   'prod_name': 'Polka Dot Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midi-skirt/AZZ00734.html',
#   'prod_name': 'Basic Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-midi-skirt/FZZ86101.html',
#   'prod_name': 'Leopard Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-lemon-stripe-hanky-hem-midi-skirt/PZZ71906.html',
#   'prod_name': 'Plus Lemon Stripe Hanky Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/asymetric-split-front-midi-skirt/DZZ46843.html',
#   'prod_name': 'Asymetric Split Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tailored-wrap-skirt/FZZ88846.html',
#   'prod_name': 'Tailored Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/checked-button-front-split-midi-skirt/DZZ01873.html',
#   'prod_name': 'Checked Button Front Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-woven-cherry-print-ruffle-dipped-hem-skirt/PZZ72267.html',
#   'prod_name': 'Plus Woven Cherry Print Ruffle Dipped Hem Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-leopard-print-satin-wrap-midi-skirt/TZZ94701.html',
#   'prod_name': 'Tall Leopard Print Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pu-leather-look-midi-skirt/DZZ00833.html',
#   'prod_name': 'PU Leather Look Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/snake-pleat-button-down-midi-skirt/FZZ87766.html',
#   'prod_name': 'Snake Pleat Button Down Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/fruit-print-satin-wrap-midi-skirt/FZZ88744.html',
#   'prod_name': 'Fruit Print Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-button-detail-midi-skirt/FZZ88942.html',
#   'prod_name': 'Polka Dot Button Detail Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-slip-midi-skirt/DZZ00439.html',
#   'prod_name': 'Satin Bias Cut Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/drop-peplum-hem-midi-skirt/FZZ88818.html',
#   'prod_name': 'Drop Peplum Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-ruffle-midi-skirt/FZZ96238.html',
#   'prod_name': 'Polka Dot Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/knot-front-wrap-midi-skirt/FZZ92227.html',
#   'prod_name': 'Knot Front Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-midaxi-skirt/FZZ90272.html',
#   'prod_name': 'Leopard Print Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jersey-midi-skirt/FZZ97722.html',
#   'prod_name': 'Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-ruffle-hem-palm-print-skirt/FZZ91350.html',
#   'prod_name': 'Satin Ruffle Hem Palm Print Skirt'},
#  {'prod_url': 'https://www.boohoo.com/cheese-cloth-lace-insert-midi-skirt/FZZ93847.html',
#   'prod_name': 'Cheese Cloth Lace Insert Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/zebra-split-midi-skirt/DZZ06352.html',
#   'prod_name': 'Zebra Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-slinky-cherry-blossom-ruched-split-midi-skirt/PZZ71787.html',
#   'prod_name': 'Plus Slinky Cherry Blossom Ruched Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/recycled-slinky-tropical-split-midi-skirt/FZZ88512.html',
#   'prod_name': 'Recycled Slinky Tropical Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-mixed-floral-midi-skirt/FZZ89423.html',
#   'prod_name': 'Satin Mixed Floral Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/buckle-detail-wrap-midi-skirt/FZZ86097.html',
#   'prod_name': 'Buckle Detail Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-lemon-stripe-hanky-hem-midi-skater-skirt/PZZ71899.html',
#   'prod_name': 'Petite Lemon Stripe Hanky Hem Midi Skater Skirt'},
#  {'prod_url': 'https://www.boohoo.com/chain-print-satin-bias-cut-midi-skirt/FZZ90202.html',
#   'prod_name': 'Chain Print Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-ruffle-hem-midaxi-skirt/FZZ92842.html',
#   'prod_name': 'Polka Dot Ruffle Hem Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-mixed-animal-print-midi-skirt/PZZ71945.html',
#   'prod_name': 'Petite Mixed Animal Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tailored-mini-skirt/FZZ88845.html',
#   'prod_name': 'Tailored Mini Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-slip-skirt/PZZ72991.html',
#   'prod_name': 'Petite Satin Slip Skirt'},
#  {'prod_url': 'https://www.boohoo.com/button-front-mini-skirt/FZZ87049.html',
#   'prod_name': 'Button Front Mini Skirt'},
#  {'prod_url': 'https://www.boohoo.com/maternity-leopard-side-stripe-midi-skirt/BZZ46597.html',
#   'prod_name': 'Maternity Leopard Side Stripe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bustier-underwire-midi-skirt/FZZ85597.html',
#   'prod_name': 'Satin Bustier Underwire Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-fruit-print-ruffle-detail-midi-skirt/PZZ71922.html',
#   'prod_name': 'Plus Fruit Print Ruffle Detail Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-bias-cut-satin-midi-skirt/TZZ95343.html',
#   'prod_name': 'Tall Bias Cut Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-8.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/loren-leather-look-midi-skirt/DZZ89405.html',
#   'prod_name': 'Loren Leather Look Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-spot-woven-ruffle-wrap-midi-skirt/PZZ74399.html',
#   'prod_name': 'Plus Spot Woven Ruffle Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/2-pack-rouched-side-jersey-midi-skirt/DZZ60242.html',
#   'prod_name': '2 Pack Rouched Side Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leather-look-mock-horn-button-paperbag-midi-skirt/DZZ08619.html',
#   'prod_name': 'Leather Look Mock Horn Button Paperbag Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/double-layer-slinky-midaxi-skirt/FZZ99623.html',
#   'prod_name': 'Double Layer Slinky Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/bias-satin-slip-midi-skirt/FZZ95318.html',
#   'prod_name': 'Bias Satin Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/rouched-side-asymetric-skirt/DZZ76860.html',
#   'prod_name': 'Rouched Side Asymetric Skirt'},
#  {'prod_url': 'https://www.boohoo.com/boxy-crop-and-midi-skirt-co-ord/DZZ75957.html',
#   'prod_name': 'Boxy Crop And Midi Skirt Co-Ord'},
#  {'prod_url': 'https://www.boohoo.com/cross-over-halterneck-top-midi-skirt-co-ord/FZZ88927.html',
#   'prod_name': 'Cross Over Halterneck Top & Midi Skirt Co-ord'},
#  {'prod_url': 'https://www.boohoo.com/maternity-lace-midi-skirt/BZZ47134.html',
#   'prod_name': 'Maternity Lace Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/polka-dot-floral-bias-cut-midi-skirt/FZZ90344.html',
#   'prod_name': 'Polka Dot Floral Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-tropical-leopard-ruffle-midi-skirt/FZZ90322.html',
#   'prod_name': 'Satin Tropical Leopard Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pocket-detail-button-midi-skirt/FZZ93069.html',
#   'prod_name': 'Pocket Detail Button Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midi-skirt/AZZ07587.html',
#   'prod_name': 'Basic Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruched-front-midi-skirt/FZZ88459.html',
#   'prod_name': 'Ruched Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-mixed-floral-midi-skirt/PZZ71205.html',
#   'prod_name': 'Petite Satin Mixed Floral Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-satin-ruffle-asymmetric-midi-skirt/PZZ73129.html',
#   'prod_name': 'Plus Satin Ruffle Asymmetric Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ95252.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-satin-palm-print-wrap-front-midi-skirt/TZZ94329.html',
#   'prod_name': 'Tall Satin Palm Print Wrap Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/rouched-side-asymetric-skirt/DZZ63808.html',
#   'prod_name': 'Rouched Side Asymetric Skirt'},
#  {'prod_url': 'https://www.boohoo.com/hanky-hem-midi-skirt/FZZ88315.html',
#   'prod_name': 'Hanky Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jumbo-rib-mini-skirt/DZZ12748.html',
#   'prod_name': 'Basic Jumbo Rib Mini Skirt'},
#  {'prod_url': 'https://www.boohoo.com/croc-embossed-midi-skirt/FZZ96239.html',
#   'prod_name': 'Croc Embossed Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/striped-linen-tie-waist-button-split-midi-skirt/FZZ90531.html',
#   'prod_name': 'Striped Linen Tie Waist Button Split Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-slip-midi-skirt/FZZ96240.html',
#   'prod_name': 'Satin Bias Cut Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tie-dye-midi-satin-slip-skirt/FZZ90241.html',
#   'prod_name': 'Tie Dye Midi Satin Slip Skirt'},
#  {'prod_url': 'https://www.boohoo.com/floor-sweeping-jersey-maxi-skirt/DZZ79437.html',
#   'prod_name': 'Floor Sweeping Jersey Maxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/zebra-print-ruffle-wrap-skirt/FZZ93261.html',
#   'prod_name': 'Zebra Print Ruffle Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruched-midi-skirt/FZZ97088-3.html',
#   'prod_name': 'Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruched-midi-skirt/FZZ97088-2.html',
#   'prod_name': 'Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tonal-stripe-paperbag-midi-skirt/FZZ90205.html',
#   'prod_name': 'Tonal Stripe Paperbag Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-plain-full-circle-midi-skirt/AZZ34748.html',
#   'prod_name': 'Basic Plain Full Circle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ditsy-floral-wrap-midi-skirt/FZZ89114.html',
#   'prod_name': 'Ditsy Floral Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-midi-skirt/PZZ75084.html',
#   'prod_name': 'Petite Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-leopard-print-ruffle-midi-skirt/DZZ07639.html',
#   'prod_name': 'Satin Leopard Print Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-animal-print-midi-skirt/PZZ74420.html',
#   'prod_name': 'Petite Animal Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/chain-scarf-satin-print-wrap-midaxi-skirt/DZZ03057.html',
#   'prod_name': 'Chain Scarf Satin Print Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/broderie-lace-up-bralet-asymetric-midi-skirt/FZZ94537.html',
#   'prod_name': 'Broderie Lace Up Bralet & Asymetric Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-3.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/slinky-ruched-midi-skirt/FZZ95004.html',
#   'prod_name': 'Slinky Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-snake-print-wrap-midaxi-skirt/DZZ03066.html',
#   'prod_name': 'Satin Snake Print Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/porcelain-print-midi-tube-skirt/FZZ90885.html',
#   'prod_name': 'Porcelain Print Midi Tube Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-6.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-midi-tube-skirt/PZZ73619.html',
#   'prod_name': 'Plus Midi Tube Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-side-stripe-midi-skirt/FZZ88421.html',
#   'prod_name': 'Leopard Side Stripe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-plain-full-circle-midi-skirt/AZZ00735.html',
#   'prod_name': 'Basic Plain Full Circle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tiger-wrap-ruffle-midi-skirt/FZZ93772.html',
#   'prod_name': 'Tiger Wrap & Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-asymmetric-stripe-midi-skirt/TZZ94444.html',
#   'prod_name': 'Tall Asymmetric Stripe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-crepe-skater-midi-skirt/TZZ94239.html',
#   'prod_name': 'Tall Crepe Skater Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-basic-jersey-midaxi-skirt/TZZ94203.html',
#   'prod_name': 'Tall Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/button-front-ribbed-midi-skirt/DZZ07398.html',
#   'prod_name': 'Button Front Ribbed Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-leopard-side-split-midaxi-skirt/FZZ89115.html',
#   'prod_name': 'Satin Leopard Side Split Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/double-up-midi-skirt/FZZ90014.html',
#   'prod_name': 'Double Up Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/rouched-sleeve-midi-skirt-co-ord-set/AZZ09698.html',
#   'prod_name': 'Rouched Sleeve Midi Skirt Co-Ord Set'},
#  {'prod_url': 'https://www.boohoo.com/button-side-split-skater-midi-skirt/FZZ94251.html',
#   'prod_name': 'Button Side Split Skater Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ95251.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/bias-cut-satin-midi-skirt/FZZ93771.html',
#   'prod_name': 'Bias Cut Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-tiger-print-bias-midi-skirt/FZZ94206.html',
#   'prod_name': 'Satin Tiger Print Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/paper-bag-waist-embossed-midi-skirt/FZZ92291.html',
#   'prod_name': 'Paper Bag Waist Embossed Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-slinky-midi-skirt/PZZ72236.html',
#   'prod_name': 'Plus Slinky Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-chain-print-satin-asymmetric-skirt/PZZ75407-1.html',
#   'prod_name': 'Plus Chain Print Satin Asymmetric Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-scuba-midi-skirt/DZZ81845.html',
#   'prod_name': 'Basic Scuba Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/woven-heart-print-ruffle-midi-skirt/DZZ00524-1.html',
#   'prod_name': 'Woven Heart Print Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-wrap-midaxi-skirt/FZZ96243.html',
#   'prod_name': 'Satin Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-green-leopard-wrap-midaxi-skirt/DZZ01979.html',
#   'prod_name': 'Satin Green Leopard Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-jersey-pleated-midi-skirt/PZZ72944.html',
#   'prod_name': 'Plus Jersey Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-1.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-knit-high-waisted-ruched-side-midi-skirt/PZZ71615.html',
#   'prod_name': 'Plus Knit High Waisted Ruched Side Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/belted-midi-skirt/FZZ89560.html',
#   'prod_name': 'Belted Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-pu-pencil-skirt/PZZ78173.html',
#   'prod_name': 'Petite PU Pencil Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tonal-stripe-button-midi-skirt/DZZ12202.html',
#   'prod_name': 'Tonal Stripe Button Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-5.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/black-basic-midi-skirt/DZZ00007.html',
#   'prod_name': 'Black Basic Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-palm-print-wrap-front-midi-skirt/FZZ91353.html',
#   'prod_name': 'Satin Palm Print Wrap Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-printed-satin-wrap-skirt/PZZ75768.html',
#   'prod_name': 'Petite Printed Satin Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/neon-polka-dot-pleated-midi-skirt/FZZ94265.html',
#   'prod_name': 'Neon Polka Dot Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pleated-woven-snake-print-midi-skirt/FZZ95218.html',
#   'prod_name': 'Pleated Woven Snake Print Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-midi-skirt/FZZ91354.html',
#   'prod_name': 'Satin Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/contrast-binding-ribbed-skirt-top-set/FZZ90371.html',
#   'prod_name': 'Contrast Binding Ribbed Skirt & Top Set'},
#  {'prod_url': 'https://www.boohoo.com/petite-polka-dot-ruffle-hem-midi-skirt/PZZ73260.html',
#   'prod_name': 'Petite Polka Dot Ruffle Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-2.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/scuba-self-belt-midi-skirt/FZZ91140.html',
#   'prod_name': 'Scuba Self Belt Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/recycled-rib-twist-detail-crop-midi-skirt-co-ord/FZZ88507-1.html',
#   'prod_name': 'Recycled Rib Twist Detail Crop Midi Skirt Co-ord'},
#  {'prod_url': 'https://www.boohoo.com/button-front-top/FZZ88615.html',
#   'prod_name': 'Button Front Top'},
#  {'prod_url': 'https://www.boohoo.com/satin-leopard-asymmetric-midaxi-skirt/DZZ03067.html',
#   'prod_name': 'Satin Leopard Asymmetric Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/mesh-ruched-midi-skirt/FZZ95072.html',
#   'prod_name': 'Mesh Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/maternity-scuba-midi-skirt-with-pockets/BZZ47294.html',
#   'prod_name': 'Maternity Scuba Midi Skirt With Pockets'},
#  {'prod_url': 'https://www.boohoo.com/contrast-stitch-pocket-detail-midi-skirt/FZZ92502.html',
#   'prod_name': 'Contrast Stitch Pocket Detail Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/rouched-front-ruffle-hem-ribbed-mini-skirt/FZZ94263.html',
#   'prod_name': 'Rouched Front Ruffle Hem Ribbed Mini Skirt'},
#  {'prod_url': 'https://www.boohoo.com/abstract-leopard-print-pleated-midi-skirt/FZZ92343.html',
#   'prod_name': 'Abstract Leopard Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/recycled-rib-twist-detail-crop-midi-skirt-co-ord/FZZ88507-2.html',
#   'prod_name': 'Recycled Rib Twist Detail Crop Midi Skirt Co-ord'},
#  {'prod_url': 'https://www.boohoo.com/plus--pu-midi-skirt/PZZ94520.html',
#   'prod_name': 'Plus PU Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/maternity-button-detail-checked-midi/BZZ47290.html',
#   'prod_name': 'Maternity Button Detail Checked Midi'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-bias-cut-midi-skirt/PZZ72647.html',
#   'prod_name': 'Petite Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/knitted-rib-tie-waist-midaxi-skirt/FZZ99620.html',
#   'prod_name': 'Knitted Rib Tie Waist Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-croset-detail-super-high-waist-skirt/PZZ72042.html',
#   'prod_name': 'Plus Croset Detail Super High Waist Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-ruffle-hem-midi-skirt/FZZ98523.html',
#   'prod_name': 'Leopard Print Ruffle Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-animal-print-wrap-skirt/PZZ71753.html',
#   'prod_name': 'Petite Animal Print Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tartan-check-midi-skirt/DZZ05589.html',
#   'prod_name': 'Tartan Check Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-neon-slinky-ruched-midi-skirt/PZZ74243-1.html',
#   'prod_name': 'Plus Neon Slinky Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/button-through-daisy-woven-midi-skirt/FZZ92252.html',
#   'prod_name': 'Button Through Daisy Woven Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tie-waist-ruffle-hem-midi-skirt/FZZ91345.html',
#   'prod_name': 'Tie Waist Ruffle Hem Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-basic-ponte-bodycon-midi-skirt/PZZ86465.html',
#   'prod_name': 'Petite Basic Ponte Bodycon Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/maternity-stripe-midi-skirt/BZZ46725.html',
#   'prod_name': 'Maternity Stripe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-woven-wrap-front-midi-skirt/PZZ75250.html',
#   'prod_name': 'Petite Woven Wrap Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruched-floral-midi-skirt/FZZ95135.html',
#   'prod_name': 'Ruched Floral Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-button-front-midi-skirt/TZZ94156.html',
#   'prod_name': 'Tall Button Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ97230.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/slinky-wrap-tie-ruched-midi-skirt/FZZ90227.html',
#   'prod_name': 'Slinky Wrap Tie Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-crepe-midi-skirt/DZZ12197.html',
#   'prod_name': 'Basic Crepe Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-satin-bias-midi-skirt/TZZ94436.html',
#   'prod_name': 'Tall Satin Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ97515.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/pu-leather-look-zip-front-midi-skirt/DZZ00265.html',
#   'prod_name': 'PU Leather Look Zip Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/chain-print-pleated-satin-midi-skirt/FZZ91226.html',
#   'prod_name': 'Chain Print Pleated Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-crepe-basic-midi-bodycon-skirt/PZZ79270.html',
#   'prod_name': 'Plus Crepe Basic Midi Bodycon Skirt'},
#  {'prod_url': 'https://www.boohoo.com/recycled-rib-twist-detail-crop-midi-skirt-co-ord/FZZ88507-3.html',
#   'prod_name': 'Recycled Rib Twist Detail Crop Midi Skirt Co-ord'},
#  {'prod_url': 'https://www.boohoo.com/plus-woven-tiger-print-asymmetric-midi-skirt/PZZ73723.html',
#   'prod_name': 'Plus Woven Tiger Print Asymmetric Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tie-back-bralet-and-midi-skirt/DZZ13038.html',
#   'prod_name': 'Tie Back Bralet And Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-7.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/asymmetric-leopard-midi-skirt/DZZ09260.html',
#   'prod_name': 'Asymmetric Leopard Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/sleeve-detail-crop-midi-skirt-co-ord/FZZ97127.html',
#   'prod_name': 'Sleeve Detail Crop & Midi Skirt Co-Ord'},
#  {'prod_url': 'https://www.boohoo.com/ribbed-asymetric-midi-skirt/FZZ96077.html',
#   'prod_name': 'Ribbed Asymetric Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruffle-mini-skirt/FZZ92499.html',
#   'prod_name': 'Ruffle Mini Skirt'},
#  {'prod_url': 'https://www.boohoo.com/high-neck-heavyweight-ribbed-top-midi-skirt-co-ord/FZZ95642.html',
#   'prod_name': 'High Neck Heavyweight Ribbed Top & Midi Skirt Co-Ord'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-midi-skirt/FZZ95013.html',
#   'prod_name': 'Satin Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-9.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-satin-bias-midi-skirt/PZZ71663.html',
#   'prod_name': 'Petite Satin Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/shirred-midi-skirt/FZZ92313.html',
#   'prod_name': 'Shirred Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/drawstring-waist-sweat-midaxi-skirt/FZZ89561.html',
#   'prod_name': 'Drawstring Waist Sweat Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/corset-detail-super-high-waist-midi-skirt/FZZ93563.html',
#   'prod_name': 'Corset Detail Super High Waist Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/woven-mixed-animal-wrap-midi-skirt/FZZ91314.html',
#   'prod_name': 'Woven Mixed Animal Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/horn-o-ring-midaxi-skirt/FZZ94258.html',
#   'prod_name': 'Horn O Ring Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-midi-skirt/FZZ94037.html',
#   'prod_name': 'Satin Bias Cut Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-slip-midi-skirt/FZZ94039.html',
#   'prod_name': 'Satin Bias Cut Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/vibrant-floral-satin-midaxi-skirt/FZZ92371.html',
#   'prod_name': 'Vibrant Floral Satin Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/off-the-shoulder-lace-up-ruffle-skirt-co-ord/FZZ94509.html',
#   'prod_name': 'Off The Shoulder Lace Up Ruffle Skirt Co-Ord'},
#  {'prod_url': 'https://www.boohoo.com/plus-chain-print-satin-asymmetric-skirt/PZZ75407-3.html',
#   'prod_name': 'Plus Chain Print Satin Asymmetric Skirt'},
#  {'prod_url': 'https://www.boohoo.com/cord-button-front-midi-skirt/FZZ99842.html',
#   'prod_name': 'Cord Button Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tailored-pencil-skirt/FZZ88844.html',
#   'prod_name': 'Tailored Pencil Skirt'},
#  {'prod_url': 'https://www.boohoo.com/full-tulle-mesh-midi-skirt/FZZ94255.html',
#   'prod_name': 'Full Tulle Mesh Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-button-front-zebra-midi-skirt/TZZ95468.html',
#   'prod_name': 'Tall Button Front Zebra Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/satin-bias-cut-slip-midi-skirt/FZZ99121.html',
#   'prod_name': 'Satin Bias Cut Slip Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-satin-skirt/PZZ75618.html',
#   'prod_name': 'Plus Satin Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-leopard-button-through-midi-skirt/PZZ76115.html',
#   'prod_name': 'Petite Leopard Button Through Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-leopard-print-ruffle-midi-skirt/TZZ95131.html',
#   'prod_name': 'Tall Leopard Print Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/leopard-print-satin-wrap-midaxi-skirt/DZZ07285.html',
#   'prod_name': 'Leopard Print Satin Wrap Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jumbo-rib-midi-skirt/FZZ98397.html',
#   'prod_name': 'Jumbo Rib Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-woven-leopard-ruffle-midi-skirt/PZZ74398.html',
#   'prod_name': 'Plus Woven Leopard Ruffle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-snake-print-ruffle-wrap-skirt/PZZ74147.html',
#   'prod_name': 'Plus Snake Print Ruffle Wrap Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jumbo-rib-square-neck-bralet-midi-skirt-co-ord/DZZ05409.html',
#   'prod_name': 'Jumbo Rib Square Neck Bralet & Midi Skirt Co-ord'},
#  {'prod_url': 'https://www.boohoo.com/plus-dogstooth-midi-skirt/PZZ75380.html',
#   'prod_name': 'Plus Dogstooth Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jumbo-rib-midi-skirt/DZZ12749.html',
#   'prod_name': 'Jumbo Rib Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-neon-slinky-ruched-midi-skirt/PZZ74243-2.html',
#   'prod_name': 'Plus Neon Slinky Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/ruched-midi-skirt/FZZ97088-1.html',
#   'prod_name': 'Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-leopard-print-pleated-midi-skirt/PZZ75023.html',
#   'prod_name': 'Plus Leopard Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/full-tulle-midi-skirt/FZZ94254.html',
#   'prod_name': 'Full Tulle Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-ribbed-high-waist-midaxi-skirt/TZZ96075.html',
#   'prod_name': 'Tall Ribbed High Waist Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/petite-jersey-basic-midi-skirt/PZZ80585.html',
#   'prod_name': 'Petite Jersey Basic Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-ruffle-hem-animal-print-skirt/TZZ95159.html',
#   'prod_name': 'Tall Ruffle Hem Animal Print Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-wrap-leopard-chain-midi-skirt/PZZ75932.html',
#   'prod_name': 'Plus Wrap Leopard & Chain Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-leopard-print-tie-midi-skirt/PZZ75484.html',
#   'prod_name': 'Plus Leopard Print Tie Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-snake-print-tie-midi-skirt/PZZ75556.html',
#   'prod_name': 'Plus Snake Print Tie Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/animal-print-tie-front-midi-skirt/FZZ90668.html',
#   'prod_name': 'Animal Print Tie Front Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-side-split-satin-midi-skirt/TZZ94473.html',
#   'prod_name': 'Tall Side Split Satin Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/knit-high-waisted-ruched-side-midi-skirt/FZZ90955.html',
#   'prod_name': 'Knit High Waisted Ruched Side Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/basic-jersey-midaxi-skirt/DZZ18848-4.html',
#   'prod_name': 'Basic Jersey Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/knot-front-floral-mix-maxi-skirt-co-ord-set/FZZ98677.html',
#   'prod_name': 'Knot Front Floral Mix Maxi Skirt Co-Ord Set'},
#  {'prod_url': 'https://www.boohoo.com/woven-floral-print-wrap-midi-skirt/DZZ02665.html',
#   'prod_name': 'Woven Floral Print Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-scuba-floral-midi-skirt/PZZ72340.html',
#   'prod_name': 'Plus Scuba Floral Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-neon-slinky-ruched-midi-skirt/PZZ74243-3.html',
#   'prod_name': 'Plus Neon Slinky Ruched Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-scuba-floral-midi-skirt/PZZ72338.html',
#   'prod_name': 'Plus Scuba Floral Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-bias-cut-satin-wrap-midi-skirt/TZZ95480.html',
#   'prod_name': 'Tall Bias Cut Satin Wrap Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-leopard-print-pleated-midi-skirt/PZZ71770.html',
#   'prod_name': 'Plus Leopard Print Pleated Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-satin-bias-midi-skirt/PZZ73394.html',
#   'prod_name': 'Plus Satin Bias Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/cord-midi-skirt/FZZ99274.html',
#   'prod_name': 'Cord Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/jersey-midi-skirt/AZZ49276.html',
#   'prod_name': 'Jersey Midi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/tall-jumbo-rib-midaxi-skirt/TZZ96071.html',
#   'prod_name': 'Tall Jumbo Rib Midaxi Skirt'},
#  {'prod_url': 'https://www.boohoo.com/plus-jersey-button-through-midi-pinafore-skirt/PZZ71733.html',
#   'prod_name': 'Plus Jersey Button Through Midi Pinafore Skirt'},
#  {'prod_url': 'https://www.boohoo.com/boutique--lace-top-and-midi-skirt-set/DZZ39522.html',
#   'prod_name': 'Boutique Lace Top and Midi Skirt Set'}]

# %%
#     shop = Field()
#     name = Field()
#     price = Field()
#     prod_url = Field()
#     image_urls = Field()
#     image_hash = Field()
#     sex = Field()
#     sale = Field()
#     saleprice = Field()

#     brand = Field()
#     currency = Field()
#     date = Field()
#     description = Field()
#     color_string = Field()
#     color_hex = Field()
#     category = Field()
#     size_stock = Field()

# %%
prod_page_req = requests.get('https://www.boohoo.com/recycled-rib-twist-detail-crop-midi-skirt-co-ord/FZZ88507-2.html', headers=headers)

# %%
prod_page_doc = lxml.html.fromstring(prod_page_req.text)

# %%
price_match = prod_page_doc.xpath('.//span[contains(@itemprop, "price")]/@content')

# %%
len(price_match)
# Out:
# 1

# %%
price = None
if len(price_match) > 0:
    price = float(price_match[0])

# %%
price
# Out:
# 19.0

# %%
price_class_match = prod_page_doc.xpath('.//span[contains(@itemprop, "price")]/@class')
price_class = None
if len(price_class_match) > 0:
    price_class = price_class_match[0]

# %%
price_class
# Out:
# 'price-sales'

# %%
'sales' in price_class
# Out:
# True

# %%
sale = 'sales' in price_class

# %%
sale
# Out:
# True

# %%
price_std = prod_page_doc.xpath('.//span[@class="price-standard"]/text()')

# %%
float(price_std[0].strip()[1:])
# Out:
# 22.0

# %%
description_match = prod_page_doc.xpath('.//meta[@property="og:description"]/@content')
description = None
if len(description_match) > 0:
    description = description_match[0]

# %%
description
# Out:
# 'Co-ordinates are the quick way to quirky this season  Make way for the matchy-matchy trend this season as style gets streamlined with co-ord sets. Top to toe prints are conversation starters with crop tops, skorts and skirts all in on the action. Break it up with a waist belt and add a quirky clutch for instant style kudos.'

# %%
primary_img_match = prod_page_doc.xpath('.//img[contains(@class, "js-primary-image")]/@src')
primary_img = None
if len(primary_img_match) > 0:
    primary_img = 'https:' + primary_img_match[0]

# %%
primary_img
# Out:
# 'https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl?$product_image_main$'

# %%
prim_im_split = primary_img.split('?')

# %%
prim_im_split
# Out:
# ['//i1.adis.ws/i/boohooamplience/fzz88507_black_xl', '$product_image_main$']

# %%
secondary_imgs = []
for t in range(1,4):
    sec_img_url = f'https:{prim_im_split[0]}_{t}?{prim_im_split[1]}'
    secondary_imgs.append(sec_img_url)

# %%
secondary_imgs
# Out:
# ['https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl_1?$product_image_main$',
#  'https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl_2?$product_image_main$',
#  'https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl_3?$product_image_main$']

# %% [markdown]
# ![title](https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl_3?$product_image_main$)

# %% [markdown]
# ![](https://i1.adis.ws/i/boohooamplience/fzz88507_black_xl_1?$product_image_main$)

# %%
color_match = prod_page_doc.xpath('.//div[contains(text(), "Colour")]/span/text()')
color_string = None
if len(color_match) > 0:
    color_string = color_match[0].strip()

# %%
color_string
# Out:
# 'black'

# %%
size_matches = prod_page_doc.xpath('.//ul[contains(@class, "swatches size")]/li/span/@data-variation-values')
size_arr = []
for size_match in size_matches:
    size_json = json.loads(size_match)
#     print(size_json)
    size_arr.append({
                'stock': 'In stock',
                'size': size_json['attributeValue']
            })

# %%
size_matches
# Out:
# ['{\n"isColor": false,\n"attributeValue": "6",\n"colorBasicDisplayValue": "null"\n}',
#  '{\n"isColor": false,\n"attributeValue": "10",\n"colorBasicDisplayValue": "null"\n}',
#  '{\n"isColor": false,\n"attributeValue": "12",\n"colorBasicDisplayValue": "null"\n}',
#  '{\n"isColor": false,\n"attributeValue": "14",\n"colorBasicDisplayValue": "null"\n}']

# %%
size_arr
# Out:
# [{'stock': 'In stock', 'size': '6'},
#  {'stock': 'In stock', 'size': '10'},
#  {'stock': 'In stock', 'size': '12'},
#  {'stock': 'In stock', 'size': '14'}]
