# %%
import lxml.html
import requests
import re
import json
import random
import math
from IPython.display import Image

# %%
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,lv;q=0.8',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    'Cookie': 'adform_qv=1; akainst=EU1; bm_sz=371D238A55056C204874C555E01A6A8B~YAAQlboQAvLYuzJvAQAAGQY8awauq69/pGSHws4wcsKGgsPT6LdyCAjmaZV0GX9uvTihCIvA65KDYhrJqC4qAMtvIZxorc+pakGPK1bJrjqrHD0ZqxIQJ1DXAhwyjgRo+oQqTcbNBzsLQai2KYVvP1nyX/EdY7Lr93lQgrDx+sQP6RHgdcwLZdii7iI=; ab_first_session=true; ab_new_user=true; optimizelyEndUserId=oeu1578052093793r0.7104636023804616; TS013be3eb=01dd555d354971cb206c5bba70bf2e9d04d1a58426f162ab00cd4fc26a21fa3cb65c42bf9f93779068d9851f4cef8aa1b49de293ff4b883a07208aea327f2633fb2a3e81b2; HMX_123=1; agCookie=42072c9b-119c-42ed-89e9-44593ab6965c; JSESSIONID=ACB6A971DFD79F8048A71BB30598A902B94A5121B0B95BC07F7E13732414B6C1C7F35BCDC30EE5D0C1B95CFE6CC8FA88CD3F587BEA5F7B524F8BB8947C24F66D.HYBECMPRDEU1P04; userCookie=##eyJjYXJ0Q291bnQiOjB9##; hm-greatbritain-favourites=""; TS0150476f=01dd555d35a598ad3f045c681e28059232d3555981f162ab00cd4fc26a21fa3cb65c42bf9f5f2238745280e5d31c5a0423cf824cef95b49b72684695a6c5c0658469808db7d9f76b09d804f675e6d09b914e97787bf51720c957e3e859a523fab247a3304ddc07fa1348d93c8e244d9cbadcf553ab; _abck=B470CB0246C637DAA9DA0AD2201507F5~0~~-1~-1~-1; ak_bmsc=200CC601CA62B5AED384CA445B0647A10210BA9569290000FD290F5EEF53C94F~; AMCVS_32B2238B555215F50A4C98A4%40AdobeOrg=1; AMCV_32B2238B555215F50A4C98A4%40AdobeOrg=-1891778711%7CMCIDTS%7C18265%7CMCMID%7C32509042840667002613805168883976474988%7CMCAAMLH-1578656894%7C6%7CMCAAMB-1578656894%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1578059294s%7CNONE%7CMCAID%7CNONE%7CvVersion%7C2.4.0; akamref=en_gb; s_cc=true; _ga=GA1.2.1762485173.1578052097; _gid=GA1.2.91507510.1578052097; _gat_GA_GLOBAL=1; _gat_GA_LOCAL=1; aasegs=aal%3D16770768; aamgasegs=segid%3D16770768; aemsegs=aem%3D15496949; AAMAA=AAMSegID%3D6499983; aamoptsegs=aam%3D6499983; aam_uuid=32480940005034741573801223354624019812; rmStore=atm:mop; _scid=55e0609b-c299-4698-9659-7336d7bbb9c5; _gcl_au=1.1.1999456257.1578052098; _derived_epik=dj0yJnU9dHVNb1ZwU1BWLWdTakR1WkI4SXBJRExWTTJscGNheWImbj05YjRzMTJUTkltbHRLOG9NeG1DZ253Jm09NyZ0PUFBQUFBRjRQS2dF; stc114913=tsa:1578052097860.965267166.0997734.22803766749101118.:20200103121817|env:1%7C20200203114817%7C20200103121817%7C1%7C1044345:20210102114817|uid:1578052097860.462183129.81846285.114913.1270117984:20210102114817|srchist:1044345%3A1%3A20200203114817:20210102114817; _CT_RS_=Recording; WRUIDAWS20180923=2588372142063675; __CT_Data=gpv=1&ckp=tld&dm=hm.com&apv_44_www36=1&cpv_44_www36=1&rpv_44_www36=1; dtPC=-; dtLatC=1; akavpau_www2_en_gb=1578052402~id=a2de8376130a19b91e7d6cad1c6f1b7e; bm_sv=1DF3FBF8986D2EB7A0C29B188D1263F7~U+1nPa2Om/ebIZWhib5B/8Dya3ev8adQ827V85zw3aEAcltUGL7gYLgUQbji0wlaE8HZTmA6/KPn+2/K+/hoPFACslUrlnMDlMRVNJx5INL+HfutnoCBxB7+pbQUBnZn9ye0CggRbnf34bCIAQdC2A==; ctm={\'pgv\':8652317113624582|\'vst\':3673420648741103|\'vstr\':3489893303812675|\'intr\':1578052105258|\'v\':1}; utag_main=v_id:016f6b3c0ac2002c3d3c4fb28e6803078002507000c48$_sn:1$_se:5$_ss:0$_st:1578053907148$ses_id:1578052094659%3Bexp-session$_pn:1%3Bexp-session$touchpoint:DESKTOP%3Bexp-session$vc:%7B%7D%3Bexp-session$cart_active:No%3Bexp-session$opt_ga:16836871062_16857820741%3Bexp-session$vapi_domain:hm.com; dtCookie=127A539A60CFA9971BCCF7218A073C8D|SCUyNk0rUHJvZHVjdGlvbitXZWJ8MQ; dtSa=true%7CKD82%7C-1%7CHM.com%20%20LadiesNew%20ArrivalsClothesShoes%20%26%20AccessoriesBeautyShop%20by%20ProductView%20AllDressesShirts%20%26%20Blo...%7C-%7C1578052107710%7C52093668_530%7Chttps%3A%2F%2Fwww2.hm.com%2Fen_5Fgb%2Fladies.html%7CWomen%27s%20Clothing%20%26%20Fashion%20-%20shop%20the%20latest%20trends%20%5Ep%20H%26M%20GB%7C1578052101992%7C; RT="sl=1&ss=1578052093291&tt=3673&obo=0&bcn=%2F%2F0211c844.akstat.io%2F&sh=1578052096970%3D1%3A0%3A3673&dm=hm.com&si=b2ea6600-abba-4323-9fee-d836e61c05a9&ld=1578052096970&r=https%3A%2F%2Fwww2.hm.com%2Fen_gb%2Fladies.html&ul=1578052107734"',
    'Host': 'www2.hm.com',
    'Pragma': 'no-cache',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

# %%
homepage_req = requests.get('https://www2.hm.com/en_gb/ladies.html', headers=headers)

# %%
homepage_doc = lxml.html.fromstring(homepage_req.text)

# %%
links = homepage_doc.xpath('.//a[@role="menuitem"]')

# %%
for link in links:
    cat_url = link.xpath("./@href")[0]
    print(cat_url)
    cat_name = link.xpath('./text()')[0]
    cat_name = ''.join(ch for ch in cat_name if ch.isalnum())
    print(f'Cat name: {cat_name}')
    cat_api_regex = re.search('\/(?:.(?!\/))+$', cat_url)
    api_regex = re.search(r'(?<=\/).*?(?=\.html?)', cat_api_regex.group(0))
    print(f'API slug: {api_regex.group(0)}')
# Out:
# /en_gb/ladies/new-arrivals/clothes.html
# Cat name: Clothes
# API slug: clothes
# /en_gb/ladies/new-arrivals/shoes-and-accessories.html
# Cat name: ShoesAccessories
# API slug: shoes-and-accessories
# /en_gb/ladies/new-arrivals/beauty.html
# Cat name: Beauty
# API slug: beauty
# /en_gb/ladies/shop-by-product/view-all.html
# Cat name: ViewAll
# API slug: view-all
# /en_gb/ladies/shop-by-product/dresses.html
# Cat name: Dresses
# API slug: dresses
# /en_gb/ladies/shop-by-product/shirts-and-blouses.html
# Cat name: ShirtsBlouses
# API slug: shirts-and-blouses
# /en_gb/ladies/shop-by-product/tops.html
# Cat name: Tops
# API slug: tops
# /en_gb/ladies/shop-by-product/cardigans-and-jumpers.html
# Cat name: CardigansJumpers
# API slug: cardigans-and-jumpers
# /en_gb/ladies/shop-by-product/blazers-and-waistcoats.html
# Cat name: Blazers
# API slug: blazers-and-waistcoats
# /en_gb/ladies/shop-by-product/jackets-and-coats.html
# Cat name: JacketsCoats
# API slug: jackets-and-coats
# /en_gb/ladies/shop-by-product/hoodies-sweatshirts.html
# Cat name: SweatshirtsHoodies
# API slug: hoodies-sweatshirts
# /en_gb/ladies/shop-by-product/trousers.html
# Cat name: Trousers
# API slug: trousers
# /en_gb/ladies/shop-by-product/jeans.html
# Cat name: Jeans
# API slug: jeans
# /en_gb/ladies/shop-by-product/skirts.html
# Cat name: Skirts
# API slug: skirts
# /en_gb/ladies/shop-by-product/shoes.html
# Cat name: Shoes
# API slug: shoes
# /en_gb/ladies/shop-by-product/accessories.html
# Cat name: Accessories
# API slug: accessories
# /en_gb/ladies/shop-by-product/lingerie.html
# Cat name: Lingerie
# API slug: lingerie
# /en_gb/ladies/shop-by-product/jumpsuits-playsuits.html
# Cat name: JumpsuitsRompers
# API slug: jumpsuits-playsuits
# /en_gb/ladies/shop-by-product/shorts.html
# Cat name: Shorts
# API slug: shorts
# /en_gb/ladies/shop-by-product/swimwear.html
# Cat name: SwimwearBeachwear
# API slug: swimwear
# /en_gb/ladies/shop-by-product/socks-and-tights.html
# Cat name: SocksTights
# API slug: socks-and-tights
# /en_gb/ladies/shop-by-product/sportswear.html
# Cat name: Sportswear
# API slug: sportswear
# /en_gb/ladies/shop-by-product/maternity-wear.html
# Cat name: MaternityWear
# API slug: maternity-wear
# /en_gb/ladies/shop-by-product/hm-plus.html
# Cat name: HMPlusSizes
# API slug: hm-plus
# /en_gb/ladies/shop-by-product/beauty.html
# Cat name: Beauty
# API slug: beauty
# /en_gb/ladies/shop-by-product/care-products.html
# Cat name: CareProducts
# API slug: care-products
# /en_gb/ladies/shop-by-product/nightwear-loungewear.html
# Cat name: NightwearLoungewear
# API slug: nightwear-loungewear
# /en_gb/ladies/conscious-shop/ladies.html
# Cat name: Ladies
# API slug: ladies
# /en_gb/ladies/sustainability-at-h-m/consious-products-explained.html
# Cat name: ConsciousProductsExplained
# API slug: consious-products-explained
# /en_gb/ladies/sustainability-at-h-m/recycle-at-h-m.html
# Cat name: RecycleatHM
# API slug: recycle-at-h-m
# /en_gb/ladies/sustainability-at-h-m/h-m-take-care.html
# Cat name: HMTakeCare
# API slug: h-m-take-care
# /en_gb/ladies/sustainability-at-h-m/h-m-s-sustainability-strategy.html
# Cat name: HMsSustainabilityStrategy
# API slug: h-m-s-sustainability-strategy
# /en_gb/ladies/h-m-music0/h-m-music0.html
# Cat name: GabrielleAplin
# API slug: h-m-music0
# /en_gb/ladies/h-m-music0/ider.html
# Cat name: IDER
# API slug: ider
# /en_gb/ladies/h-m-music0/millie-turner.html
# Cat name: MillieTurner
# API slug: millie-turner
# /en_gb/ladies/shop-by-concept/divided.html
# Cat name: Divided
# API slug: divided
# /en_gb/ladies/shop-by-concept/trend.html
# Cat name: Trend
# API slug: trend
# /en_gb/ladies/shop-by-concept/modern-classic.html
# Cat name: ModernClassic
# API slug: modern-classic
# /en_gb/ladies/shop-by-concept/party.html
# Cat name: Party
# API slug: party
# /en_gb/ladies/shop-by-concept/basics.html
# Cat name: Basics
# API slug: basics
# /en_gb/ladies/shop-by-concept/logg.html
# Cat name: LOGG
# API slug: logg
# /en_gb/ladies/shop-by-concept/hm-sport.html
# Cat name: Sportswear
# API slug: hm-sport
# /en_gb/ladies/shop-by-concept/premium-quality.html
# Cat name: PremiumQuality
# API slug: premium-quality
# /en_gb/ladies/shop-by-concept/conscious-sustainable-style.html
# Cat name: ConsciousSustainableStyle
# API slug: conscious-sustainable-style
# /en_gb/ladies/shop-by-concept/denim.html
# Cat name: Denim
# API slug: denim
# /en_gb/ladies/gift-cards/gift-card.html
# Cat name: GiftCards
# API slug: gift-card
# /en_gb/ladies/magazine/magazine.html
# Cat name: Magazine
# API slug: magazine

# %%
cat_url = 'https://www2.hm.com/en_gb/ladies/shop-by-product/jackets-and-coats.html'

# %%
cat_page_req = requests.get(cat_url, headers=headers)

# %%
cat_page_doc = lxml.html.fromstring(cat_page_req.text)

# %%
count_slug_array = 'jackets-and-coats'.split('-')

# %%
count_slug_array = [word for word in count_slug_array if word not in ['and']]

# %%
count_slug = ''.join(count_slug_array)

# %%
count_check_slug = f'ladies_{count_slug}'

# %%
long_api_slug = re.search(r'(?<=data\-filtered\-products\-url\=\").*?(?=\")', cat_page_req.text)

# %%
long_api_slug.group(0)
# Out:
# '/en_gb/ladies/shop-by-product/jackets-and-coats/_jcr_content/main/productlisting.display.json'

# %%
if len(cat_url.split('new-arrivals')) == 2:
    count_check_url = f'https://www2.hm.com{long_api_slug.group(0)}?sort=stock&image-size=large&image=model&offset=0&page-size=36'
elif len(cat_url.split('shop-by-occasion')) == 2:
    count_check_url = f'https://www2.hm.com{long_api_slug.group(0)}?sort=stock&image-size=large&image=model&offset=0&page-size=36'
else:
    count_check_url = f'https://www2.hm.com{long_api_slug.group(0)}?product-type={count_check_slug}&sort=stock&image-size=large&image=model&offset=0&page-size=36'
print(count_check_url)
# Out:
# https://www2.hm.com/en_gb/ladies/shop-by-product/jackets-and-coats/_jcr_content/main/productlisting.display.json?product-type=ladies_jacketscoats&sort=stock&image-size=large&image=model&offset=0&page-size=36

# %%
count_check_response = requests.get(count_check_url, headers=headers)

# %%
if count_check_response.status_code == 200:
    count_check_dict = json.loads(count_check_response.text)
    if len(count_check_dict) > 0:
        prod_count = count_check_dict['total']
        page_count = int(math.ceil(prod_count / 36))

        for i in range(0, page_count):
#             print(f'offset = {i * 36}')
            if len(cat_url.split('new-arrivals')) == 2:
                get_prod_url = f'https://www2.hm.com{long_api_slug.group(0)}?sort=stock&image-size=large&image=model&offset={i * 36}&page-size=36'
            elif len(cat_url.split('shop-by-occasion')) == 2:
                get_prod_url = f'https://www2.hm.com{long_api_slug.group(0)}?sort=stock&image-size=large&image=model&offset={i * 36}&page-size=36'
            else:
                get_prod_url = f'https://www2.hm.com{long_api_slug.group(0)}?product-type={count_check_slug}&sort=stock&image-size=large&image=model&offset={i * 36}&page-size=36'

#             print(get_prod_url)
            get_prod_response = requests.get(get_prod_url, headers=headers)
            if get_prod_response.status_code == 200:
                get_prod_dict = json.loads(get_prod_response.text)

                prod_array = get_prod_dict['products']
                for prod in prod_array:
#                     print(prod)
                    prod_url = prod['link']
                    prod_id = prod['articleCode']
                    sale_price = prod['redPrice']
                    if len(sale_price) == 0:
                        sale_price = prod['yellowPrice']
                    swatches = prod['swatches']
                    current_swatch = [swatch for swatch in swatches if swatch['articleLink'] == prod_url]
                    if len(current_swatch) > 0:
                        color_string = current_swatch[0]['colorName']
                        color_hex = current_swatch[0]['colorCode']

                        print({
                                'name': prod['title'],
                                'price': prod['price'],
                                'sale': prod['showPriceMarker'],
                                'sale_price': sale_price,
                                'prod_url': f'https://www2.hm.com{prod_url}',
                                'prod_id': prod_id,
                                'color_string': color_string,
                                'color_hex': color_hex
                            })
# Out:
# {'name': 'Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0833548001.html', 'prod_id': '0833548001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'H&M+ Dogtooth-patterned coat', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831444001.html', 'prod_id': '0831444001', 'color_string': 'Black/Dogtooth-patterned', 'color_hex': '#272628'}
# {'name': 'Boxy puffer jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721268001.html', 'prod_id': '0721268001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Lightweight hooded down coat', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0775825001.html', 'prod_id': '0775825001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Short wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0661794001.html', 'prod_id': '0661794001', 'color_string': 'Light beige marl', 'color_hex': '#D1C9B3'}
# {'name': 'Pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0746168003.html', 'prod_id': '0746168003', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849095001.html', 'prod_id': '0849095001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile-lined parka', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721266001.html', 'prod_id': '0721266001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Dogtooth-patterned coat', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831545001.html', 'prod_id': '0831545001', 'color_string': 'Black/Dogtooth-patterned', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0782562001.html', 'prod_id': '0782562001', 'color_string': 'Light beige', 'color_hex': '#D0C9C0'}
# {'name': 'Wool-blend shirt jacket', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0835207001.html', 'prod_id': '0835207001', 'color_string': 'Grey marl', 'color_hex': '#848287'}
# {'name': 'Pile coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0790006003.html', 'prod_id': '0790006003', 'color_string': 'Beige', 'color_hex': '#AC996F'}
# {'name': 'Imitation leather shirt jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831686001.html', 'prod_id': '0831686001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Boxy puffer jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721268006.html', 'prod_id': '0721268006', 'color_string': 'Light grey', 'color_hex': '#B9B1AA'}
# {'name': 'Wool-blend coat', 'price': '£119.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811953003.html', 'prod_id': '0811953003', 'color_string': 'Light beige', 'color_hex': '#E9E4DA'}
# {'name': 'Knee-length wool-blend coat', 'price': '£99.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0763323002.html', 'prod_id': '0763323002', 'color_string': 'Burgundy', 'color_hex': '#762229'}
# {'name': 'Padded hooded jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772832001.html', 'prod_id': '0772832001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Coat with a hood', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0844549001.html', 'prod_id': '0844549001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Printed puffer jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0841862001.html', 'prod_id': '0841862001', 'color_string': 'Black/Patterned', 'color_hex': '#272628'}
# {'name': 'Padded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0778270001.html', 'prod_id': '0778270001', 'color_string': 'White', 'color_hex': '#ECEDEC'}
# {'name': 'High-collared pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837743002.html', 'prod_id': '0837743002', 'color_string': 'Dark grey', 'color_hex': '#383A3D'}
# {'name': 'Hooded fleece jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0805000001.html', 'prod_id': '0805000001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Knee-length coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787049001.html', 'prod_id': '0787049001', 'color_string': 'Moss green', 'color_hex': '#3E3629'}
# {'name': 'Hooded fleece jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0805000003.html', 'prod_id': '0805000003', 'color_string': 'Light grey marl', 'color_hex': '#A6A8AC'}
# {'name': 'Pile coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837325001.html', 'prod_id': '0837325001', 'color_string': 'Dark beige', 'color_hex': '#89725A'}
# {'name': 'Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0699623006.html', 'prod_id': '0699623006', 'color_string': 'Light grey marl', 'color_hex': '#B2ADA4'}
# {'name': 'Short faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837360002.html', 'prod_id': '0837360002', 'color_string': 'Plum', 'color_hex': '#4B262D'}
# {'name': 'Imitation leather biker jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0815851001.html', 'prod_id': '0815851001', 'color_string': 'Black/Silver-coloured', 'color_hex': '#272628'}
# {'name': 'Short wool-blend coat', 'price': '£99.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0853928001.html', 'prod_id': '0853928001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Coat with a faux fur collar', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0761360001.html', 'prod_id': '0761360001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Coat with a tie belt', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0614622018.html', 'prod_id': '0614622018', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837325002.html', 'prod_id': '0837325002', 'color_string': 'White', 'color_hex': '#EEECE0'}
# {'name': 'Wool-blend bouclé coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0705944002.html', 'prod_id': '0705944002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded parka', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0742561001.html', 'prod_id': '0742561001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0824143001.html', 'prod_id': '0824143001', 'color_string': 'Dark green', 'color_hex': '#384440'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721267001.html', 'prod_id': '0721267001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Stand-up-collar pile jacket', 'price': '£19.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0785706001.html', 'prod_id': '0785706001', 'color_string': 'Cream', 'color_hex': '#D0C9C0'}
# {'name': 'Faux fur jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0824143002.html', 'prod_id': '0824143002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Bouclé coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0833534001.html', 'prod_id': '0833534001', 'color_string': 'Dark blue', 'color_hex': '#2C2E35'}
# {'name': 'Short faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811229001.html', 'prod_id': '0811229001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Wool-blend coat', 'price': '£139.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0839464001.html', 'prod_id': '0839464001', 'color_string': 'Dark grey', 'color_hex': '#4D494F'}
# {'name': 'Padded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0778270003.html', 'prod_id': '0778270003', 'color_string': 'Red', 'color_hex': '#951F34'}
# {'name': 'Hooded fleece jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0805000004.html', 'prod_id': '0805000004', 'color_string': 'Light pink', 'color_hex': '#A49092'}
# {'name': 'Short bouclé coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849730002.html', 'prod_id': '0849730002', 'color_string': 'Pigeon blue', 'color_hex': '#687182'}
# {'name': 'Short faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0770607001.html', 'prod_id': '0770607001', 'color_string': 'Light greige', 'color_hex': '#B9B1AA'}
# {'name': 'Wool-blend coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0312878001.html', 'prod_id': '0312878001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Double-breasted wool-mix coat', 'price': '£99.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0799742003.html', 'prod_id': '0799742003', 'color_string': 'Camel', 'color_hex': '#8B6433'}
# {'name': 'Padded parka', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0535035002.html', 'prod_id': '0535035002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'High-collared pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837743001.html', 'prod_id': '0837743001', 'color_string': 'Light beige', 'color_hex': '#F3EFE5'}
# {'name': 'Metallic puffer jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787144002.html', 'prod_id': '0787144002', 'color_string': 'Brown', 'color_hex': '#7B5E4D'}
# {'name': 'Faux fur jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0778840001.html', 'prod_id': '0778840001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802920001.html', 'prod_id': '0802920001', 'color_string': 'Greige', 'color_hex': '#B9B1AA'}
# {'name': 'Wool coat', 'price': '£119.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0839996001.html', 'prod_id': '0839996001', 'color_string': 'Dark blue', 'color_hex': '#4C5164'}
# {'name': 'Cotton parka', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787172001.html', 'prod_id': '0787172001', 'color_string': 'Green', 'color_hex': '#696A50'}
# {'name': 'Faux fur jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0741054001.html', 'prod_id': '0741054001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded parka with a hood', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0795020001.html', 'prod_id': '0795020001', 'color_string': 'Dark blue', 'color_hex': '#2C2E35'}
# {'name': 'Duffle coat with faux fur', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0788306001.html', 'prod_id': '0788306001', 'color_string': 'Light beige', 'color_hex': '#C3BFB5'}
# {'name': 'Oversized twill jacket', 'price': '£29.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0783709001.html', 'prod_id': '0783709001', 'color_string': 'Dark blue', 'color_hex': '#393A45'}
# {'name': 'Double-breasted coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0699617004.html', 'prod_id': '0699617004', 'color_string': 'Dark green', 'color_hex': '#384440'}
# {'name': 'Down coat with a belt', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0786921001.html', 'prod_id': '0786921001', 'color_string': 'Dark brown', 'color_hex': '#403835'}
# {'name': 'Pile jacket with a collar', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849802001.html', 'prod_id': '0849802001', 'color_string': 'Beige', 'color_hex': '#B1A396'}
# {'name': 'Short faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837360001.html', 'prod_id': '0837360001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0760454002.html', 'prod_id': '0760454002', 'color_string': 'Red', 'color_hex': '#951F34'}
# {'name': 'Padded jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740211002.html', 'prod_id': '0740211002', 'color_string': 'Mustard yellow', 'color_hex': '#AC8D52'}
# {'name': 'Double-breasted jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0786818001.html', 'prod_id': '0786818001', 'color_string': 'Light beige', 'color_hex': '#AE9F8E'}
# {'name': 'Coat with a belt', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0832977001.html', 'prod_id': '0832977001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802920004.html', 'prod_id': '0802920004', 'color_string': 'Khaki green', 'color_hex': '#66665B'}
# {'name': 'Short wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0661794006.html', 'prod_id': '0661794006', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0741054005.html', 'prod_id': '0741054005', 'color_string': 'Light pink', 'color_hex': '#D6BAB6'}
# {'name': 'Short pile coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772822001.html', 'prod_id': '0772822001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Long faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802927001.html', 'prod_id': '0802927001', 'color_string': 'Cream', 'color_hex': '#EEECE0'}
# {'name': 'Short bouclé coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849730001.html', 'prod_id': '0849730001', 'color_string': 'Old rose', 'color_hex': '#9F6F6B'}
# {'name': 'Oversized down jacket', 'price': '£119.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0815330001.html', 'prod_id': '0815330001', 'color_string': 'White', 'color_hex': '#ECEDEC'}
# {'name': 'Pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0746168005.html', 'prod_id': '0746168005', 'color_string': 'White', 'color_hex': '#DCD6C7'}
# {'name': 'Faux fur-lined jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740208004.html', 'prod_id': '0740208004', 'color_string': 'Beige', 'color_hex': '#B49F7C'}
# {'name': 'Faux fur-lined jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740208008.html', 'prod_id': '0740208008', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Oversized biker jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0760449001.html', 'prod_id': '0760449001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0780955001.html', 'prod_id': '0780955001', 'color_string': 'Light beige/Leopard print', 'color_hex': '#272628'}
# {'name': 'Short wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0661794002.html', 'prod_id': '0661794002', 'color_string': 'Dark blue', 'color_hex': '#2B3241'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0841863001.html', 'prod_id': '0841863001', 'color_string': 'Beige', 'color_hex': '#BBAB92'}
# {'name': 'Oversized denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849659001.html', 'prod_id': '0849659001', 'color_string': 'Cream', 'color_hex': '#E8E4D5'}
# {'name': 'Wool-blend coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0312878010.html', 'prod_id': '0312878010', 'color_string': 'Beige', 'color_hex': '#907E67'}
# {'name': 'Wool-blend coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0848782001.html', 'prod_id': '0848782001', 'color_string': 'Light grey', 'color_hex': '#B2B1B5'}
# {'name': 'Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0760451001.html', 'prod_id': '0760451001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802930002.html', 'prod_id': '0802930002', 'color_string': 'Cream', 'color_hex': '#EEECE0'}
# {'name': 'Faux fur collar biker jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0830535002.html', 'prod_id': '0830535002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Straight-cut coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755361004.html', 'prod_id': '0755361004', 'color_string': 'Dark beige', 'color_hex': '#937050'}
# {'name': 'Puffer jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802921002.html', 'prod_id': '0802921002', 'color_string': 'Light pink', 'color_hex': '#B09A95'}
# {'name': 'Padded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755440003.html', 'prod_id': '0755440003', 'color_string': 'Beige', 'color_hex': '#B7AB9A'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0782562002.html', 'prod_id': '0782562002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Wool-blend shirt jacket', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0805134001.html', 'prod_id': '0805134001', 'color_string': 'Dark beige', 'color_hex': '#A9927F'}
# {'name': 'Lined biker jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0795071001.html', 'prod_id': '0795071001', 'color_string': 'Light beige', 'color_hex': '#BFAFA0'}
# {'name': 'Jacquard-weave shirt jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837810001.html', 'prod_id': '0837810001', 'color_string': 'Black/Checked', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0838659002.html', 'prod_id': '0838659002', 'color_string': 'Burgundy', 'color_hex': '#582B34'}
# {'name': 'Padded parka with a hood', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740213001.html', 'prod_id': '0740213001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile-lined denim jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831462002.html', 'prod_id': '0831462002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Biker jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721762001.html', 'prod_id': '0721762001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787097001.html', 'prod_id': '0787097001', 'color_string': 'Cream', 'color_hex': '#F3EFE5'}
# {'name': 'H&M+ Shirt jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831441001.html', 'prod_id': '0831441001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Coat with faux fur', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0829812002.html', 'prod_id': '0829812002', 'color_string': 'Pink', 'color_hex': '#AF8694'}
# {'name': 'Faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740215006.html', 'prod_id': '0740215006', 'color_string': 'Natural white', 'color_hex': '#D0C9C0'}
# {'name': 'Knee-length coat', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811634001.html', 'prod_id': '0811634001', 'color_string': 'Cream', 'color_hex': '#EAE3D2'}
# {'name': 'Pile-lined parka', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721266002.html', 'prod_id': '0721266002', 'color_string': 'Khaki green', 'color_hex': '#3D4139'}
# {'name': 'Windproof running jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0558282001.html', 'prod_id': '0558282001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile-lined biker jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0799329001.html', 'prod_id': '0799329001', 'color_string': 'Light mole', 'color_hex': '#A79E92'}
# {'name': 'Padded hooded outdoor jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0794321001.html', 'prod_id': '0794321001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Double-breasted jacket', 'price': '£29.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755360002.html', 'prod_id': '0755360002', 'color_string': 'Grey marl', 'color_hex': '#5F6168'}
# {'name': 'Hooded jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721269001.html', 'prod_id': '0721269001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0760454001.html', 'prod_id': '0760454001', 'color_string': 'Beige/Leopard print', 'color_hex': '#C2B097'}
# {'name': 'Lightweight hooded down coat', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0775825003.html', 'prod_id': '0775825003', 'color_string': 'Dark brown', 'color_hex': '#423C37'}
# {'name': 'Long down jacket', 'price': '£119.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811455001.html', 'prod_id': '0811455001', 'color_string': 'Dark khaki green', 'color_hex': '#444742'}
# {'name': 'Wool-blend coat', 'price': '£119.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811943001.html', 'prod_id': '0811943001', 'color_string': 'Greige', 'color_hex': '#726A5D'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0829187001.html', 'prod_id': '0829187001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur gilet', 'price': '£29.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0760425001.html', 'prod_id': '0760425001', 'color_string': 'Light brown', 'color_hex': '#816E63'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0849095002.html', 'prod_id': '0849095002', 'color_string': 'White', 'color_hex': '#ECEDEC'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0782562003.html', 'prod_id': '0782562003', 'color_string': 'Blue', 'color_hex': '#224A7C'}
# {'name': 'Padded parka with a hood', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740213002.html', 'prod_id': '0740213002', 'color_string': 'Red', 'color_hex': '#951F34'}
# {'name': 'Lightweight down jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755363001.html', 'prod_id': '0755363001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0804631001.html', 'prod_id': '0804631001', 'color_string': 'Turquoise', 'color_hex': '#3D8C96'}
# {'name': 'Faux fur coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0784272002.html', 'prod_id': '0784272002', 'color_string': 'Light beige', 'color_hex': '#D0C2AA'}
# {'name': 'Short pile coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772822002.html', 'prod_id': '0772822002', 'color_string': 'Cream', 'color_hex': '#DCD6C7'}
# {'name': 'Short wool-blend jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0812784001.html', 'prod_id': '0812784001', 'color_string': 'Light greige', 'color_hex': '#B9B1AA'}
# {'name': 'Faux fur-lined jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740208006.html', 'prod_id': '0740208006', 'color_string': 'Greige', 'color_hex': '#B9B1AA'}
# {'name': 'Long faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802927002.html', 'prod_id': '0802927002', 'color_string': 'Sage green', 'color_hex': '#7B8883'}
# {'name': 'Pile-lined denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0774683001.html', 'prod_id': '0774683001', 'color_string': 'Denim blue', 'color_hex': '#4C5164'}
# {'name': 'Padded hooded jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0806477001.html', 'prod_id': '0806477001', 'color_string': 'Dark beige', 'color_hex': '#9F8061'}
# {'name': 'Long, lightweight down jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0774954001.html', 'prod_id': '0774954001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Suede biker jacket', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787052003.html', 'prod_id': '0787052003', 'color_string': 'Brown', 'color_hex': '#7C4F3A'}
# {'name': 'Faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0810008002.html', 'prod_id': '0810008002', 'color_string': 'Light khaki green', 'color_hex': '#8F9489'}
# {'name': 'Pile jacket with a collar', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0794779001.html', 'prod_id': '0794779001', 'color_string': 'Brown', 'color_hex': '#754B2D'}
# {'name': 'Pile sports top', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0754275001.html', 'prod_id': '0754275001', 'color_string': 'Light beige', 'color_hex': '#D7CFBD'}
# {'name': 'Hooded running jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0686655003.html', 'prod_id': '0686655003', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Hooded sports jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0696155001.html', 'prod_id': '0696155001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Double-breasted coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772761001.html', 'prod_id': '0772761001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Short faux fur jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802929003.html', 'prod_id': '0802929003', 'color_string': 'Ice blue', 'color_hex': '#878D99'}
# {'name': 'H&M+ Padded gilet', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0800304001.html', 'prod_id': '0800304001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Flannel shirt jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0799850001.html', 'prod_id': '0799850001', 'color_string': 'Natural white/Checked', 'color_hex': '#EFEFDF'}
# {'name': 'Long denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831446002.html', 'prod_id': '0831446002', 'color_string': 'Black', 'color_hex': '#2E2E30'}
# {'name': 'Imitation leather shirt jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0865434001.html', 'prod_id': '0865434001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0810008001.html', 'prod_id': '0810008001', 'color_string': 'Light brown', 'color_hex': '#9F7E55'}
# {'name': 'Short coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0745737001.html', 'prod_id': '0745737001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802918003.html', 'prod_id': '0802918003', 'color_string': 'Dusky green', 'color_hex': '#A6AEAA'}
# {'name': 'Pile jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0844960001.html', 'prod_id': '0844960001', 'color_string': 'Orange', 'color_hex': '#B16232'}
# {'name': 'Oversized denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0687856001.html', 'prod_id': '0687856001', 'color_string': 'Denim blue', 'color_hex': '#767F99'}
# {'name': 'Long hooded gilet', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0807825001.html', 'prod_id': '0807825001', 'color_string': 'Olive green', 'color_hex': '#6C5531'}
# {'name': 'Pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0825244002.html', 'prod_id': '0825244002', 'color_string': 'Light beige', 'color_hex': '#BBA594'}
# {'name': 'H&M+ Biker jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0761502001.html', 'prod_id': '0761502001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Imitation leather jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0850224001.html', 'prod_id': '0850224001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Oversized denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0780237001.html', 'prod_id': '0780237001', 'color_string': 'Denim blue', 'color_hex': '#79829D'}
# {'name': 'Short faux fur jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802929001.html', 'prod_id': '0802929001', 'color_string': 'Light pink', 'color_hex': '#D6BAB6'}
# {'name': 'Oversized twill jacket', 'price': '£29.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0783709003.html', 'prod_id': '0783709003', 'color_string': 'Rust brown', 'color_hex': '#7D402A'}
# {'name': 'H&M+ Double-breasted jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0777467001.html', 'prod_id': '0777467001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded parka with a hood', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0795020002.html', 'prod_id': '0795020002', 'color_string': 'Apricot', 'color_hex': '#B49885'}
# {'name': 'Short pile coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772822003.html', 'prod_id': '0772822003', 'color_string': 'Dark yellow', 'color_hex': '#9A7230'}
# {'name': 'Denim jacket', 'price': '£29.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0399061015.html', 'prod_id': '0399061015', 'color_string': 'Black denim', 'color_hex': '#272628'}
# {'name': 'Padded parka', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0535035001.html', 'prod_id': '0535035001', 'color_string': 'Dark mole', 'color_hex': '#6F6767'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787096002.html', 'prod_id': '0787096002', 'color_string': 'Pink', 'color_hex': '#A3486D'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721267002.html', 'prod_id': '0721267002', 'color_string': 'Powder pink', 'color_hex': '#B3A49F'}
# {'name': 'H&M+ Denim jacket', 'price': '£19.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0763544001.html', 'prod_id': '0763544001', 'color_string': 'Bright red', 'color_hex': '#A2273B'}
# {'name': 'Denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0735600006.html', 'prod_id': '0735600006', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded bomber jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0797680004.html', 'prod_id': '0797680004', 'color_string': 'Khaki green', 'color_hex': '#5E5648'}
# {'name': 'Cotton twill parka', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0772830001.html', 'prod_id': '0772830001', 'color_string': 'Light beige', 'color_hex': '#B1A895'}
# {'name': 'Padded hooded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721267003.html', 'prod_id': '0721267003', 'color_string': 'Red', 'color_hex': '#8D2535'}
# {'name': 'Popover jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0753007001.html', 'prod_id': '0753007001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0761370001.html', 'prod_id': '0761370001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Pile jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0825244001.html', 'prod_id': '0825244001', 'color_string': 'Powder pink', 'color_hex': '#D4BFB8'}
# {'name': 'Felted coat with a tie belt', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0690212001.html', 'prod_id': '0690212001', 'color_string': 'Old rose', 'color_hex': '#A49092'}
# {'name': 'Padded jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811297001.html', 'prod_id': '0811297001', 'color_string': 'Light khaki green/Patterned', 'color_hex': '#5C6155'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0787147001.html', 'prod_id': '0787147001', 'color_string': 'Beige', 'color_hex': '#8C735A'}
# {'name': 'Denim utility jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721450001.html', 'prod_id': '0721450001', 'color_string': 'Khaki green', 'color_hex': '#5A695E'}
# {'name': 'Oversized denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0780237002.html', 'prod_id': '0780237002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0804796001.html', 'prod_id': '0804796001', 'color_string': 'Cream/Patterned', 'color_hex': '#F4F3E9'}
# {'name': 'Felted coat with a tie belt', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0690212002.html', 'prod_id': '0690212002', 'color_string': 'Light greige', 'color_hex': '#B1AAA7'}
# {'name': 'Denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0735600002.html', 'prod_id': '0735600002', 'color_string': 'Denim blue', 'color_hex': '#68759A'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0534181010.html', 'prod_id': '0534181010', 'color_string': 'Burgundy', 'color_hex': '#503B40'}
# {'name': 'Coat with a tie belt', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755362003.html', 'prod_id': '0755362003', 'color_string': 'Light brown', 'color_hex': '#9F7E55'}
# {'name': 'Coat with draped lapels', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0580301001.html', 'prod_id': '0580301001', 'color_string': 'Beige', 'color_hex': '#A5917C'}
# {'name': 'Denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0735600008.html', 'prod_id': '0735600008', 'color_string': 'Light blue', 'color_hex': '#79829D'}
# {'name': 'Oversized pile jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0819509001.html', 'prod_id': '0819509001', 'color_string': 'Beige', 'color_hex': '#BBAB92'}
# {'name': 'H&M+ Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0840312004.html', 'prod_id': '0840312004', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0851913001.html', 'prod_id': '0851913001', 'color_string': 'Dark khaki green', 'color_hex': '#575549'}
# {'name': 'Checked shirt jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0799017001.html', 'prod_id': '0799017001', 'color_string': 'Black/White checked', 'color_hex': '#272628'}
# {'name': 'Padded parka with a hood', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0740213003.html', 'prod_id': '0740213003', 'color_string': 'Natural white', 'color_hex': '#ECEDEC'}
# {'name': 'H&M+ Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0725178001.html', 'prod_id': '0725178001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Hooded running jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0686655006.html', 'prod_id': '0686655006', 'color_string': 'Light pink', 'color_hex': '#CB9A97'}
# {'name': 'Pile coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0802924001.html', 'prod_id': '0802924001', 'color_string': 'Natural white', 'color_hex': '#DFD7CA'}
# {'name': 'Pile-lined parka', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721266003.html', 'prod_id': '0721266003', 'color_string': 'Burgundy', 'color_hex': '#5B313D'}
# {'name': 'Padded bomber jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0797680003.html', 'prod_id': '0797680003', 'color_string': 'Rust brown', 'color_hex': '#7C4F3A'}
# {'name': 'Denim jacket', 'price': '£19.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721273009.html', 'prod_id': '0721273009', 'color_string': 'Mustard yellow', 'color_hex': '#BB8C3F'}
# {'name': 'Faux fur jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811640001.html', 'prod_id': '0811640001', 'color_string': 'Light beige', 'color_hex': '#D8D0CB'}
# {'name': 'H&M+ Long coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0796319001.html', 'prod_id': '0796319001', 'color_string': 'Rust red', 'color_hex': '#762229'}
# {'name': 'Pile coat', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0790006001.html', 'prod_id': '0790006001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Denim jacket', 'price': '£19.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721273001.html', 'prod_id': '0721273001', 'color_string': 'Denim blue', 'color_hex': '#79829D'}
# {'name': 'Pile sports jacket', 'price': '£29.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0797540001.html', 'prod_id': '0797540001', 'color_string': 'Light brown', 'color_hex': '#9E886B'}
# {'name': 'Faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0779414001.html', 'prod_id': '0779414001', 'color_string': 'Light beige', 'color_hex': '#DFD8C9'}
# {'name': 'Twill utility jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0729606002.html', 'prod_id': '0729606002', 'color_string': 'Light brown', 'color_hex': '#8C7256'}
# {'name': 'Short faux fur jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0811229003.html', 'prod_id': '0811229003', 'color_string': 'Old rose', 'color_hex': '#8E716E'}
# {'name': 'H&M+ Padded gilet', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0800304002.html', 'prod_id': '0800304002', 'color_string': 'Dark khaki green', 'color_hex': '#57564B'}
# {'name': 'Short cotton parka', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0809200002.html', 'prod_id': '0809200002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Faux fur jacket', 'price': '£69.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0837706001.html', 'prod_id': '0837706001', 'color_string': 'Beige', 'color_hex': '#B1A895'}
# {'name': 'Boxy puffer jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0721268002.html', 'prod_id': '0721268002', 'color_string': 'Light neon yellow', 'color_hex': '#E9E890'}
# {'name': 'Biker jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0782816002.html', 'prod_id': '0782816002', 'color_string': 'Light beige', 'color_hex': '#AE987E'}
# {'name': 'Denim jacket', 'price': '£29.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0399061026.html', 'prod_id': '0399061026', 'color_string': 'Denim blue', 'color_hex': '#54586D'}
# {'name': 'Pile-lined parka', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0826701001.html', 'prod_id': '0826701001', 'color_string': 'Rust brown', 'color_hex': '#9A594E'}
# {'name': 'H&M+ Coat with draped lapels', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0809887001.html', 'prod_id': '0809887001', 'color_string': 'Beige', 'color_hex': '#A5917C'}
# {'name': 'Wool-blend jacket', 'price': '£99.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0816313001.html', 'prod_id': '0816313001', 'color_string': 'Beige', 'color_hex': '#B79D85'}
# {'name': 'Double-breasted jacket', 'price': '£29.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0755360001.html', 'prod_id': '0755360001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0534181012.html', 'prod_id': '0534181012', 'color_string': 'Grey marl', 'color_hex': '#A5A5A5'}
# {'name': 'Short coat', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0781591001.html', 'prod_id': '0781591001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Hooded sports jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0696155002.html', 'prod_id': '0696155002', 'color_string': 'White', 'color_hex': '#ECEDEC'}
# {'name': 'Denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0767798001.html', 'prod_id': '0767798001', 'color_string': 'Light denim blue', 'color_hex': '#8898AC'}
# {'name': 'Hooded fleece jacket', 'price': '£24.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0678686001.html', 'prod_id': '0678686001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'H&M+ Coat with a tie belt', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0761937001.html', 'prod_id': '0761937001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Straight-style coat', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0836047001.html', 'prod_id': '0836047001', 'color_string': 'Light beige/Checked', 'color_hex': '#C7B9AB'}
# {'name': 'Fleece jacket', 'price': '£29.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0793443001.html', 'prod_id': '0793443001', 'color_string': 'Light beige', 'color_hex': '#D7CFBD'}
# {'name': 'Wool-blend coat', 'price': '£79.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0786751001.html', 'prod_id': '0786751001', 'color_string': 'Dark grey marl', 'color_hex': '#94989F'}
# {'name': 'Faux fur jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0788303001.html', 'prod_id': '0788303001', 'color_string': 'Greige', 'color_hex': '#D2C8BA'}
# {'name': 'Pile sports top', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0754275004.html', 'prod_id': '0754275004', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Padded parka with a hood', 'price': '£59.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0786202001.html', 'prod_id': '0786202001', 'color_string': 'Light beige', 'color_hex': '#B9B1AA'}
# {'name': 'Denim jacket', 'price': '£29.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0399061008.html', 'prod_id': '0399061008', 'color_string': 'Light denim blue', 'color_hex': '#8898AC'}
# {'name': 'Cotton twill jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0859708001.html', 'prod_id': '0859708001', 'color_string': 'Beige', 'color_hex': '#9C8B73'}
# {'name': 'Lightweight jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0784384003.html', 'prod_id': '0784384003', 'color_string': 'Powder pink/Patterned', 'color_hex': '#E8E4D5'}
# {'name': 'Lightweight jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0784384002.html', 'prod_id': '0784384002', 'color_string': 'Silver-coloured', 'color_hex': '#666B75'}
# {'name': 'Biker jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0698776002.html', 'prod_id': '0698776002', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Long denim jacket', 'price': '£39.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0831446001.html', 'prod_id': '0831446001', 'color_string': 'Denim blue', 'color_hex': '#767F99'}
# {'name': 'Boxy denim jacket', 'price': '£12.99', 'sale': True, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0779603002.html', 'prod_id': '0779603002', 'color_string': 'Light beige', 'color_hex': '#EFEFDF'}
# {'name': 'Reflective running gilet', 'price': '£12.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0703251001.html', 'prod_id': '0703251001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'H&M+ Biker jacket', 'price': '£49.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0805115001.html', 'prod_id': '0805115001', 'color_string': 'Black', 'color_hex': '#272628'}
# {'name': 'Oversized denim jacket', 'price': '£34.99', 'sale': False, 'sale_price': '', 'prod_url': 'https://www2.hm.com/en_gb/productpage.0687856003.html', 'prod_id': '0687856003', 'color_string': 'Light denim blue', 'color_hex': '#C8D0DB'}

# %%
type([1,2,4])
# Out:
# list

# %%
type({'a':1})
# Out:
# dict

# %%
prod_req = requests.get('https://www2.hm.com/en_gb/productpage.0837706001.html', headers=headers)

# %%
prod_doc = lxml.html.fromstring(prod_req.text)

# %%
formatted_text = prod_req.text.replace('"', '\'')

# %%
prod_id = '0837706001'

# %%
js_match = re.search('(?<=productArticleDetails\ =\ )[\s\S]*(?=\;)', formatted_text)
prod_match = re.search(f'(?<=\'{prod_id}\'\:\ )[\s\S]*(?=\,\n)', js_match.group(0))

# %%
prod_match.group(0)
# Out:
# "{\r\n            'name': 'Beige',\r\n            'inStore': false,\r\n            'energyClass': '',\r\n            'energyClassInterval': '',\r\n            'energyClassCode': '',\r\n            'energyClassIntervalCode': '',\r\n            'colorCode': '13',\r\n            'totalStyleWithArticles': '15',\r\n            'styleWithDefaultArticles':'0843752001,0814293010,0812484006,0822345001,0822958003,0866465001,0851062001,0859706001,0849544002,0858381003,0837448004,0849544001,0799365003,0853717001,0840024001',\r\n            'productsWithStyleWith':'0837706_group_001_en_gb,0843752_group_001_en_gb,0814293_group_010_en_gb,0812484_group_006_en_gb,0822345_group_001_en_gb,0822958_group_003_en_gb,0866465_group_001_en_gb,0851062_group_001_en_gb,0859706_group_001_en_gb,0849544_group_002_en_gb,0858381_group_003_en_gb,0837448_group_004_en_gb,0849544_group_001_en_gb,0799365_group_003_en_gb,0853717_group_001_en_gb,0840024_group_001_en_gb',\r\n            \r\n                    '0843752001':'dam',\r\n                \r\n                    '0814293010':'dam',\r\n                \r\n                    '0812484006':'dam',\r\n                \r\n                    '0822345001':'dam',\r\n                \r\n                    '0822958003':'manual',\r\n                \r\n                    '0866465001':'manual',\r\n                \r\n                    '0851062001':'manual',\r\n                \r\n                    '0859706001':'manual',\r\n                \r\n                    '0849544002':'manual',\r\n                \r\n                    '0858381003':'manual',\r\n                \r\n                    '0837448004':'manual',\r\n                \r\n                    '0849544001':'manual',\r\n                \r\n                    '0799365003':'manual',\r\n                \r\n                    '0853717001':'manual',\r\n                \r\n                    '0840024001':'manual',\r\n                \r\n                'selection': 'New Arrival',\r\n                \r\n            'description': 'Straight-cut jacket in long pile faux fur with cotton twill sections. Collar, press-studs down the front and a tab with press-studs at the hem. Lined.',\r\n            'images':[\r\n                \r\n                {\r\n                    'thumbnail': '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/thumb]',\r\n                    'image': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/main]' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilemain]',\r\n                    'fullscreen': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]',\r\n                    'zoom': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/zoom]&zoom=zoom' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]&zoom=zoom'\r\n                },\r\n                {\r\n                    'thumbnail': '//lp2.hm.com/hmgoepprod?s ...

# %%
images_string_match = re.search('(?<=\'images\'\:\[).*?(?=\]\,\r\n)', prod_match.group(0), re.I | re.DOTALL)

# %%
images_string_match.group(0)
# Out:
# "\r\n                \r\n                {\r\n                    'thumbnail': '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/thumb]',\r\n                    'image': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/main]' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilemain]',\r\n                    'fullscreen': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]',\r\n                    'zoom': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/zoom]&zoom=zoom' : '//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]&zoom=zoom'\r\n                },\r\n                {\r\n                    'thumbnail': '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/thumb]',\r\n                    'image': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/main]' : '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilemain]',\r\n                    'fullscreen': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]' : '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]',\r\n                    'zoom': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/zoom]&zoom=zoom' : '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/mobilefullscreen]&zoom=zoom'\r\n                },\r\n                {\r\n                    'thumbnail': '//lp2.hm.com/hmgoepprod?set=source[/6b/0e/6b0e86640b1a141b78b3c5155efff598bdac5ad2.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/thumb]',\r\n                    'image': isDesktop ? '//lp2.hm.com/hmgoepprod?set=source[/6b/0e/6b0e86640b1a141b78b3c5155efff598bdac5ad2.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/main]' : '//lp2.hm.com/hmgoepprod?set=source[/6b/0e/6b0e86640b1a141b78b3c5155efff598bdac5ad2.jpg],origin[dam],category[l ...

# %%
img_slug_match = re.findall('(?<=fullscreen\'\:\ isDesktop\ \?\ \').*?(?=\'\ \:)', images_string_match.group(0))

# %%
img_slug_match
# Out:
# ['//lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  '//lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  '//lp2.hm.com/hmgoepprod?set=source[/6b/0e/6b0e86640b1a141b78b3c5155efff598bdac5ad2.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  '//lp2.hm.com/hmgoepprod?set=source[/fa/d1/fad17e397aaae2fa8c4131291a0e06fac5dabddd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  '//lp2.hm.com/hmgoepprod?set=source[/08/61/08616591478693017c90d86f8aa6782bbd7695a1.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  '//lp2.hm.com/hmgoepprod?set=source[/ab/9e/ab9ef5c2b766288daddbbb4c10b80822f507d351.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[DESCRIPTIVEDETAIL],res[m],hmver[1]&call=url[file:/product/fullscreen]']

# %%
image_urls = [f'https:{img_slug}' for img_slug in img_slug_match]

# %%
image_urls
# Out:
# ['https://lp2.hm.com/hmgoepprod?set=source[/a4/4e/a44e9a57039139b6a3fe803fb6603d5767ae1f31.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  'https://lp2.hm.com/hmgoepprod?set=source[/42/4c/424c3f2f38c13c3752d8d280eab385729c3e47fd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  'https://lp2.hm.com/hmgoepprod?set=source[/6b/0e/6b0e86640b1a141b78b3c5155efff598bdac5ad2.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  'https://lp2.hm.com/hmgoepprod?set=source[/fa/d1/fad17e397aaae2fa8c4131291a0e06fac5dabddd.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[LOOKBOOK],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  'https://lp2.hm.com/hmgoepprod?set=source[/08/61/08616591478693017c90d86f8aa6782bbd7695a1.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&call=url[file:/product/fullscreen]',
#  'https://lp2.hm.com/hmgoepprod?set=source[/ab/9e/ab9ef5c2b766288daddbbb4c10b80822f507d351.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[DESCRIPTIVEDETAIL],res[m],hmver[1]&call=url[file:/product/fullscreen]']

# %% [markdown]
# ![](https://lp2.hm.com/hmgoepprod?set=source[/08/61/08616591478693017c90d86f8aa6782bbd7695a1.jpg],origin[dam],category[ladies_jacketscoats_jackets],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&call=url[file:/product/fullscreen])

# %%
sizes_match = re.search('(?<=\'sizes\'\:\[)[\s\S]*?(?=\]\,)', prod_match.group(0))
size_name_match = re.findall('(?<=\'name\'\:\ \')[\S]*?(?=\')', sizes_match.group(0))
sizes_stock = [{
    'stock': 'In stock',
    'size': size
} for size in size_name_match]
size_stock = sizes_stock

# %%
size_stock
# Out:
# [{'stock': 'In stock', 'size': 'XS'},
#  {'stock': 'In stock', 'size': 'S'},
#  {'stock': 'In stock', 'size': 'M'},
#  {'stock': 'In stock', 'size': 'L'},
#  {'stock': 'In stock', 'size': 'XL'},
#  {'stock': 'In stock', 'size': 'XS/P'},
#  {'stock': 'In stock', 'size': 'S/P'},
#  {'stock': 'In stock', 'size': 'M/P'},
#  {'stock': 'In stock', 'size': 'L/P'}]

# %%
description = prod_doc.xpath('.//p[contains(@class, "pdp-description-tex")]/text()')

# %%
description
# Out:
# ['Straight-cut jacket in long pile faux fur with cotton twill sections. Collar, press-studs down the front and a tab with press-studs at the hem. Lined.']
