# %%
import lxml.html
import requests
import re
import json
import random

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9,lv;q=0.8',
    'cache-control': 'no-cache',
    'cookie': 'fvgs_ml=mosaic; frsx=AAAAALZhWsZk02ljiSRiMe4HQv-HOE5K3fuNuHRSNeNxUIhZg808YlKMyq5B5fs6ATXMJDtkDwA1QQuhnSFhHDdqURXke9qv23n7tQ7e3rNAZGmx-Kw42LlxlrKiOI5z5ZwwidZpCEoKBDRNOkcqM_E=; Zalando-Client-Id=e05d7de4-47d5-4c92-9c94-fb4d8366f543; bm_sz=45E0CF7E5A3DEC84F8D257A26300950E~YAAQFd3dWF9YoT5vAQAA3629VgaNYlQGi2FegrE/TPqD1XWm5JRbm5rhUwbR3sV5xT+zKa709NGSfE4Tr5PA43woKv0h/i5Opo2ZL07zg3k7TMfC0BVXOZ+WtLvwdrAcJ8LTS1Rn81vCAOp7c2yuRhXcta9fZyhkqsF+7EDXIVXMbHy1ICQcOtBiWBR0CiylSyTi; ak_bmsc=02E54EE860C684EB5D0AAEF20DA8C7FB58DDDD15164D0000EDEA095E05F0B210~; _ga=GA1.3.333545424.1577708271; _ga=GA1.3.333545424.1577708271; _gid=GA1.3.599663451.1577708272; _gcl_au=1.1.1619036198.1577708272; sqt_cap=1577708271496; _gat_zalga=1; ncx=f; _derived_epik=dj0yJnU9UjdPajdyS3dvX0EzMktSV0Q4M0FKWWVIQnhqaDYtOEkmbj1yZnpGSTFBdVVsNWpWbUdDcGM5OGF3Jm09NyZ0PUFBQUFBRjRKNng0; _abck=AF74E2D14D67F222EA4ACBF9C403D4E4~-1~~-1~-1~-1',
    'pragma': 'no-cache',
    'referer': 'https://www.zalando.co.uk/',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

# %%
# shop = Field()
# name = Field()
# price = Field()
# prod_url = Field()
# prod_id = Field()
# image_urls = Field()
# image_hash = Field()
# sex = Field()
# sale = Field()
# saleprice = Field()
# color_string = Field()
# brand = Field()
# currency = Field()
# date = Field()
# description = Field()
# category = Field()
# size_stock = Field()
# in_stock = Field()

# %%
init_req_url = 'https://www.zalando.co.uk/api/catalog/articles?limit=84&offset=84&sort=popularity'
init_ajax_req = requests.get(init_req_url, headers=headers)
init_json_dict = json.loads(init_ajax_req.text)
page_count = init_json_dict['pagination']['page_count']

# %%
page_count
# Out:
# 892

# %%
inner_api_url = f'https://www.zalando.co.uk/api/catalog/articles?limit=84&offset=84&sort=popularity'

# %%
inner_ajax_req = requests.get(inner_api_url, headers=headers)

# %%
inner_json_dict = json.loads(inner_ajax_req.text)
item_array = inner_json_dict['articles']

# %%
item_array
# Out:
# [{'sku': 'TOL21A002-Q11',
#   'name': 'TREGGINGS WITH TAPE - Leggings - Trousers - black',
#   'price': {'original': '£43.99',
#    'promotional': '£28.59',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['20', '22', '24', '26', '28'],
#   'url_key': 'my-true-me-tom-tailor-treggings-with-tape-leggings-trousers-black-tol21a002-q11',
#   'media': [{'path': 'TO/L2/1A/00/2Q/11/TOL21A002-Q11@4.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/L2/1A/00/2Q/11/TOL21A002-Q11@7.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'MY TRUE ME TOM TAILOR',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-35%',
#     'tracking_value': 'discount rate'},
#    {'key': 'assortmentArea',
#     'value': 'Plus size',
#     'tracking_value': 'plus size'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'LE222O050-K11',
#   'name': '2 HORSE GRAPHIC TEE - Print T-shirt - dress blues',
#   'price': {'original': '£29.99',
#    'promotional': '£15.00',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL'],
#   'url_key': 'levisr-2-horse-graphic-tee-print-t-shirt-dress-blues-le222o050-k11',
#   'media': [{'path': 'LE/22/2O/05/0K/11/LE222O050-K11@15.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'LE/22/2O/05/0K/11/LE222O050-K11@12.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'S2315O000-K16',
#   'name': 'JAZZ ORIGINAL VINTAGE - Trainers - blue/black',
#   'price': {'original': '£84.99',
#    'promotional': '£50.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '9.5',
#    '11'],
#   'url_key': 'saucony-jazz-original-vintage-trainers-s2315o000-k16',
#   'media': [{'path': 'S2/31/5O/00/0K/16/S2315O000-K16@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'Saucony',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'RI922A037-C11',
#   'name': 'Suit trousers - charcoal',
#   'price': {'original': '£39.99',
#    'promotional': '£23.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['28x30',
#    '28x32',
#    '30x30',
#    '30x32',
#    '32x30',
#    '32x32',
#    '32x34',
#    '34x32',
#    '34x34',
#    '36x32',
#    '36x34'],
#   'url_key': 'river-island-suit-trousers-charcoal-ri922a037-c11',
#   'media': [{'path': 'RI/92/2A/03/7C/11/RI922A037-C11@8.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'RI/92/2A/03/7C/11/RI922A037-C11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'River Island',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'N1241E0PE-Q11',
#   'name': 'ONE - Leggings - black/white',
#   'price': {'original': '£34.99',
#    'promotional': '£34.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#   'url_key': 'nike-performance-all-in-leggings-blackwhite-n1241e0pe-q11',
#   'media': [{'path': 'N1/24/1E/0P/EQ/11/N1241E0PE-Q11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'N1/24/1E/0P/EQ/11/N1241E0PE-Q11@3.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Nike Performance',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'VA211A06P-Q11',
#   'name': 'CLASSIC PLATFORM - Slip-ons - black',
#   'price': {'original': '£54.99',
#    'promotional': '£38.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5', '4', '4.5', '5', '6', '6.5', '7.5', '8'],
#   'url_key': 'vans-classic-platform-trainers-black-va211a06p-q11',
#   'media': [{'path': 'VA/21/1A/06/PQ/11/VA211A06P-Q11@13.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Vans',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'RE011A0AV-T11',
#   'name': 'AZTREK ADVENTURE - Trainers - buff/grey/emerald',
#   'price': {'original': '£69.99',
#    'promotional': '£41.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5', '4', '4.5', '5', '5.5', '6', '6.5', '7', '7.5', '8'],
#   'url_key': 'reebok-classic-aztrek-adventure-trainers-buffgreyemerald-re011a0av-t11',
#   'media': [{'path': 'RE/01/1A/0A/VT/11/RE011A0AV-T11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Reebok Classic',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'campaign',
#     'value': 'HOT DROP',
#     'tracking_value': 'mu_sneaker_releases'},
#    {'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'DO216I00V-Q11',
#   'name': '1460 PASCAL MONO JUNIOR - Classic ankle boots - black',
#   'price': {'original': '£64.99',
#    'promotional': '£51.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['1', '2', '10K', '11K', '12K', '13K', '11.5K'],
#   'url_key': 'dr-martens-1460-pascal-mono-junior-classic-ankle-boots-black-do216i00v-q11',
#   'media': [{'path': 'DO/21/6I/00/VQ/11/DO216I00V-Q11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Dr. Martens',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-20%',
#     'tracking_value': 'discount rate'},
#    {'key': 'csr', 'value': 'Sustainability', 'tracking_value': 'sustainable'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'HY524K00S-Q11',
#   'name': 'TAPED HOODIE - Zip-up hoodie - black',
#   'price': {'original': '£41.99',
#    'promotional': '£35.69',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['5-6y', '7-8y', '9-10y', '11-12y', '13y'],
#   'url_key': 'hype-taped-hoodie-zip-up-hoodie-black-hy524k00s-q11',
#   'media': [{'path': 'HY/52/4K/00/SQ/11/HY524K00S-Q11@2.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Hype',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-15%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'TO122T04J-Q11',
#   'name': 'HEAVY BOMBER - Winter jacket - black',
#   'price': {'original': '£314.99',
#    'promotional': '£314.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#   'url_key': 'tommy-hilfiger-heavy-bomber-winter-jacket-black-to122t04j-q11',
#   'media': [{'path': 'TO/12/2T/04/JQ/11/TO122T04J-Q11@12.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/12/2T/04/JQ/11/TO122T04J-Q11@3.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'NI114F008-Q11',
#   'name': 'HUARACHE RUN ULTRA  - Baby shoes - black',
#   'price': {'original': '£42.99',
#    'promotional': '£30.09',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['5.5K', '6.5K', '7.5K', '8.5K', '9.5K'],
#   'url_key': 'nike-sportswear-huarache-run-ultra-trainers-ni114f008-q11',
#   'media': [{'path': 'NI/11/4F/00/8Q/11/NI114F008-Q11@7.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'SC322E037-K11',
#   'name': 'STUART CLASSIC - Chinos - night',
#   'price': {'original': '£119.99',
#    'promotional': '£119.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['28x32',
#    '29x30',
#    '29x32',
#    '29x34',
#    '30x30',
#    '30x32',
#    '30x34',
#    '31x30',
#    '31x32',
#    '31x34',
#    '31x36',
#    '32x30',
#    '32x32',
#    '32x34',
#    '32x36',
#    '33x30',
#    '33x32',
#    '33x34',
#    '34x30',
#    '34x32',
#    '34x34',
#    '34x36',
#    '36x30',
#    '36x32',
#    '36x34',
#    '36x36',
#    '38x34',
#    '38x36'],
#   'url_key': 'scotch-and-soda-stuart-classic-chinos-sc322e037-k11',
#   'media': [{'path': 'SC/32/2E/03/7K/11/SC322E037-K11@14.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'SC/32/2E/03/7K/11/SC322E037-K11@15.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Scotch & Soda',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'LE221D05V-A11',
#   'name': 'TEE 2 PACK - Basic T-shirt - white',
#   'price': {'original': '£29.99',
#    'promotional': '£17.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M'],
#   'url_key': 'levisr-2-pack-tee-basic-t-shirt-white-le221d05v-a11',
#   'media': [{'path': 'LE/22/1D/05/VA/11/LE221D05V-A11@7.png',
#     'role': 'DEFAULT',
#     'packet_shot': True},
#    {'path': 'LE/22/1D/05/VA/11/LE221D05V-A11@10.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': '5VA51H0A5-K11',
#   'name': 'OBOE - Across body bag - blue',
#   'price': {'original': '£54.99',
#    'promotional': '£38.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'valentino-by-mario-valentino-oboe-across-body-bag-5va51h0a5-k11',
#   'media': [{'path': '5V/A5/1H/0A/5K/11/5VA51H0A5-K11@13.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': '5V/A5/1H/0A/5K/11/5VA51H0A5-K11@12.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Valentino by Mario Valentino',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'A0112C024-Q11',
#   'name': 'LEGADOSEN - Slip-ons - black',
#   'price': {'original': '£89.99',
#    'promotional': '£45.00',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['7', '8', '9', '10', '11', '12'],
#   'url_key': 'aldo-legadosen-slip-ons-a0112c024-q11',
#   'media': [{'path': 'A0/11/2C/02/4Q/11/A0112C024-Q11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'ALDO',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'MK151H0E6-O11',
#   'name': 'POUCHES CHAIN POUCHETTE - Clutch - brown',
#   'price': {'original': '£74.99',
#    'promotional': '£74.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'michael-michael-kors-clutch-brown-mk151h0e6-o11',
#   'media': [{'path': 'MK/15/1H/0E/6O/11/MK151H0E6-O11@16.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'MK/15/1H/0E/6O/11/MK151H0E6-O11@10.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'MICHAEL Michael Kors',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'SK113D08A-A11',
#   'name': "D'LITES - Trainers - white/silver",
#   'price': {'original': '£41.99',
#    'promotional': '£41.99',
#    'has_different_prices': True,
#    'has_different_original_prices': True,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['1.5',
#    '2',
#    '3',
#    '4',
#    '5',
#    '10K',
#    '11K',
#    '12K',
#    '13K',
#    '11.5K',
#    '12.5K',
#    '13.5K'],
#   'url_key': 'skechers-dlites-trainers-whitesilver-sk113d08a-a11',
#   'media': [{'path': 'SK/11/3D/08/AA/11/SK113D08A-A11@8.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'Skechers',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'GU124G03M-A11',
#   'name': 'Print T-shirt - true white',
#   'price': {'original': '£14.99',
#    'promotional': '£10.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['7y', '8y', '10y', '12y', '14y', '16y'],
#   'url_key': 'guess-core-print-t-shirt-gu124g03m-a11',
#   'media': [{'path': 'GU/12/4G/03/MA/11/GU124G03M-A11@6.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'Guess',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'LE226G00A-A11',
#   'name': 'BATWING TEE - Long sleeved top - white',
#   'price': {'original': '£25.99',
#    'promotional': '£16.89',
#    'has_different_prices': True,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': True,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['4y', '5y', '6y', '8y', '10y', '12y', '14y', '16y'],
#   'url_key': 'levisr-batwing-tee-long-sleeved-top-le226g00a-a11',
#   'media': [{'path': 'LE/22/6G/00/AA/11/LE226G00A-A11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-35%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'M9121C3RF-J11',
#   'name': 'LACY - Day dress - pink',
#   'price': {'original': '£49.99',
#    'promotional': '£29.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#   'url_key': 'mango-lacy-day-dress-pink-m9121c3rf-j11',
#   'media': [{'path': 'M9/12/1C/3R/FJ/11/M9121C3RF-J11@15.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'M9/12/1C/3R/FJ/11/M9121C3RF-J11@14.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Mango',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'OS322O0T1-Q11',
#   'name': 'ONSMSTEFAN  TEE - Print T-shirt - black',
#   'price': {'original': '£12.99',
#    'promotional': '£7.14',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL'],
#   'url_key': 'only-and-sons-onsmstefan-tee-print-t-shirt-os322o0t1-q11',
#   'media': [{'path': 'OS/32/2O/0T/1Q/11/OS322O0T1-Q11@8.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'OS/32/2O/0T/1Q/11/OS322O0T1-Q11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Only & Sons',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-45%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': '2HE51L00F-A11',
#   'name': 'Ring - silver-coloured',
#   'price': {'original': '£60.03',
#    'promotional': '£30.44',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': [],
#   'url_key': 'heideman-mit-swarovski-stein-ring-silver-coloured-2he51l00f-a11',
#   'media': [{'path': '2H/E5/1L/00/FA/11/2HE51L00F-A11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Heideman',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-49%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'LE221D072-G11',
#   'name': 'GRAPHIC VARSITY TEE - Basic T-shirt - tonal baby tab brilliant red',
#   'price': {'original': '£29.99',
#    'promotional': '£17.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XXS', 'XS', 'S', 'M', 'L'],
#   'url_key': 'levisr-graphic-varsity-tee-basic-t-shirt-le221d072-g11',
#   'media': [{'path': 'LE/22/1D/07/2G/11/LE221D072-G11@14.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'LE/22/1D/07/2G/11/LE221D072-G11@15.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'NI111A0GV-A11',
#   'name': 'INTERNATIONALIST - Trainers - summit white/metallic silver',
#   'price': {'original': '£74.99',
#    'promotional': '£44.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2.5',
#    '3',
#    '3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '8.5'],
#   'url_key': 'nike-sportswear-internationalist-trainers-summit-whitemetallic-silver-ni111a0gv-a11',
#   'media': [{'path': 'NI/11/1A/0G/VA/11/NI111A0GV-A11@11.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': '6CA51H0CZ-Q11',
#   'name': 'RAPID URBAN XBODY - Bum bag - black',
#   'price': {'original': '£74.99',
#    'promotional': '£37.50',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'calvin-klein-rapid-urban-xbody-bum-bag-black-6ca51h0cz-q11',
#   'media': [{'path': '6C/A5/1H/0C/ZQ/11/6CA51H0CZ-Q11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': '6C/A5/1H/0C/ZQ/11/6CA51H0CZ-Q11@12.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Calvin Klein',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'LE221D05G-A12',
#   'name': 'THE PERFECT TEE - Print T-shirt - white/red',
#   'price': {'original': '£19.99',
#    'promotional': '£14.39',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XXS', 'XS', 'S', 'M', 'L'],
#   'url_key': 'levisr-the-perfect-tee-print-t-shirt-le221d05g-a12',
#   'media': [{'path': 'LE/22/1D/05/GA/12/LE221D05G-A12@10.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'LE/22/1D/05/GA/12/LE221D05G-A12@11.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-28%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'PI911N02F-C12',
#   'name': 'Classic ankle boots - grey',
#   'price': {'original': '£69.99',
#    'promotional': '£59.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5', '4', '5', '5.5', '6.5', '7.5', '8'],
#   'url_key': 'pier-one-boots-grey-pi911n02f-c12',
#   'media': [{'path': 'PI/91/1N/02/FC/12/PI911N02F-C12@13.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Pier One',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-15%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'SU222T0DA-Q11',
#   'name': 'ULTIMATE RADAR QUILT PUFFER - Winter jacket - black',
#   'price': {'original': '£99.99',
#    'promotional': '£69.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#   'url_key': 'superdry-ultimate-radar-quilt-puffer-winter-jacket-black-su222t0da-q11',
#   'media': [{'path': 'SU/22/2T/0D/AQ/11/SU222T0DA-Q11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'SU/22/2T/0D/AQ/11/SU222T0DA-Q11@10.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Superdry',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': '5VA51H03S-Q11',
#   'name': 'DIVINA  - Across body bag - nero',
#   'price': {'original': '£54.99',
#    'promotional': '£54.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'valentino-by-mario-valentino-divina-across-body-bag-5va51h03s-q11',
#   'media': [{'path': '5V/A5/1H/03/SQ/11/5VA51H03S-Q11@15.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': '5V/A5/1H/03/SQ/11/5VA51H03S-Q11@4.2.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Valentino by Mario Valentino',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'ALK22T008-N11',
#   'name': 'OSHAWA PADDED - Winter jacket - khaki',
#   'price': {'original': '£119.99',
#    'promotional': '£89.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#   'url_key': 'alessandro-zavetti-oshawa-padded-parka-khaki-alk22t008-n11',
#   'media': [{'path': 'AL/K2/2T/00/8N/11/ALK22T008-N11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'AL/K2/2T/00/8N/11/ALK22T008-N11@15.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Alessandro Zavetti',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-25%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'JU121N009-K11',
#   'name': 'ANGELINA TROUSERS - Flared Jeans - blue denim',
#   'price': {'original': '£94.99',
#    'promotional': '£56.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['25', '26', '27', '28', '29', '30'],
#   'url_key': 'just-female-angelina-trousers-flared-jeans-blue-denim-ju121n009-k11',
#   'media': [{'path': 'JU/12/1N/00/9K/11/JU121N009-K11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'JU/12/1N/00/9K/11/JU121N009-K11@12.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'JUST FEMALE',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'HY526G00B-J11',
#   'name': 'KIDS SPECKLE FADE - Print T-shirt - pink/white',
#   'price': {'original': '£18.99',
#    'promotional': '£15.19',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3-4y', '5-6y', '7-8y', '9-10y', '11-12y', '13y'],
#   'url_key': 'hype-kids-speckle-fade-print-t-shirt-pinkwhite-hy526g00b-j11',
#   'media': [{'path': 'HY/52/6G/00/BJ/11/HY526G00B-J11@6.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Hype',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-20%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'ROP14D001-K11',
#   'name': 'INVADER - Trainers - navy/light grey',
#   'price': {'original': '£54.99',
#    'promotional': '£32.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['1.5',
#    '2.5',
#    '3.5',
#    '4',
#    '6',
#    '6.5',
#    '10K',
#    '11K',
#    '12K',
#    '11.5K'],
#   'url_key': 'rooskickx-invader-trainers-navylight-grey-rop14d001-k11',
#   'media': [{'path': 'RO/P1/4D/00/1K/11/ROP14D001-K11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Rooskickx',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'SU111A01U-A12',
#   'name': 'COTU - Trainers - white',
#   'price': {'original': '£64.99',
#    'promotional': '£48.74',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['4', '5', '5.5', '6.5', '7', '8'],
#   'url_key': 'superga-2730-trainers-su111a01u-a12',
#   'media': [{'path': 'SU/11/1A/01/UA/12/SU111A01U-A12@3.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Superga',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-25%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'TO152L02H-D11',
#   'name': 'DRESSED UP LOGO - Ring - silver-coloured',
#   'price': {'original': '£33.99',
#    'promotional': '£33.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': [],
#   'url_key': 'tommy-hilfiger-dressed-up-logo-ring-silver-coloured-to152l02h-d11',
#   'media': [{'path': 'TO/15/2L/02/HD/11/TO152L02H-D11@2.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'new', 'value': 'New', 'tracking_value': 'new'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': '1FI11A00U-A12',
#   'name': 'D FORMATION - Trainers - white/navy/red',
#   'price': {'original': '£104.99',
#    'promotional': '£62.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['4', '5', '6', '7', '8', '9'],
#   'url_key': 'fila-formation-trainers-1fi11a00u-a12',
#   'media': [{'path': '1F/I1/1A/00/UA/12/1FI11A00U-A12@3.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Fila',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'outfits': [{'id': 'NjbvO20ZQTa',
#     'url_key': '/outfits/NjbvO20ZQTa',
#     'media': [{'path': '6c21a3e385694dbc83bc6e40f5855cc2/0b3fb016e2034262b053367005ea7aec.jpeg',
#       'outline_reference': 'outfit_image'}],
#     'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#     'gender': 'unisex',
#     'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#      'name': 'Styled by Zalando',
#      'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#        'outline_reference': 'creator_image'}]},
#     'items': [{'id': 'GIE31G003-S14'},
#      {'id': 'EV421C0XZ-Q11'},
#      {'id': '1FI11A00U-A12'},
#      {'id': 'LIW51L050-T11'},
#      {'id': '1FI810002-A11'}]}],
#   'delivery_promises': []},
#  {'sku': 'CR221G022-M11',
#   'name': 'ANETT - Blazer - sea green',
#   'price': {'original': '£64.99',
#    'promotional': '£38.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XXL'],
#   'url_key': 'cream-anett-blazer-cr221g022-m11',
#   'media': [{'path': 'CR/22/1G/02/2M/11/CR221G022-M11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'CR/22/1G/02/2M/11/CR221G022-M11@6.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Cream',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'NI111A0GJ-Q13',
#   'name': 'SHOX ENIGMA 9000 - Trainers - black/gym red',
#   'price': {'original': '£114.99',
#    'promotional': '£80.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2.5',
#    '3',
#    '3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '8.5'],
#   'url_key': 'nike-sportswear-shox-enigma-9000-trainers-ni111a0gj-q13',
#   'media': [{'path': 'NI/11/1A/0G/JQ/13/NI111A0GJ-Q13@27.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'PO252O00D-C11',
#   'name': 'Beanie - fawn grey heather',
#   'price': {'original': '£43.99',
#    'promotional': '£35.19',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'polo-ralph-lauren-beanie-fawn-grey-heather-po252o00d-c11',
#   'media': [{'path': 'PO/25/2O/00/DC/11/PO252O00D-C11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'PO/25/2O/00/DC/11/PO252O00D-C11@7.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Polo Ralph Lauren',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-20%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'KIE22T007-Q11',
#   'name': 'FROST - Winter coat - jet black',
#   'price': {'original': '£99.99',
#    'promotional': '£74.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL'],
#   'url_key': 'kings-will-dream-frost-winter-coat-jet-black-kie22t007-q11',
#   'media': [{'path': 'KI/E2/2T/00/7Q/11/KIE22T007-Q11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'KI/E2/2T/00/7Q/11/KIE22T007-Q11@3.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Kings Will Dream',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-25%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'RE011S06G-A11',
#   'name': 'CLUB C 85 - Trainers - white/light grey',
#   'price': {'original': '£64.99',
#    'promotional': '£48.74',
#    'has_different_prices': True,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': True,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2.5',
#    '3',
#    '3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '8.5'],
#   'url_key': 'reebok-classic-club-c-85-trainers-re011s06g-a11',
#   'media': [{'path': 'RE/01/1S/06/GA/11/RE011S06G-A11@13.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Reebok Classic',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': 'up to -25%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'TO152D04D-Q11',
#   'name': 'NEW ALY BELT - Belt business - black',
#   'price': {'original': '£34.99',
#    'promotional': '£34.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['32', '34', '36', '38', '40', '44'],
#   'url_key': 'tommy-hilfiger-new-aly-belt-black-to152d04d-q11',
#   'media': [{'path': 'TO/15/2D/04/DQ/11/TO152D04D-Q11@15.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/15/2D/04/DQ/11/TO152D04D-Q11@12.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'PO222H016-K13',
#   'name': 'ANORAK JACKET - Summer jacket - aviator navy',
#   'price': {'original': '£154.99',
#    'promotional': '£108.49',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL'],
#   'url_key': 'polo-ralph-lauren-anorak-jacket-summer-jacket-aviator-navy-po222h016-k13',
#   'media': [{'path': 'PO/22/2H/01/6K/13/PO222H016-K13@4.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'PO/22/2H/01/6K/13/PO222H016-K13@6.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Polo Ralph Lauren',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'TO152D061-Q11',
#   'name': 'NEW DENTON - Belt business - black',
#   'price': {'original': '£34.99',
#    'promotional': '£34.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#   'url_key': 'tommy-hilfiger-new-denton-belt-business-to152d061-q11',
#   'media': [{'path': 'TO/15/2D/06/1Q/11/TO152D061-Q11@18.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/15/2D/06/1Q/11/TO152D061-Q11@14.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'NI122S0CG-C11',
#   'name': 'HOODIE  - Hoodie - dark grey heather',
#   'price': {'original': '£49.99',
#    'promotional': '£49.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#   'url_key': 'nike-sportswear-hoodie-sweatshirt-ni122s0cg-c11',
#   'media': [{'path': 'NI/12/2S/0C/GC/11/NI122S0CG-C11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'NI/12/2S/0C/GC/11/NI122S0CG-C11@8.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'new', 'value': 'New', 'tracking_value': 'new'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'K0551L04H-F11',
#   'name': 'LOVES ME KNOT LOVES ME KNOT STUDS - Earrings - gold-coloured',
#   'price': {'original': '£47.99',
#    'promotional': '£26.39',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'kate-spade-new-york-loves-me-knot-loves-me-knot-studs-earrings-gold-coloured-k0551l04h-f11',
#   'media': [{'path': 'K0/55/1L/04/HF/11/K0551L04H-F11@6.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'K0/55/1L/04/HF/11/K0551L04H-F11@3.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'kate spade new york',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-45%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'SUU15G000-Q11',
#   'name': 'Clogs - black',
#   'price': {'original': '£42.99',
#    'promotional': '£30.09',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['5.5-6', '6.5-7', '7.5-8', '8.5-9', '9.5-10'],
#   'url_key': 'subu-mules-black-suu15g000-q11',
#   'media': [{'path': 'SU/U1/5G/00/0Q/11/SUU15G000-Q11@8.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'SUBU',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'LE221D07G-T11',
#   'name': 'GRAPHIC VARSITY TEE - Print T-shirt - multicolor',
#   'price': {'original': '£29.99',
#    'promotional': '£17.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M'],
#   'url_key': 'levisr-graphic-varsity-tee-print-t-shirt-multicolor-le221d07g-t11',
#   'media': [{'path': 'LE/22/1D/07/GT/11/LE221D07G-T11@17.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'LE/22/1D/07/GT/11/LE221D07G-T11@19.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'A0F22O04G-E11',
#   'name': 'POP ICON CREW - Basic T-shirt - popcorn with mood indigo',
#   'price': {'original': '£20.99',
#    'promotional': '£10.50',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'L', 'XL', 'XXL'],
#   'url_key': 'abercrombie-and-fitch-pop-icon-crew-print-t-shirt-a0f22o04g-e11',
#   'media': [{'path': 'A0/F2/2O/04/GE/11/A0F22O04G-E11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'A0/F2/2O/04/GE/11/A0F22O04G-E11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Abercrombie & Fitch',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'GS121J06Z-M11',
#   'name': 'EARTH BEETLE R SW WMN L\\S - Sweatshirt - faded balsam',
#   'price': {'original': '£94.99',
#    'promotional': '£52.24',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#   'url_key': 'g-star-earth-beetle-r-sw-wmn-ls-sweatshirt-faded-balsam-gs121j06z-m11',
#   'media': [{'path': 'GS/12/1J/06/ZM/11/GS121J06Z-M11@17.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'GS/12/1J/06/ZM/11/GS121J06Z-M11@13.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'G-Star',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-45%',
#     'tracking_value': 'discount rate'},
#    {'key': 'csr', 'value': 'Sustainability', 'tracking_value': 'sustainable'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': '5VA51H03S-G11',
#   'name': 'DIVINA  - Across body bag - rosso',
#   'price': {'original': '£54.99',
#    'promotional': '£43.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'valentino-by-mario-valentino-divina-across-body-bag-rosso-5va51h03s-g11',
#   'media': [{'path': '5V/A5/1H/03/SG/11/5VA51H03S-G11@11.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': '5V/A5/1H/03/SG/11/5VA51H03S-G11@10.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Valentino by Mario Valentino',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-20%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'TO151H0PS-Q11',
#   'name': 'HONEY BELT BAG - Bum bag - black',
#   'price': {'original': '£104.99',
#    'promotional': '£62.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'tommy-hilfiger-honey-belt-bag-bum-bag-black-to151h0ps-q11',
#   'media': [{'path': 'TO/15/1H/0P/SQ/11/TO151H0PS-Q11@3.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/15/1H/0P/SQ/11/TO151H0PS-Q11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'TO151H0OT-T11',
#   'name': 'SMOOTH CROSSOVER - Across body bag - multi',
#   'price': {'original': '£104.99',
#    'promotional': '£62.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'tommy-hilfiger-smooth-crossover-across-body-bag-multi-to151h0ot-t11',
#   'media': [{'path': 'TO/15/1H/0O/TT/11/TO151H0OT-T11@10.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/15/1H/0O/TT/11/TO151H0OT-T11@12.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'FI922S004-Q11',
#   'name': 'LOGO - Sweatshirt - black',
#   'price': {'original': '£129.99',
#    'promotional': '£77.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'XL'],
#   'url_key': 'fiorucci-logo-sweatshirt-black-fi922s004-q11',
#   'media': [{'path': 'FI/92/2S/00/4Q/11/FI922S004-Q11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'FI/92/2S/00/4Q/11/FI922S004-Q11@3.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Fiorucci',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'AD115O0IN-Q11',
#   'name': 'COAST STAR - Trainers - core black/collegiate royal/scarlet',
#   'price': {'original': '£69.99',
#    'promotional': '£35.00',
#    'has_different_prices': True,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': True,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '8.5',
#    '9',
#    '9.5',
#    '10',
#    '10.5',
#    '11',
#    '11.5',
#    '12',
#    '12.5'],
#   'url_key': 'adidas-originals-coast-star-trainers-core-blackcollegiate-royalscarlet-ad115o0in-q11',
#   'media': [{'path': 'AD/11/5O/0I/NQ/11/AD115O0IN-Q11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'adidas Originals',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': 'up to -50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'NA824A0ES-K11',
#   'name': 'NITCLASSIC - Slim fit jeans - dark blue denim',
#   'price': {'original': '£23.00',
#    'promotional': '£23.00',
#    'has_different_prices': True,
#    'has_different_original_prices': True,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2y',
#    '3y',
#    '4y',
#    '5y',
#    '6y',
#    '7y',
#    '8y',
#    '9y',
#    '10y',
#    '11y',
#    '12y',
#    '13y',
#    '14y'],
# ...
#  {'sku': 'AN651G04L-C12',
#   'name': 'Cape - grey/silver',
#   'price': {'original': '£25.99',
#    'promotional': '£13.00',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'anna-field-cape-greysilver-an651g04l-c12',
#   'media': [{'path': 'AN/65/1G/04/LC/12/AN651G04L-C12@12.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'AN/65/1G/04/LC/12/AN651G04L-C12@13.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Anna Field',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'M9121G0QT-M11',
#   'name': 'PERFECT - Leather jacket - dark green',
#   'price': {'original': '£119.99',
#    'promotional': '£83.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L'],
#   'url_key': 'mango-perfect-leather-jacket-m9121g0qt-m11',
#   'media': [{'path': 'M9/12/1G/0Q/TM/11/M9121G0QT-M11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'M9/12/1G/0Q/TM/11/M9121G0QT-M11@11.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Mango',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'LE226G005-A11',
#   'name': 'BATWING TEE - Print T-shirt - white',
#   'price': {'original': '£13.99',
#    'promotional': '£13.99',
#    'has_different_prices': True,
#    'has_different_original_prices': True,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3y', '4y', '5y', '6y', '8y', '10y', '12y', '14y', '16y'],
#   'url_key': 'levisr-print-t-shirt-white-le226g005-a11',
#   'media': [{'path': 'LE/22/6G/00/5A/11/LE226G005-A11@2.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': "Levi's®",
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'M4511X008-D11',
#   'name': 'Winter boots - silver',
#   'price': {'original': '£74.99',
#    'promotional': '£63.74',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2.5-5', '6-7.5', '8-9.5'],
#   'url_key': 'moon-boot-winter-boots-silver-m4511x008-d11',
#   'media': [{'path': 'M4/51/1X/00/8D/11/M4511X008-D11@15.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'Moon Boot',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-15%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'outfits': [{'id': 'JOD4kpurQqS',
#     'url_key': '/outfits/JOD4kpurQqS',
#     'media': [{'path': '1df7afe9bab14a44933f75de7a599925/fd10ccccfb0948c38de185fb5d6e031f.jpeg',
#       'outline_reference': 'outfit_image'}],
#     'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#     'gender': 'unisex',
#     'creator': {'id': '9bdd4942-b149-4915-9a62-a938b3307a0a',
#      'name': 'fashionindividual',
#      'media': [{'path': '5d36c93886dc4e398ba1cf70e0e78b66/4177515ed286486a8fc67e5ca80cd01e.jpeg',
#        'outline_reference': 'creator_image'}]},
#     'items': [{'id': 'WEB21U01H-N11'},
#      {'id': 'VE121D19Q-M11'},
#      {'id': 'WEB21A034-N11'},
#      {'id': 'M4511X008-D11'},
#      {'id': 'SA351B000-M13'}]}],
#   'delivery_promises': []},
#  {'sku': 'LE421N05Z-K11',
#   'name': 'CAROL - Straight leg jeans - dark garner',
#   'price': {'original': '£90.00',
#    'promotional': '£45.00',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['25x31',
#    '25x33',
#    '26x31',
#    '27x31',
#    '27x33',
#    '28x31',
#    '28x33',
#    '28x35',
#    '29x31',
#    '29x33',
#    '29x35',
#    '30x35',
#    '32x33',
#    '33x33',
#    '34x33'],
#   'url_key': 'lee-carol-straight-leg-jeans-dark-garner-le421n05z-k11',
#   'media': [{'path': 'LE/42/1N/05/ZK/11/LE421N05Z-K11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'LE/42/1N/05/ZK/11/LE421N05Z-K11@10.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Lee',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-50%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'TO151Q01P-Q11',
#   'name': 'POPPY BACKPACK - Rucksack - black',
#   'price': {'original': '£79.99',
#    'promotional': '£55.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'tommy-hilfiger-poppy-backpack-rucksack-black-to151q01p-q11',
#   'media': [{'path': 'TO/15/1Q/01/PQ/11/TO151Q01P-Q11@11.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/15/1Q/01/PQ/11/TO151Q01P-Q11@10.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'THA52H006-Q11',
#   'name': 'SAC EPAULE - Across body bag - black',
#   'price': {'original': '£84.99',
#    'promotional': '£53.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'the-kooples-sac-epaule-across-body-bag-black-tha52h006-q11',
#   'media': [{'path': 'TH/A5/2H/00/6Q/11/THA52H006-Q11@14.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TH/A5/2H/00/6Q/11/THA52H006-Q11@8.1.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'The Kooples',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-36%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []},
#  {'sku': 'NI112O08O-Q11',
#   'name': 'AIR VAPORMAX FLYKNIT - Trainers - black/anthracite/white/metallic silver',
#   'price': {'original': '£169.99',
#    'promotional': '£169.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['5.5',
#    '6',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '10',
#    '11',
#    '11.5',
#    '12',
#    '14'],
#   'url_key': 'nike-sportswear-air-vapormax-flyknit-3-trainers-ni112o08o-q11',
#   'media': [{'path': 'NI/11/2O/08/OQ/11/NI112O08O-Q11@4.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'AF822D003-A11',
#   'name': 'Shirt - weiß',
#   'price': {'original': '£59.99',
#    'promotional': '£35.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#   'url_key': 'a-fish-named-fred-shirt-weiss-af822d003-a11',
#   'media': [{'path': 'AF/82/2D/00/3A/11/AF822D003-A11@4.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'AF/82/2D/00/3A/11/AF822D003-A11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'A fish named fred',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-40%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'TO122O02W-Q11',
#   'name': 'NEW STRETCH TEE C-NECK - Basic T-shirt - flag black',
#   'price': {'original': '£25.99',
#    'promotional': '£25.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#   'url_key': 'tommy-hilfiger-slim-fit-basic-t-shirt-flag-black-to122o02w-q11',
#   'media': [{'path': 'TO/12/2O/02/WQ/11/TO122O02W-Q11@10.2.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/12/2O/02/WQ/11/TO122O02W-Q11@11.2.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'TO122O02W-K11',
#   'name': 'NEW STRETCH TEE C-NECK - Basic T-shirt - navy blazer',
#   'price': {'original': '£25.99',
#    'promotional': '£25.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#   'url_key': 'tommy-hilfiger-basic-t-shirt-navy-blazer-to122o02w-k11',
#   'media': [{'path': 'TO/12/2O/02/WK/11/TO122O02W-K11@10.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TO/12/2O/02/WK/11/TO122O02W-K11@11.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Tommy Hilfiger',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'NI111A0D1-A11',
#   'name': 'ZOOM 2K - Trainers - white/black',
#   'price': {'original': '£79.99',
#    'promotional': '£67.99',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['2.5',
#    '3',
#    '3.5',
#    '4',
#    '4.5',
#    '5',
#    '5.5',
#    '6',
#    '6.5',
#    '7',
#    '7.5',
#    '8',
#    '8.5'],
#   'url_key': 'nike-sportswear-zoom-2k-trainers-ni111a0d1-a11',
#   'media': [{'path': 'NI/11/1A/0D/1A/11/NI111A0D1-A11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': True}],
#   'brand_name': 'Nike Sportswear',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-15%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'DAI21G000-G11',
#   'name': 'LOTTA RAIN JACKET - Waterproof jacket - red',
#   'price': {'original': '£124.99',
#    'promotional': '£81.24',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['8', '10', '12', '14/16', '18/20'],
#   'url_key': 'danefa-kobenhavn-bomber-jacket-red-dai21g000-g11',
#   'media': [{'path': 'DA/I2/1G/00/0G/11/DAI21G000-G11@9.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'DA/I2/1G/00/0G/11/DAI21G000-G11@10.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Danefæ København',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-35%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'AD111A0UO-A11',
#   'name': 'FALCON TORSION SYSTEM RUNNING-STYLE SHOES - Trainers - footwear white/crystal white/core black',
#   'price': {'original': '£89.99',
#    'promotional': '£49.49',
#    'has_different_prices': True,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': True,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['3.5', '4', '4.5', '5', '5.5', '6.5', '7', '7.5', '9'],
#   'url_key': 'adidas-originals-trainers-footwear-whitecrystal-whitecore-black-ad111a0uo-a11',
#   'media': [{'path': 'AD/11/1A/0U/OA/11/AD111A0UO-A11@3.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'adidas Originals',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': 'up to -45%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'shoe',
#   'delivery_promises': []},
#  {'sku': 'AD124G02B-A11',
#   'name': 'Long sleeved top - white/black',
#   'price': {'original': '£19.95',
#    'promotional': '£19.95',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['7-8y', '8-9y', '9-10y', '10-11y', '11-12y', '12-13y', '13-14y'],
#   'url_key': 'adidas-originals-stripes-long-sleeved-top-whiteblack-ad124g02b-a11',
#   'media': [{'path': 'AD/12/4G/02/BA/11/AD124G02B-A11@5.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False}],
#   'brand_name': 'adidas Originals',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'EVB21N014-K11',
#   'name': 'Jeans Skinny Fit - dark blue denim',
#   'price': {'original': '£25.99',
#    'promotional': '£18.19',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['18', '20', '22', '24'],
#   'url_key': 'evenandodd-curvy-jeans-skinny-fit-dark-blue-denim-evb21n014-k11',
#   'media': [{'path': 'EV/B2/1N/01/4K/11/EVB21N014-K11@12.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'EV/B2/1N/01/4K/11/EVB21N014-K11@17.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'Even&Odd Curvy',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'},
#    {'key': 'assortmentArea',
#     'value': 'Plus size',
#     'tracking_value': 'plus size'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'THJ21C01V-Q11',
#   'name': 'MIDI HALTER DRESS WITH CHAIN DETAIL - Jumper dress - black',
#   'price': {'original': '£47.99',
#    'promotional': '£33.59',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['XS', 'S', 'M', 'L'],
#   'url_key': 'the-ragged-priest-midi-halter-dress-with-chain-detail-jumper-dress-black-thj21c01v-q11',
#   'media': [{'path': 'TH/J2/1C/01/VQ/11/THJ21C01V-Q11@7.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'TH/J2/1C/01/VQ/11/THJ21C01V-Q11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'The Ragged Priest',
#   'is_premium': False,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-30%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'clothing',
#   'delivery_promises': []},
#  {'sku': 'K0551L008-F11',
#   'name': 'SMALL SQUARE LEVERBACKS - Earrings - jet',
#   'price': {'original': '£44.99',
#    'promotional': '£24.74',
#    'has_different_prices': False,
#    'has_different_original_prices': False,
#    'has_different_promotional_prices': False,
#    'has_discount_on_selected_sizes_only': False},
#   'sizes': ['One Size'],
#   'url_key': 'kate-spade-new-york-earrings-jet-k0551l008-f11',
#   'media': [{'path': 'K0/55/1L/00/8F/11/K0551L008-F11@8.1.jpg',
#     'role': 'DEFAULT',
#     'packet_shot': False},
#    {'path': 'K0/55/1L/00/8F/11/K0551L008-F11@9.jpg',
#     'role': 'HOVER',
#     'packet_shot': False}],
#   'brand_name': 'kate spade new york',
#   'is_premium': True,
#   'family_articles': [],
#   'flags': [{'key': 'discountRate',
#     'value': '-45%',
#     'tracking_value': 'discount rate'}],
#   'product_group': 'accessoires',
#   'delivery_promises': []}]

# %%
items = []

# %%
for item in item_array:
    name = item['name']
    price_match = item['price']['original']
    price = float(re.sub(r'£', '', price_match))
    saleprice_match = item['price']['promotional']
    saleprice = float(re.sub(r'£', '', saleprice_match))
    if saleprice == price:
        saleprice = None
        sale = False
    else:
        sale = True
    sizes = item['sizes']
    prod_url = f'https://www.zalando.co.uk/{item["url_key"]}.html'
    size_stock = [{"stock": "In stock", "size": size} for size in sizes]
    in_stock = False
    for size in size_stock:
        if size['stock'] == 'In stock':
            in_stock = True
    brand = item['brand_name']
    
    items.append({
        'name': name,
        'price': price,
        'saleprice': saleprice,
        'sale': sale,
        'size_stock': size_stock,
        'in_stock': in_stock,
        'brand': brand,
        'prod_url': prod_url
    })

# %%
items
# Out:
# [{'name': 'TREGGINGS WITH TAPE - Leggings - Trousers - black',
#   'price': 43.99,
#   'saleprice': 28.59,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '20'},
#    {'stock': 'In stock', 'size': '22'},
#    {'stock': 'In stock', 'size': '24'},
#    {'stock': 'In stock', 'size': '26'},
#    {'stock': 'In stock', 'size': '28'}],
#   'in_stock': True,
#   'brand': 'MY TRUE ME TOM TAILOR',
#   'prod_url': 'https://www.zalando.co.uk/my-true-me-tom-tailor-treggings-with-tape-leggings-trousers-black-tol21a002-q11.html'},
#  {'name': '2 HORSE GRAPHIC TEE - Print T-shirt - dress blues',
#   'price': 29.99,
#   'saleprice': 15.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-2-horse-graphic-tee-print-t-shirt-dress-blues-le222o050-k11.html'},
#  {'name': 'JAZZ ORIGINAL VINTAGE - Trainers - blue/black',
#   'price': 84.99,
#   'saleprice': 50.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '9.5'},
#    {'stock': 'In stock', 'size': '11'}],
#   'in_stock': True,
#   'brand': 'Saucony',
#   'prod_url': 'https://www.zalando.co.uk/saucony-jazz-original-vintage-trainers-s2315o000-k16.html'},
#  {'name': 'Suit trousers - charcoal',
#   'price': 39.99,
#   'saleprice': 23.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '28x30'},
#    {'stock': 'In stock', 'size': '28x32'},
#    {'stock': 'In stock', 'size': '30x30'},
#    {'stock': 'In stock', 'size': '30x32'},
#    {'stock': 'In stock', 'size': '32x30'},
#    {'stock': 'In stock', 'size': '32x32'},
#    {'stock': 'In stock', 'size': '32x34'},
#    {'stock': 'In stock', 'size': '34x32'},
#    {'stock': 'In stock', 'size': '34x34'},
#    {'stock': 'In stock', 'size': '36x32'},
#    {'stock': 'In stock', 'size': '36x34'}],
#   'in_stock': True,
#   'brand': 'River Island',
#   'prod_url': 'https://www.zalando.co.uk/river-island-suit-trousers-charcoal-ri922a037-c11.html'},
#  {'name': 'ONE - Leggings - black/white',
#   'price': 34.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Nike Performance',
#   'prod_url': 'https://www.zalando.co.uk/nike-performance-all-in-leggings-blackwhite-n1241e0pe-q11.html'},
#  {'name': 'CLASSIC PLATFORM - Slip-ons - black',
#   'price': 54.99,
#   'saleprice': 38.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'}],
#   'in_stock': True,
#   'brand': 'Vans',
#   'prod_url': 'https://www.zalando.co.uk/vans-classic-platform-trainers-black-va211a06p-q11.html'},
#  {'name': 'AZTREK ADVENTURE - Trainers - buff/grey/emerald',
#   'price': 69.99,
#   'saleprice': 41.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'}],
#   'in_stock': True,
#   'brand': 'Reebok Classic',
#   'prod_url': 'https://www.zalando.co.uk/reebok-classic-aztrek-adventure-trainers-buffgreyemerald-re011a0av-t11.html'},
#  {'name': '1460 PASCAL MONO JUNIOR - Classic ankle boots - black',
#   'price': 64.99,
#   'saleprice': 51.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '1'},
#    {'stock': 'In stock', 'size': '2'},
#    {'stock': 'In stock', 'size': '10K'},
#    {'stock': 'In stock', 'size': '11K'},
#    {'stock': 'In stock', 'size': '12K'},
#    {'stock': 'In stock', 'size': '13K'},
#    {'stock': 'In stock', 'size': '11.5K'}],
#   'in_stock': True,
#   'brand': 'Dr. Martens',
#   'prod_url': 'https://www.zalando.co.uk/dr-martens-1460-pascal-mono-junior-classic-ankle-boots-black-do216i00v-q11.html'},
#  {'name': 'TAPED HOODIE - Zip-up hoodie - black',
#   'price': 41.99,
#   'saleprice': 35.69,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '5-6y'},
#    {'stock': 'In stock', 'size': '7-8y'},
#    {'stock': 'In stock', 'size': '9-10y'},
#    {'stock': 'In stock', 'size': '11-12y'},
#    {'stock': 'In stock', 'size': '13y'}],
#   'in_stock': True,
#   'brand': 'Hype',
#   'prod_url': 'https://www.zalando.co.uk/hype-taped-hoodie-zip-up-hoodie-black-hy524k00s-q11.html'},
#  {'name': 'HEAVY BOMBER - Winter jacket - black',
#   'price': 314.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'},
#    {'stock': 'In stock', 'size': '3XL'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-heavy-bomber-winter-jacket-black-to122t04j-q11.html'},
#  {'name': 'HUARACHE RUN ULTRA  - Baby shoes - black',
#   'price': 42.99,
#   'saleprice': 30.09,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '5.5K'},
#    {'stock': 'In stock', 'size': '6.5K'},
#    {'stock': 'In stock', 'size': '7.5K'},
#    {'stock': 'In stock', 'size': '8.5K'},
#    {'stock': 'In stock', 'size': '9.5K'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-huarache-run-ultra-trainers-ni114f008-q11.html'},
#  {'name': 'STUART CLASSIC - Chinos - night',
#   'price': 119.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '28x32'},
#    {'stock': 'In stock', 'size': '29x30'},
#    {'stock': 'In stock', 'size': '29x32'},
#    {'stock': 'In stock', 'size': '29x34'},
#    {'stock': 'In stock', 'size': '30x30'},
#    {'stock': 'In stock', 'size': '30x32'},
#    {'stock': 'In stock', 'size': '30x34'},
#    {'stock': 'In stock', 'size': '31x30'},
#    {'stock': 'In stock', 'size': '31x32'},
#    {'stock': 'In stock', 'size': '31x34'},
#    {'stock': 'In stock', 'size': '31x36'},
#    {'stock': 'In stock', 'size': '32x30'},
#    {'stock': 'In stock', 'size': '32x32'},
#    {'stock': 'In stock', 'size': '32x34'},
#    {'stock': 'In stock', 'size': '32x36'},
#    {'stock': 'In stock', 'size': '33x30'},
#    {'stock': 'In stock', 'size': '33x32'},
#    {'stock': 'In stock', 'size': '33x34'},
#    {'stock': 'In stock', 'size': '34x30'},
#    {'stock': 'In stock', 'size': '34x32'},
#    {'stock': 'In stock', 'size': '34x34'},
#    {'stock': 'In stock', 'size': '34x36'},
#    {'stock': 'In stock', 'size': '36x30'},
#    {'stock': 'In stock', 'size': '36x32'},
#    {'stock': 'In stock', 'size': '36x34'},
#    {'stock': 'In stock', 'size': '36x36'},
#    {'stock': 'In stock', 'size': '38x34'},
#    {'stock': 'In stock', 'size': '38x36'}],
#   'in_stock': True,
#   'brand': 'Scotch & Soda',
#   'prod_url': 'https://www.zalando.co.uk/scotch-and-soda-stuart-classic-chinos-sc322e037-k11.html'},
#  {'name': 'TEE 2 PACK - Basic T-shirt - white',
#   'price': 29.99,
#   'saleprice': 17.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-2-pack-tee-basic-t-shirt-white-le221d05v-a11.html'},
#  {'name': 'OBOE - Across body bag - blue',
#   'price': 54.99,
#   'saleprice': 38.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Valentino by Mario Valentino',
#   'prod_url': 'https://www.zalando.co.uk/valentino-by-mario-valentino-oboe-across-body-bag-5va51h0a5-k11.html'},
#  {'name': 'LEGADOSEN - Slip-ons - black',
#   'price': 89.99,
#   'saleprice': 45.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '9'},
#    {'stock': 'In stock', 'size': '10'},
#    {'stock': 'In stock', 'size': '11'},
#    {'stock': 'In stock', 'size': '12'}],
#   'in_stock': True,
#   'brand': 'ALDO',
#   'prod_url': 'https://www.zalando.co.uk/aldo-legadosen-slip-ons-a0112c024-q11.html'},
#  {'name': 'POUCHES CHAIN POUCHETTE - Clutch - brown',
#   'price': 74.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'MICHAEL Michael Kors',
#   'prod_url': 'https://www.zalando.co.uk/michael-michael-kors-clutch-brown-mk151h0e6-o11.html'},
#  {'name': "D'LITES - Trainers - white/silver",
#   'price': 41.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '1.5'},
#    {'stock': 'In stock', 'size': '2'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '10K'},
#    {'stock': 'In stock', 'size': '11K'},
#    {'stock': 'In stock', 'size': '12K'},
#    {'stock': 'In stock', 'size': '13K'},
#    {'stock': 'In stock', 'size': '11.5K'},
#    {'stock': 'In stock', 'size': '12.5K'},
#    {'stock': 'In stock', 'size': '13.5K'}],
#   'in_stock': True,
#   'brand': 'Skechers',
#   'prod_url': 'https://www.zalando.co.uk/skechers-dlites-trainers-whitesilver-sk113d08a-a11.html'},
#  {'name': 'Print T-shirt - true white',
#   'price': 14.99,
#   'saleprice': 10.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '7y'},
#    {'stock': 'In stock', 'size': '8y'},
#    {'stock': 'In stock', 'size': '10y'},
#    {'stock': 'In stock', 'size': '12y'},
#    {'stock': 'In stock', 'size': '14y'},
#    {'stock': 'In stock', 'size': '16y'}],
#   'in_stock': True,
#   'brand': 'Guess',
#   'prod_url': 'https://www.zalando.co.uk/guess-core-print-t-shirt-gu124g03m-a11.html'},
#  {'name': 'BATWING TEE - Long sleeved top - white',
#   'price': 25.99,
#   'saleprice': 16.89,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '4y'},
#    {'stock': 'In stock', 'size': '5y'},
#    {'stock': 'In stock', 'size': '6y'},
#    {'stock': 'In stock', 'size': '8y'},
#    {'stock': 'In stock', 'size': '10y'},
#    {'stock': 'In stock', 'size': '12y'},
#    {'stock': 'In stock', 'size': '14y'},
#    {'stock': 'In stock', 'size': '16y'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-batwing-tee-long-sleeved-top-le226g00a-a11.html'},
#  {'name': 'LACY - Day dress - pink',
#   'price': 49.99,
#   'saleprice': 29.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Mango',
#   'prod_url': 'https://www.zalando.co.uk/mango-lacy-day-dress-pink-m9121c3rf-j11.html'},
#  {'name': 'ONSMSTEFAN  TEE - Print T-shirt - black',
#   'price': 12.99,
#   'saleprice': 7.14,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Only & Sons',
#   'prod_url': 'https://www.zalando.co.uk/only-and-sons-onsmstefan-tee-print-t-shirt-os322o0t1-q11.html'},
#  {'name': 'Ring - silver-coloured',
#   'price': 60.03,
#   'saleprice': 30.44,
#   'sale': True,
#   'size_stock': [],
#   'in_stock': False,
#   'brand': 'Heideman',
#   'prod_url': 'https://www.zalando.co.uk/heideman-mit-swarovski-stein-ring-silver-coloured-2he51l00f-a11.html'},
#  {'name': 'GRAPHIC VARSITY TEE - Basic T-shirt - tonal baby tab brilliant red',
#   'price': 29.99,
#   'saleprice': 17.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XXS'},
#    {'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-graphic-varsity-tee-basic-t-shirt-le221d072-g11.html'},
#  {'name': 'INTERNATIONALIST - Trainers - summit white/metallic silver',
#   'price': 74.99,
#   'saleprice': 44.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-internationalist-trainers-summit-whitemetallic-silver-ni111a0gv-a11.html'},
#  {'name': 'RAPID URBAN XBODY - Bum bag - black',
#   'price': 74.99,
#   'saleprice': 37.5,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Calvin Klein',
#   'prod_url': 'https://www.zalando.co.uk/calvin-klein-rapid-urban-xbody-bum-bag-black-6ca51h0cz-q11.html'},
#  {'name': 'THE PERFECT TEE - Print T-shirt - white/red',
#   'price': 19.99,
#   'saleprice': 14.39,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XXS'},
#    {'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-the-perfect-tee-print-t-shirt-le221d05g-a12.html'},
#  {'name': 'Classic ankle boots - grey',
#   'price': 69.99,
#   'saleprice': 59.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'}],
#   'in_stock': True,
#   'brand': 'Pier One',
#   'prod_url': 'https://www.zalando.co.uk/pier-one-boots-grey-pi911n02f-c12.html'},
#  {'name': 'ULTIMATE RADAR QUILT PUFFER - Winter jacket - black',
#   'price': 99.99,
#   'saleprice': 69.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Superdry',
#   'prod_url': 'https://www.zalando.co.uk/superdry-ultimate-radar-quilt-puffer-winter-jacket-black-su222t0da-q11.html'},
#  {'name': 'DIVINA  - Across body bag - nero',
#   'price': 54.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Valentino by Mario Valentino',
#   'prod_url': 'https://www.zalando.co.uk/valentino-by-mario-valentino-divina-across-body-bag-5va51h03s-q11.html'},
#  {'name': 'OSHAWA PADDED - Winter jacket - khaki',
#   'price': 119.99,
#   'saleprice': 89.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Alessandro Zavetti',
#   'prod_url': 'https://www.zalando.co.uk/alessandro-zavetti-oshawa-padded-parka-khaki-alk22t008-n11.html'},
#  {'name': 'ANGELINA TROUSERS - Flared Jeans - blue denim',
#   'price': 94.99,
#   'saleprice': 56.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '25'},
#    {'stock': 'In stock', 'size': '26'},
#    {'stock': 'In stock', 'size': '27'},
#    {'stock': 'In stock', 'size': '28'},
#    {'stock': 'In stock', 'size': '29'},
#    {'stock': 'In stock', 'size': '30'}],
#   'in_stock': True,
#   'brand': 'JUST FEMALE',
#   'prod_url': 'https://www.zalando.co.uk/just-female-angelina-trousers-flared-jeans-blue-denim-ju121n009-k11.html'},
#  {'name': 'KIDS SPECKLE FADE - Print T-shirt - pink/white',
#   'price': 18.99,
#   'saleprice': 15.19,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3-4y'},
#    {'stock': 'In stock', 'size': '5-6y'},
#    {'stock': 'In stock', 'size': '7-8y'},
#    {'stock': 'In stock', 'size': '9-10y'},
#    {'stock': 'In stock', 'size': '11-12y'},
#    {'stock': 'In stock', 'size': '13y'}],
#   'in_stock': True,
#   'brand': 'Hype',
#   'prod_url': 'https://www.zalando.co.uk/hype-kids-speckle-fade-print-t-shirt-pinkwhite-hy526g00b-j11.html'},
#  {'name': 'INVADER - Trainers - navy/light grey',
#   'price': 54.99,
#   'saleprice': 32.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '1.5'},
#    {'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '10K'},
#    {'stock': 'In stock', 'size': '11K'},
#    {'stock': 'In stock', 'size': '12K'},
#    {'stock': 'In stock', 'size': '11.5K'}],
#   'in_stock': True,
#   'brand': 'Rooskickx',
#   'prod_url': 'https://www.zalando.co.uk/rooskickx-invader-trainers-navylight-grey-rop14d001-k11.html'},
#  {'name': 'COTU - Trainers - white',
#   'price': 64.99,
#   'saleprice': 48.74,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '8'}],
#   'in_stock': True,
#   'brand': 'Superga',
#   'prod_url': 'https://www.zalando.co.uk/superga-2730-trainers-su111a01u-a12.html'},
#  {'name': 'DRESSED UP LOGO - Ring - silver-coloured',
#   'price': 33.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [],
#   'in_stock': False,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-dressed-up-logo-ring-silver-coloured-to152l02h-d11.html'},
#  {'name': 'D FORMATION - Trainers - white/navy/red',
#   'price': 104.99,
#   'saleprice': 62.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '9'}],
#   'in_stock': True,
#   'brand': 'Fila',
#   'prod_url': 'https://www.zalando.co.uk/fila-formation-trainers-1fi11a00u-a12.html'},
#  {'name': 'ANETT - Blazer - sea green',
#   'price': 64.99,
#   'saleprice': 38.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Cream',
#   'prod_url': 'https://www.zalando.co.uk/cream-anett-blazer-cr221g022-m11.html'},
#  {'name': 'SHOX ENIGMA 9000 - Trainers - black/gym red',
#   'price': 114.99,
#   'saleprice': 80.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-shox-enigma-9000-trainers-ni111a0gj-q13.html'},
#  {'name': 'Beanie - fawn grey heather',
#   'price': 43.99,
#   'saleprice': 35.19,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Polo Ralph Lauren',
#   'prod_url': 'https://www.zalando.co.uk/polo-ralph-lauren-beanie-fawn-grey-heather-po252o00d-c11.html'},
#  {'name': 'FROST - Winter coat - jet black',
#   'price': 99.99,
#   'saleprice': 74.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Kings Will Dream',
#   'prod_url': 'https://www.zalando.co.uk/kings-will-dream-frost-winter-coat-jet-black-kie22t007-q11.html'},
#  {'name': 'CLUB C 85 - Trainers - white/light grey',
#   'price': 64.99,
#   'saleprice': 48.74,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'}],
#   'in_stock': True,
#   'brand': 'Reebok Classic',
#   'prod_url': 'https://www.zalando.co.uk/reebok-classic-club-c-85-trainers-re011s06g-a11.html'},
#  {'name': 'NEW ALY BELT - Belt business - black',
#   'price': 34.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '32'},
#    {'stock': 'In stock', 'size': '34'},
#    {'stock': 'In stock', 'size': '36'},
#    {'stock': 'In stock', 'size': '38'},
#    {'stock': 'In stock', 'size': '40'},
#    {'stock': 'In stock', 'size': '44'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-new-aly-belt-black-to152d04d-q11.html'},
#  {'name': 'ANORAK JACKET - Summer jacket - aviator navy',
#   'price': 154.99,
#   'saleprice': 108.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Polo Ralph Lauren',
#   'prod_url': 'https://www.zalando.co.uk/polo-ralph-lauren-anorak-jacket-summer-jacket-aviator-navy-po222h016-k13.html'},
#  {'name': 'NEW DENTON - Belt business - black',
#   'price': 34.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '32'},
#    {'stock': 'In stock', 'size': '34'},
#    {'stock': 'In stock', 'size': '36'},
#    {'stock': 'In stock', 'size': '38'},
#    {'stock': 'In stock', 'size': '40'},
#    {'stock': 'In stock', 'size': '42'},
#    {'stock': 'In stock', 'size': '44'},
#    {'stock': 'In stock', 'size': '46'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-new-denton-belt-business-to152d061-q11.html'},
#  {'name': 'HOODIE  - Hoodie - dark grey heather',
#   'price': 49.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-hoodie-sweatshirt-ni122s0cg-c11.html'},
#  {'name': 'LOVES ME KNOT LOVES ME KNOT STUDS - Earrings - gold-coloured',
#   'price': 47.99,
#   'saleprice': 26.39,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'kate spade new york',
#   'prod_url': 'https://www.zalando.co.uk/kate-spade-new-york-loves-me-knot-loves-me-knot-studs-earrings-gold-coloured-k0551l04h-f11.html'},
#  {'name': 'Clogs - black',
#   'price': 42.99,
#   'saleprice': 30.09,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '5.5-6'},
#    {'stock': 'In stock', 'size': '6.5-7'},
#    {'stock': 'In stock', 'size': '7.5-8'},
#    {'stock': 'In stock', 'size': '8.5-9'},
#    {'stock': 'In stock', 'size': '9.5-10'}],
#   'in_stock': True,
#   'brand': 'SUBU',
#   'prod_url': 'https://www.zalando.co.uk/subu-mules-black-suu15g000-q11.html'},
#  {'name': 'GRAPHIC VARSITY TEE - Print T-shirt - multicolor',
#   'price': 29.99,
#   'saleprice': 17.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-graphic-varsity-tee-print-t-shirt-multicolor-le221d07g-t11.html'},
#  {'name': 'POP ICON CREW - Basic T-shirt - popcorn with mood indigo',
#   'price': 20.99,
#   'saleprice': 10.5,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Abercrombie & Fitch',
#   'prod_url': 'https://www.zalando.co.uk/abercrombie-and-fitch-pop-icon-crew-print-t-shirt-a0f22o04g-e11.html'},
#  {'name': 'EARTH BEETLE R SW WMN L\\S - Sweatshirt - faded balsam',
#   'price': 94.99,
#   'saleprice': 52.24,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XXS'},
#    {'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'G-Star',
#   'prod_url': 'https://www.zalando.co.uk/g-star-earth-beetle-r-sw-wmn-ls-sweatshirt-faded-balsam-gs121j06z-m11.html'},
#  {'name': 'DIVINA  - Across body bag - rosso',
#   'price': 54.99,
#   'saleprice': 43.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Valentino by Mario Valentino',
#   'prod_url': 'https://www.zalando.co.uk/valentino-by-mario-valentino-divina-across-body-bag-rosso-5va51h03s-g11.html'},
#  {'name': 'HONEY BELT BAG - Bum bag - black',
#   'price': 104.99,
#   'saleprice': 62.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-honey-belt-bag-bum-bag-black-to151h0ps-q11.html'},
#  {'name': 'SMOOTH CROSSOVER - Across body bag - multi',
#   'price': 104.99,
#   'saleprice': 62.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-smooth-crossover-across-body-bag-multi-to151h0ot-t11.html'},
#  {'name': 'LOGO - Sweatshirt - black',
#   'price': 129.99,
#   'saleprice': 77.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'XL'}],
#   'in_stock': True,
#   'brand': 'Fiorucci',
#   'prod_url': 'https://www.zalando.co.uk/fiorucci-logo-sweatshirt-black-fi922s004-q11.html'},
#  {'name': 'COAST STAR - Trainers - core black/collegiate royal/scarlet',
#   'price': 69.99,
#   'saleprice': 35.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'},
#    {'stock': 'In stock', 'size': '9'},
#    {'stock': 'In stock', 'size': '9.5'},
#    {'stock': 'In stock', 'size': '10'},
#    {'stock': 'In stock', 'size': '10.5'},
#    {'stock': 'In stock', 'size': '11'},
#    {'stock': 'In stock', 'size': '11.5'},
#    {'stock': 'In stock', 'size': '12'},
#    {'stock': 'In stock', 'size': '12.5'}],
#   'in_stock': True,
#   'brand': 'adidas Originals',
#   'prod_url': 'https://www.zalando.co.uk/adidas-originals-coast-star-trainers-core-blackcollegiate-royalscarlet-ad115o0in-q11.html'},
#  {'name': 'NITCLASSIC - Slim fit jeans - dark blue denim',
#   'price': 23.0,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '2y'},
#    {'stock': 'In stock', 'size': '3y'},
#    {'stock': 'In stock', 'size': '4y'},
#    {'stock': 'In stock', 'size': '5y'},
#    {'stock': 'In stock', 'size': '6y'},
#    {'stock': 'In stock', 'size': '7y'},
#    {'stock': 'In stock', 'size': '8y'},
#    {'stock': 'In stock', 'size': '9y'},
#    {'stock': 'In stock', 'size': '10y'},
#    {'stock': 'In stock', 'size': '11y'},
#    {'stock': 'In stock', 'size': '12y'},
#    {'stock': 'In stock', 'size': '13y'},
#    {'stock': 'In stock', 'size': '14y'}],
#   'in_stock': True,
#   'brand': 'Name it',
#   'prod_url': 'https://www.zalando.co.uk/name-it-straight-leg-jeans-dark-blue-denim-na824a0es-k11.html'},
#  {'name': 'LOGO HOODY - Hoodie - black',
#   'price': 89.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'},
#    {'stock': 'In stock', 'size': '3XL'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-logo-hoody-sweatshirt-to122s06q-q11.html'},
#  {'name': 'MIX AND MATCH ASYMETRIC ANIMAL MIDI DRESS - Maxi dress - brown',
#   'price': 43.99,
#   'saleprice': 24.19,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '16'},
#    {'stock': 'In stock', 'size': '18'},
#    {'stock': 'In stock', 'size': '20'},
#    {'stock': 'In stock', 'size': '22'},
#    {'stock': 'In stock', 'size': '24'}],
#   'in_stock': True,
#   'brand': 'Glamorous Curve',
#   'prod_url': 'https://www.zalando.co.uk/glamorous-curve-mix-and-match-asymetric-animal-midi-dress-maxi-dress-brown-gla21c065-o11.html'},
#  {'name': 'DALSI - Faux leather jacket - black',
#   'price': 89.99,
#   'saleprice': 62.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'L'}],
#   'in_stock': True,
#   'brand': 'Mango',
#   'prod_url': 'https://www.zalando.co.uk/mango-faux-leather-jacket-black-m9121u0ms-q11.html'},
#  {'name': 'FALCON 2000  - Trainers - core black',
#   'price': 74.99,
#   'saleprice': 37.5,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'},
#    {'stock': 'In stock', 'size': '9'}],
#   'in_stock': True,
#   'brand': 'adidas Originals',
#   'prod_url': 'https://www.zalando.co.uk/adidas-originals-trainers-core-black-ad111a0wt-q11.html'},
#  {'name': 'SLIM SCANTON COBCO - Slim fit jeans - cobble black comfort',
#   'price': 79.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '27x30'},
#    {'stock': 'In stock', 'size': '27x32'},
#    {'stock': 'In stock', 'size': '27x36'},
#    {'stock': 'In stock', 'size': '28x32'},
#    {'stock': 'In stock', 'size': '28x34'},
#    {'stock': 'In stock', 'size': '29x34'},
#    {'stock': 'In stock', 'size': '29x36'},
#    {'stock': 'In stock', 'size': '30x30'},
#    {'stock': 'In stock', 'size': '30x32'},
#    {'stock': 'In stock', 'size': '30x34'},
#    {'stock': 'In stock', 'size': '30x36'},
#    {'stock': 'In stock', 'size': '31x30'},
#    {'stock': 'In stock', 'size': '31x32'},
#    {'stock': 'In stock', 'size': '31x34'},
#    {'stock': 'In stock', 'size': '31x36'},
#    {'stock': 'In stock', 'size': '32x30'},
#    {'stock': 'In stock', 'size': '32x32'},
#    {'stock': 'In stock', 'size': '32x34'},
#    {'stock': 'In stock', 'size': '32x36'},
#    {'stock': 'In stock', 'size': '33x30'},
#    {'stock': 'In stock', 'size': '33x34'},
#    {'stock': 'In stock', 'size': '33x36'},
#    {'stock': 'In stock', 'size': '34x30'},
#    {'stock': 'In stock', 'size': '34x32'},
#    {'stock': 'In stock', 'size': '34x34'},
#    {'stock': 'In stock', 'size': '36x30'},
#    {'stock': 'In stock', 'size': '36x32'},
#    {'stock': 'In stock', 'size': '36x34'},
#    {'stock': 'In stock', 'size': '36x36'},
#    {'stock': 'In stock', 'size': '38x30'},
#    {'stock': 'In stock', 'size': '38x32'},
#    {'stock': 'In stock', 'size': '38x34'},
#    {'stock': 'In stock', 'size': '38x36'}],
#   'in_stock': True,
#   'brand': 'Tommy Jeans',
#   'prod_url': 'https://www.zalando.co.uk/tommy-jeans-slim-scanton-cobco-slim-fit-jeans-cobble-black-comfort-tob22g017-q11.html'},
#  {'name': 'HERITAGE SMALL SLING BAG - Handbag - blue',
#   'price': 59.99,
#   'saleprice': 32.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Tommy Jeans',
#   'prod_url': 'https://www.zalando.co.uk/tommy-jeans-heritage-small-sling-bag-handbag-blue-tob51h00t-k11.html'},
#  {'name': 'FAIRVIEW - Sweatshirt - brown duck',
#   'price': 54.99,
#   'saleprice': 35.74,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Dickies',
#   'prod_url': 'https://www.zalando.co.uk/dickies-fairview-sweatshirt-brown-duck-di622s028-o11.html'},
#  {'name': 'CREWNECK - Long sleeved top - red',
#   'price': 39.99,
#   'saleprice': 23.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Champion',
#   'prod_url': 'https://www.zalando.co.uk/champion-crewneck-long-sleeved-top-red-c7641d01c-g11.html'},
#  {'name': 'UA OLD SKOOL PLATFORM - Trainers - black/white',
#   'price': 69.99,
#   'saleprice': 59.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'},
#    {'stock': 'In stock', 'size': '9'}],
#   'in_stock': True,
#   'brand': 'Vans',
#   'prod_url': 'https://www.zalando.co.uk/vans-trainers-blackwhite-va211s03a-q11.html'},
#  {'name': 'AIR 270 REACT SE - Trainers - pumice/white',
#   'price': 149.99,
#   'saleprice': 75.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-air-270-react-se-trainers-pumicewhite-ni111a0ia-b11.html'},
#  {'name': 'Cape - grey/silver',
#   'price': 25.99,
#   'saleprice': 13.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Anna Field',
#   'prod_url': 'https://www.zalando.co.uk/anna-field-cape-greysilver-an651g04l-c12.html'},
#  {'name': 'PERFECT - Leather jacket - dark green',
#   'price': 119.99,
#   'saleprice': 83.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'}],
#   'in_stock': True,
#   'brand': 'Mango',
#   'prod_url': 'https://www.zalando.co.uk/mango-perfect-leather-jacket-m9121g0qt-m11.html'},
#  {'name': 'BATWING TEE - Print T-shirt - white',
#   'price': 13.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '3y'},
#    {'stock': 'In stock', 'size': '4y'},
#    {'stock': 'In stock', 'size': '5y'},
#    {'stock': 'In stock', 'size': '6y'},
#    {'stock': 'In stock', 'size': '8y'},
#    {'stock': 'In stock', 'size': '10y'},
#    {'stock': 'In stock', 'size': '12y'},
#    {'stock': 'In stock', 'size': '14y'},
#    {'stock': 'In stock', 'size': '16y'}],
#   'in_stock': True,
#   'brand': "Levi's®",
#   'prod_url': 'https://www.zalando.co.uk/levisr-print-t-shirt-white-le226g005-a11.html'},
#  {'name': 'Winter boots - silver',
#   'price': 74.99,
#   'saleprice': 63.74,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5-5'},
#    {'stock': 'In stock', 'size': '6-7.5'},
#    {'stock': 'In stock', 'size': '8-9.5'}],
#   'in_stock': True,
#   'brand': 'Moon Boot',
#   'prod_url': 'https://www.zalando.co.uk/moon-boot-winter-boots-silver-m4511x008-d11.html'},
#  {'name': 'CAROL - Straight leg jeans - dark garner',
#   'price': 90.0,
#   'saleprice': 45.0,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '25x31'},
#    {'stock': 'In stock', 'size': '25x33'},
#    {'stock': 'In stock', 'size': '26x31'},
#    {'stock': 'In stock', 'size': '27x31'},
#    {'stock': 'In stock', 'size': '27x33'},
#    {'stock': 'In stock', 'size': '28x31'},
#    {'stock': 'In stock', 'size': '28x33'},
#    {'stock': 'In stock', 'size': '28x35'},
#    {'stock': 'In stock', 'size': '29x31'},
#    {'stock': 'In stock', 'size': '29x33'},
#    {'stock': 'In stock', 'size': '29x35'},
#    {'stock': 'In stock', 'size': '30x35'},
#    {'stock': 'In stock', 'size': '32x33'},
#    {'stock': 'In stock', 'size': '33x33'},
#    {'stock': 'In stock', 'size': '34x33'}],
#   'in_stock': True,
#   'brand': 'Lee',
#   'prod_url': 'https://www.zalando.co.uk/lee-carol-straight-leg-jeans-dark-garner-le421n05z-k11.html'},
#  {'name': 'POPPY BACKPACK - Rucksack - black',
#   'price': 79.99,
#   'saleprice': 55.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-poppy-backpack-rucksack-black-to151q01p-q11.html'},
#  {'name': 'SAC EPAULE - Across body bag - black',
#   'price': 84.99,
#   'saleprice': 53.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'The Kooples',
#   'prod_url': 'https://www.zalando.co.uk/the-kooples-sac-epaule-across-body-bag-black-tha52h006-q11.html'},
#  {'name': 'AIR VAPORMAX FLYKNIT - Trainers - black/anthracite/white/metallic silver',
#   'price': 169.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '10'},
#    {'stock': 'In stock', 'size': '11'},
#    {'stock': 'In stock', 'size': '11.5'},
#    {'stock': 'In stock', 'size': '12'},
#    {'stock': 'In stock', 'size': '14'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-air-vapormax-flyknit-3-trainers-ni112o08o-q11.html'},
#  {'name': 'Shirt - weiß',
#   'price': 59.99,
#   'saleprice': 35.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'},
#    {'stock': 'In stock', 'size': '3XL'}],
#   'in_stock': True,
#   'brand': 'A fish named fred',
#   'prod_url': 'https://www.zalando.co.uk/a-fish-named-fred-shirt-weiss-af822d003-a11.html'},
#  {'name': 'NEW STRETCH TEE C-NECK - Basic T-shirt - flag black',
#   'price': 25.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-slim-fit-basic-t-shirt-flag-black-to122o02w-q11.html'},
#  {'name': 'NEW STRETCH TEE C-NECK - Basic T-shirt - navy blazer',
#   'price': 25.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'},
#    {'stock': 'In stock', 'size': 'XL'},
#    {'stock': 'In stock', 'size': 'XXL'}],
#   'in_stock': True,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-basic-t-shirt-navy-blazer-to122o02w-k11.html'},
#  {'name': 'ZOOM 2K - Trainers - white/black',
#   'price': 79.99,
#   'saleprice': 67.99,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '2.5'},
#    {'stock': 'In stock', 'size': '3'},
#    {'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '8.5'}],
#   'in_stock': True,
#   'brand': 'Nike Sportswear',
#   'prod_url': 'https://www.zalando.co.uk/nike-sportswear-zoom-2k-trainers-ni111a0d1-a11.html'},
#  {'name': 'LOTTA RAIN JACKET - Waterproof jacket - red',
#   'price': 124.99,
#   'saleprice': 81.24,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '8'},
#    {'stock': 'In stock', 'size': '10'},
#    {'stock': 'In stock', 'size': '12'},
#    {'stock': 'In stock', 'size': '14/16'},
#    {'stock': 'In stock', 'size': '18/20'}],
#   'in_stock': True,
#   'brand': 'Danefæ København',
#   'prod_url': 'https://www.zalando.co.uk/danefa-kobenhavn-bomber-jacket-red-dai21g000-g11.html'},
#  {'name': 'FALCON TORSION SYSTEM RUNNING-STYLE SHOES - Trainers - footwear white/crystal white/core black',
#   'price': 89.99,
#   'saleprice': 49.49,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '3.5'},
#    {'stock': 'In stock', 'size': '4'},
#    {'stock': 'In stock', 'size': '4.5'},
#    {'stock': 'In stock', 'size': '5'},
#    {'stock': 'In stock', 'size': '5.5'},
#    {'stock': 'In stock', 'size': '6.5'},
#    {'stock': 'In stock', 'size': '7'},
#    {'stock': 'In stock', 'size': '7.5'},
#    {'stock': 'In stock', 'size': '9'}],
#   'in_stock': True,
#   'brand': 'adidas Originals',
#   'prod_url': 'https://www.zalando.co.uk/adidas-originals-trainers-footwear-whitecrystal-whitecore-black-ad111a0uo-a11.html'},
#  {'name': 'Long sleeved top - white/black',
#   'price': 19.95,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [{'stock': 'In stock', 'size': '7-8y'},
#    {'stock': 'In stock', 'size': '8-9y'},
#    {'stock': 'In stock', 'size': '9-10y'},
#    {'stock': 'In stock', 'size': '10-11y'},
#    {'stock': 'In stock', 'size': '11-12y'},
#    {'stock': 'In stock', 'size': '12-13y'},
#    {'stock': 'In stock', 'size': '13-14y'}],
#   'in_stock': True,
#   'brand': 'adidas Originals',
#   'prod_url': 'https://www.zalando.co.uk/adidas-originals-stripes-long-sleeved-top-whiteblack-ad124g02b-a11.html'},
#  {'name': 'Jeans Skinny Fit - dark blue denim',
#   'price': 25.99,
#   'saleprice': 18.19,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': '18'},
#    {'stock': 'In stock', 'size': '20'},
#    {'stock': 'In stock', 'size': '22'},
#    {'stock': 'In stock', 'size': '24'}],
#   'in_stock': True,
#   'brand': 'Even&Odd Curvy',
#   'prod_url': 'https://www.zalando.co.uk/evenandodd-curvy-jeans-skinny-fit-dark-blue-denim-evb21n014-k11.html'},
#  {'name': 'MIDI HALTER DRESS WITH CHAIN DETAIL - Jumper dress - black',
#   'price': 47.99,
#   'saleprice': 33.59,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'XS'},
#    {'stock': 'In stock', 'size': 'S'},
#    {'stock': 'In stock', 'size': 'M'},
#    {'stock': 'In stock', 'size': 'L'}],
#   'in_stock': True,
#   'brand': 'The Ragged Priest',
#   'prod_url': 'https://www.zalando.co.uk/the-ragged-priest-midi-halter-dress-with-chain-detail-jumper-dress-black-thj21c01v-q11.html'},
#  {'name': 'SMALL SQUARE LEVERBACKS - Earrings - jet',
#   'price': 44.99,
#   'saleprice': 24.74,
#   'sale': True,
#   'size_stock': [{'stock': 'In stock', 'size': 'One Size'}],
#   'in_stock': True,
#   'brand': 'kate spade new york',
#   'prod_url': 'https://www.zalando.co.uk/kate-spade-new-york-earrings-jet-k0551l008-f11.html'}]

# %%
[item for item in items if item['in_stock'] == False]
# Out:
# [{'name': 'Ring - silver-coloured',
#   'price': 60.03,
#   'saleprice': 30.44,
#   'sale': True,
#   'size_stock': [],
#   'in_stock': False,
#   'brand': 'Heideman',
#   'prod_url': 'https://www.zalando.co.uk/heideman-mit-swarovski-stein-ring-silver-coloured-2he51l00f-a11.html'},
#  {'name': 'DRESSED UP LOGO - Ring - silver-coloured',
#   'price': 33.99,
#   'saleprice': None,
#   'sale': False,
#   'size_stock': [],
#   'in_stock': False,
#   'brand': 'Tommy Hilfiger',
#   'prod_url': 'https://www.zalando.co.uk/tommy-hilfiger-dressed-up-logo-ring-silver-coloured-to152l02h-d11.html'}]

# %%
prod_req = requests.get('https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html', headers=headers)

# %%
prod_doc = lxml.html.fromstring(prod_req.text)

# %%
prod_json_string = prod_doc.xpath('.//script[contains(@id, "pdp-props")]/text()')

# %%
prod_json_string_clean = re.sub('\<\!\[CDATA', '', prod_json_string[0])

# %%
prod_json_string_cleaner = re.sub('\]\>', '', prod_json_string_clean)

# %%
prod_json_string_cleaner
# Out:
# '[{"layout":"cover","model":{"layout":"cover","priceInfo":{"showPriceHint":false,"priceHintType":""},"mediaInfo":{"currentIndex":0},"sizeInfo":{"displaySizeSelection":true,"showDropdown":true,"enableSizeFits":true,"sizeReco":{"enabled":false,"preselected":false},"enableSizeTable":true,"sizeRecoAlgoVersion":"MD1","sizeTableBounds":[{"targetGroups":["MALE","FEMALE","UNISEX"],"filterName":"matchStrictEqual"}],"showSizeSwitch":true},"selectedSizeFormat":"LOCAL","interactions":{"isGalleryZoomed":false,"isSocialDrawerOpen":false,"isColorsDrawerOpen":false,"isSizeDropdownVisible":false,"isPartnerModalVisible":false,"isSizeReminderModalOpen":false,"isPartnerInfoVisible":false,"showSizeRecoBox":false,"wishlistCTAState":"notloading","addToCartCTAState":"notloading","wishlistSuccess":false,"wishlistFailure":false,"wishlistLoading":false,"wishlistStates":{}},"sizeReminderFormErrors":{},"hoverLayer":{"isActive":false},"articleInfo":{"modelId":"ES421E0OL","id":"ES421E0OL-A11","shopUrl":"https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html","sizeFits":null,"commodity_group":{"values":["2","1","E","Z"]},"active":true,"coming_soon":false,"release_date":null,"name":"Blouse - off white","color":"off white","silhouette_code":"shirt","product_group":"clothing","category_tag":"Blouse","categories":["catalog","women","womens-clothing","womens-clothing-blouses-tunics","womens-clothing-blouses","all","clothing"],"brand":{"name":"Esprit Collection","code":"ES4","image_url":"33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg","logoUrl":"https://mosaic03.ztat.net/vgs/media/brand/33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg","logoLargeUrl":"https://mosaic03.ztat.net/vgs/media/brandxl/33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg","shopUrl":"/esprit-collection"},"available":true,"units":[{"displayPrice":{"isPriceDifferent":false,"isOriginalPriceDifferent":false,"isDiscounted":false,"percentageDiscount":0,"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"}},"id":"ES421E0OL-A110320000","size":{"local":"6","local_type":"UK","manufacturer":"32","manufacturer_type":"UNKNOWN"},"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"available":false,"stock":0},{"displayPrice":{"isPriceDifferent":false,"isOriginalPriceDifferent":false,"isDiscounted":false,"percentageDiscount":0,"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"}},"id":"ES421E0OL-A110340000","size":{"local":"8","local_type":"UK","manufacturer":"34","manufacturer_type":"UNKNOWN"},"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"available":true,"stock":1,"merchantId":"810d1d00-4312-43e5-bd31-d8373fdd24c7","fulfillmentType":"ZALANDO","deliveryPromises":[]},{"displayPrice":{"isPriceDifferent":false,"isOriginalPriceDifferent":false,"isDiscounted":false,"percentageDiscount":0,"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"}},"id":"ES421E0OL-A110360000","size":{"local":"10","local_type":"UK","manufacturer":"36","manufacturer_type":"UNKNOWN"},"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"available":true,"stock":1,"merchantId":"810d1d00-4312-43e5-bd31-d8373fdd24c7","fulfillmentType":"ZALANDO","deliveryPromises":[]},{"displayPrice":{"isPriceDifferent":false,"isOriginalPriceDifferent":false,"isDiscounted":false,"percentageDiscount":0,"price":{"currency":"GBP","value":44.99,"formatted":"£44.99"},"originalPrice":{"currency":"GBP","value":44.99,"formatted":"£44.99"}},"id":"ES421E0OL-A110380000","size":{"local":"12","local_type":"UK","manufacturer":"38","manufacturer_type":"UNKNOWN"},"price":{"currency":"GBP","value":44.99, ...

# %%
prod_json = json.loads(prod_json_string_cleaner)

# %%
prod_json
# Out:
# [{'layout': 'cover',
#   'model': {'layout': 'cover',
#    'priceInfo': {'showPriceHint': False, 'priceHintType': ''},
#    'mediaInfo': {'currentIndex': 0},
#    'sizeInfo': {'displaySizeSelection': True,
#     'showDropdown': True,
#     'enableSizeFits': True,
#     'sizeReco': {'enabled': False, 'preselected': False},
#     'enableSizeTable': True,
#     'sizeRecoAlgoVersion': 'MD1',
#     'sizeTableBounds': [{'targetGroups': ['MALE', 'FEMALE', 'UNISEX'],
#       'filterName': 'matchStrictEqual'}],
#     'showSizeSwitch': True},
#    'selectedSizeFormat': 'LOCAL',
#    'interactions': {'isGalleryZoomed': False,
#     'isSocialDrawerOpen': False,
#     'isColorsDrawerOpen': False,
#     'isSizeDropdownVisible': False,
#     'isPartnerModalVisible': False,
#     'isSizeReminderModalOpen': False,
#     'isPartnerInfoVisible': False,
#     'showSizeRecoBox': False,
#     'wishlistCTAState': 'notloading',
#     'addToCartCTAState': 'notloading',
#     'wishlistSuccess': False,
#     'wishlistFailure': False,
#     'wishlistLoading': False,
#     'wishlistStates': {}},
#    'sizeReminderFormErrors': {},
#    'hoverLayer': {'isActive': False},
#    'articleInfo': {'modelId': 'ES421E0OL',
#     'id': 'ES421E0OL-A11',
#     'shopUrl': 'https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html',
#     'sizeFits': None,
#     'commodity_group': {'values': ['2', '1', 'E', 'Z']},
#     'active': True,
#     'coming_soon': False,
#     'release_date': None,
#     'name': 'Blouse - off white',
#     'color': 'off white',
#     'silhouette_code': 'shirt',
#     'product_group': 'clothing',
#     'category_tag': 'Blouse',
#     'categories': ['catalog',
#      'women',
#      'womens-clothing',
#      'womens-clothing-blouses-tunics',
#      'womens-clothing-blouses',
#      'all',
#      'clothing'],
#     'brand': {'name': 'Esprit Collection',
#      'code': 'ES4',
#      'image_url': '33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg',
#      'logoUrl': 'https://mosaic03.ztat.net/vgs/media/brand/33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg',
#      'logoLargeUrl': 'https://mosaic03.ztat.net/vgs/media/brandxl/33e037ae-9556-4463-b02b-0e5d3bed78c5.jpg',
#      'shopUrl': '/esprit-collection'},
#     'available': True,
#     'units': [{'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110320000',
#       'size': {'local': '6',
#        'local_type': 'UK',
#        'manufacturer': '32',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': False,
#       'stock': 0},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110340000',
#       'size': {'local': '8',
#        'local_type': 'UK',
#        'manufacturer': '34',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': True,
#       'stock': 1,
#       'merchantId': '810d1d00-4312-43e5-bd31-d8373fdd24c7',
#       'fulfillmentType': 'ZALANDO',
#       'deliveryPromises': []},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110360000',
#       'size': {'local': '10',
#        'local_type': 'UK',
#        'manufacturer': '36',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': True,
#       'stock': 1,
#       'merchantId': '810d1d00-4312-43e5-bd31-d8373fdd24c7',
#       'fulfillmentType': 'ZALANDO',
#       'deliveryPromises': []},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110380000',
#       'size': {'local': '12',
#        'local_type': 'UK',
#        'manufacturer': '38',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': True,
#       'stock': 11,
#       'merchantId': '810d1d00-4312-43e5-bd31-d8373fdd24c7',
#       'fulfillmentType': 'ZALANDO',
#       'deliveryPromises': []},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110400000',
#       'size': {'local': '14',
#        'local_type': 'UK',
#        'manufacturer': '40',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': True,
#       'stock': 2,
#       'merchantId': '810d1d00-4312-43e5-bd31-d8373fdd24c7',
#       'fulfillmentType': 'ZALANDO',
#       'deliveryPromises': []},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110420000',
#       'size': {'local': '16',
#        'local_type': 'UK',
#        'manufacturer': '42',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': True,
#       'stock': 3,
#       'merchantId': '810d1d00-4312-43e5-bd31-d8373fdd24c7',
#       'fulfillmentType': 'ZALANDO',
#       'deliveryPromises': []},
#      {'displayPrice': {'isPriceDifferent': False,
#        'isOriginalPriceDifferent': False,
#        'isDiscounted': False,
#        'percentageDiscount': 0,
#        'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#        'originalPrice': {'currency': 'GBP',
#         'value': 44.99,
#         'formatted': '£44.99'}},
#       'id': 'ES421E0OL-A110440000',
#       'size': {'local': '18',
#        'local_type': 'UK',
#        'manufacturer': '44',
#        'manufacturer_type': 'UNKNOWN'},
#       'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#       'originalPrice': {'currency': 'GBP',
#        'value': 44.99,
#        'formatted': '£44.99'},
#       'available': False,
#       'stock': 0}],
#     'partnerTncUrl': 'https://www.zalando.co.uk/zalando-terms/',
#     'soldoutUnits': [{'id': 'ES421E0OL-A110320000',
#       'size': {'local': '6',
#        'local_type': 'UK',
#        'manufacturer': '32',
#        'manufacturer_type': 'UNKNOWN'}},
#      {'id': 'ES421E0OL-A110440000',
#       'size': {'local': '18',
#        'local_type': 'UK',
#        'manufacturer': '44',
#        'manufacturer_type': 'UNKNOWN'}}],
#     'lastAvailableSize': None,
#     'media': {'videos': [],
#      'images': [{'type': 'PREMIUM',
#        'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=30',
#         'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=66',
#         'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=102',
#         'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=78',
#         'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=336',
#         'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=765',
#         'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=1800',
#         'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?impolicy=detail'}},
#       {'type': 'STYLE',
#        'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=30',
#         'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=66',
#         'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=102',
#         'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=78',
#         'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=336',
#         'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=765',
#         'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=1800',
#         'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?impolicy=detail'}},
#       {'type': 'PREMIUM',
#        'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=30',
#         'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=66',
#         'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=102',
#         'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=78',
#         'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=336',
#         'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=765',
#         'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=1800',
#         'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?impolicy=detail'}},
#       {'type': 'PACKSHOT',
#        'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=30&filter=packshot',
#         'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=66&filter=packshot',
#         'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=102&filter=packshot',
#         'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=78&filter=packshot',
#         'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=336&filter=packshot',
#         'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=765&filter=packshot',
#         'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=1800&filter=packshot',
#         'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?impolicy=detail&filter=packshot'}},
#       {'type': 'DETAILED',
#        'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=30',
#         'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=66',
#         'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=102',
#         'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=78',
#         'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=336',
#         'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=765',
#         'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=1800',
#         'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?impolicy=detail'}}]},
#     'displayPrice': {'isPriceDifferent': False,
#      'isOriginalPriceDifferent': False,
#      'isDiscountDifferent': False,
#      'isDiscounted': False,
#      'percentageDiscount': 0,
#      'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#      'originalPrice': {'currency': 'GBP',
#       'value': 44.99,
#       'formatted': '£44.99'}},
#     'averageStarRating': None,
#     'roundedAverageStarRating': 0,
#     'reviewsCount': None,
#     'starRatingDistribution': [],
#     'attributes': [{'category': 'heading_material',
#       'type': 'attributes_map',
#       'data': [{'name': 'Outer fabric material', 'values': '100% viscose'},
#        {'name': 'Care instructions',
#         'values': 'Do not tumble dry, machine wash at 30°C, Machine wash on gentle cycle'}],
#       'subheading': 'Outer fabric material: 100% viscose'},
#      {'category': 'heading_details',
#       'type': 'attributes_map',
#       'data': [{'name': 'Collar', 'values': 'Standing collar'},
#        {'name': 'Fastening', 'values': 'Button'},
#        {'name': 'Sheer', 'values': 'Semi-sheer'},
#        {'name': 'Pattern', 'values': 'Plain'},
#        {'name': 'config_sku', 'values': 'ES421E0OL-A11'}],
#       'subheading': 'Collar: Standing collar'},
#      {'category': 'heading_measure_and_fitting',
#       'type': 'attributes_map',
#       'data': [{'name': "Our model's height",
#         'values': 'Our model is 5\' 10"  tall and is wearing size 10'},
#        {'name': 'Fit', 'values': 'Wide cut'},
#        {'name': 'Length', 'values': 'Extra long'},
#        {'name': 'Sleeve length', 'values': 'Extra long'},
#        {'name': 'Sleeve length', 'values': '25.5 " (Size 10)'},
#        {'name': 'Back width', 'values': '16.5 " (Size 10)'},
#        {'name': 'Total length', 'values': '32.5 " (Size 10)'}],
#       'subheading': 'Our model\'s height: Our model is 5\' 10"  tall and is wearing size 10'},
#      {'category': 'heading_beauty_details',
#       'type': 'attributes_map',
#       'data': [{'name': 'Outer fabric material', 'values': '100% viscose'},
#        {'name': 'config_sku', 'values': 'ES421E0OL-A11'}],
#       'subheading': 'Outer fabric material: 100% viscose'}],
#     'targetGroups': {'gender': ['FEMALE'],
#      'age': ['ADULT'],
#      'domain': ['DEFAULT']},
#     'isPremium': False,
#     'modelHeight': 'Our model is 5\' 10"  tall and is wearing size 10',
#     'hotline': '0203 059 8139',
#     'flags': [],
#     'colors': [{'id': 'ES421E0OL-A11',
#       'name': 'Blouse - off white',
#       'color': 'off white',
#       'shopUrl': 'https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html',
#       'pictureUrl': 'https://mosaic03.ztat.net/vgs/media/thumb_hd/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png',
#       'media': {'videos': [],
#        'images': [{'type': 'PREMIUM',
#          'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=30',
#           'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=66',
#           'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=102',
#           'reco': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=168',
#           'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=336',
#           'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=78',
#           'thumb2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=156',
#           'thumbHd': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=78',
#           'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=765',
#           'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=1800',
#           'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?impolicy=detail'}},
#         {'type': 'STYLE',
#          'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=30',
#           'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=66',
#           'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=102',
#           'reco': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=168',
#           'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=336',
#           'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=78',
#           'thumb2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=156',
#           'thumbHd': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=78',
#           'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=765',
#           'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=1800',
#           'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?impolicy=detail'}},
#         {'type': 'PREMIUM',
#          'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=30',
#           'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=66',
#           'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=102',
#           'reco': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=168',
#           'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=336',
#           'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=78',
#           'thumb2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=156',
#           'thumbHd': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=78',
#           'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=765',
#           'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=1800',
#           'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?impolicy=detail'}},
#         {'type': 'PACKSHOT',
#          'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=30&filter=packshot',
#           'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=66&filter=packshot',
#           'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=102&filter=packshot',
#           'reco': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=168&filter=packshot',
#           'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=336&filter=packshot',
#           'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=78&filter=packshot',
#           'thumb2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=156&filter=packshot',
#           'thumbHd': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=78&filter=packshot',
#           'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=765&filter=packshot',
#           'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=1800&filter=packshot',
#           'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?impolicy=detail&filter=packshot'}},
#         {'type': 'DETAILED',
#          'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=30',
#           'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=66',
#           'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=102',
#           'reco': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=168',
#           'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=336',
#           'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=78',
#           'thumb2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=156',
#           'thumbHd': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=78',
#           'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=765',
#           'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=1800',
#           'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?impolicy=detail'}}]}}]},
#    'displayPrice': {'isPriceDifferent': False,
#     'isOriginalPriceDifferent': False,
#     'isDiscountDifferent': False,
#     'isDiscounted': False,
#     'percentageDiscount': 0,
#     'price': {'currency': 'GBP', 'value': 44.99, 'formatted': '£44.99'},
#     'originalPrice': {'currency': 'GBP',
#      'value': 44.99,
#      'formatted': '£44.99'}},
#    'productDetailsCluster': [{'category': 'heading_material',
#      'type': 'attributes_map',
#      'data': [{'name': 'Outer fabric material', 'values': '100% viscose'},
#       {'name': 'Care instructions',
#        'values': 'Do not tumble dry, machine wash at 30°C, Machine wash on gentle cycle'}],
#      'subheading': 'Outer fabric material: 100% viscose'},
#     {'category': 'heading_details',
#      'type': 'attributes_map',
#      'data': [{'name': 'Collar', 'values': 'Standing collar'},
#       {'name': 'Fastening', 'values': 'Button'},
#       {'name': 'Sheer', 'values': 'Semi-sheer'},
#       {'name': 'Pattern', 'values': 'Plain'},
#       {'name': 'config_sku', 'values': 'ES421E0OL-A11'}],
#      'subheading': 'Collar: Standing collar'},
#     {'category': 'heading_measure_and_fitting',
#      'type': 'attributes_map',
#      'data': [{'name': "Our model's height",
#        'values': 'Our model is 5\' 10"  tall and is wearing size 10'},
#       {'name': 'Fit', 'values': 'Wide cut'},
#       {'name': 'Length', 'values': 'Extra long'},
#       {'name': 'Sleeve length', 'values': 'Extra long'},
#       {'name': 'Sleeve length', 'values': '25.5 " (Size 10)'},
#       {'name': 'Back width', 'values': '16.5 " (Size 10)'},
#       {'name': 'Total length', 'values': '32.5 " (Size 10)'}],
#      'subheading': 'Our model\'s height: Our model is 5\' 10"  tall and is wearing size 10'},
#     {'category': 'heading_beauty_details',
#      'type': 'attributes_map',
#      'data': [{'name': 'Outer fabric material', 'values': '100% viscose'},
#       {'name': 'config_sku', 'values': 'ES421E0OL-A11'}],
#      'subheading': 'Outer fabric material: 100% viscose'}],
#    'hotline': '0203 059 8139',
#    'selectedSize': None,
#    'socialInfo': [{'id': 'MESSENGER',
#      'params': {'link': 'https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html'}},
#     {'id': 'WHATSAPP',
#      'params': {'text': 'https://www.zalando.co.uk/esprit-collection-blouse-off-white-es421e0ol-a11.html'}}],
#    'partnerInfo': {'isUpdated': False,
#     'hasNoPartners': True,
#     'hasOnlyPartners': False,
#     'hasOnlyOnePartner': True,
#     'hasSomePartners': False},
#    'sizeReminderForm': {'first_name': '',
#     'email': '',
#     'unit': 'ES421E0OL-A110320000'},
#    'deviceInfo': {'versions': {'trident': None, 'windowsNT': None},
#     'isMobile': False,
#     'isTablet': False,
#     'isDesktop': True},
#    'featureToggles': {'id': 16,
#     'salesChannel': '83c4e87f-6819-41bb-af61-46cddb8453f5',
#     'countryCode': 'GB',
#     'defaultLocale': 'en-GB',
#     'enableSizeReco': False,
#     'enableShippingMov': True,
#     'notification': {'enableAddToCartNotification': False},
#     'sizeChat': {'enabled': False,
#      'config': {'emailAddress': 'ukdefault@zalando.co.uk',
#       'language': 'en',
#       'buttonId': '5730Y00000000wu',
#       'deploymentId': '5720Y00000000kr',
#       'organizationId': '00D0Y000000Ztg8',
#       'chatUrl': 'https://d.la1-c1-frf.salesforceliveagent.com/chat',
#       'liveAgentSrc': 'https://mosaic01.ztat.net/vgs/vendor/sf-liveagent-deployment.38.0.js'},
#      'disabledAppDomains': [],
#      'disabledGenders': ['KIDS'],
#      'disabledForZetMembers': True,
#      'enabledSilhouetteCodes': ['dress',
#       't_shirt_top',
#       'cardigan',
#       'pullover',
#       'coat']},
#     'bodyMeasurementGuides': {'enabled': False,
#      'profiles': {'feet': {'figurines': ['MaleFoot',
#         'FemaleFoot',
#         'FemaleFoot']},
#       'finger': {'figurines': ['MaleHandRings',
#         'FemaleHandRings',
#         'FemaleHandRings']},
#       'hand': {'figurines': ['MaleHandGloves',
#         'FemaleHandGloves',
#         'FemaleHandGloves']},
#       'fullBody': [{'conditions': ['leg'],
#         'figurines': ['MaleFullBodyAll',
#          'FemaleFullBodyAll',
#          'FemaleFullBodyAll']},
#        {'figurines': ['MaleFullBodyChestWaistHips',
#          'FemaleFullBodyBustWaistHips',
#          'FemaleFullBodyBustWaistHips']}],
#       'upperBody': [{'_default': True,
#         'conditions': ['hip', 'waist'],
#         'figurines': ['MaleUpperBodyAll',
#          'FemaleUpperBodyAll',
#          'FemaleUpperBodyAll']},
#        {'conditions': ['waist'],
#         'figurines': ['MaleUpperBodyChestWaist',
#          'FemaleUpperBodyBustWaist',
#          'FemaleUpperBodyBustWaist']},
#        {'conditions': ['hip'],
#         'figurines': ['MaleUpperBodyChestHips',
#          'FemaleUpperBodyBustHips',
#          'FemaleUpperBodyBustHips']}],
#       'lowerBody': [{'_default': True,
#         'conditions': ['waist', 'hip', 'leg'],
#         'figurines': ['MaleLowerBodyAll',
#          'FemaleLowerBodyAll',
#          'FemaleLowerBodyAll']},
#        {'conditions': ['waist'],
#         'figurines': ['MaleLowerBodyWaistHips',
#          'FemaleLowerBodyWaistHips',
#          'FemaleLowerBodyWaistHips']},
#        {'conditions': ['hip'],
#         'figurines': ['MaleLowerBodyHips',
#          'FemaleLowerBodyHips',
#          'FemaleLowerBodyHips']}],
#       'head': {'figurines': ['UnisexHead', 'UnisexHead', 'UnisexHead']}},
#      'rules': {'ankle_boots': 'feet',
#       'backless_slipper': 'feet',
#       'ballerina_shoe': 'feet',
#       'bathrobe': 'fullBody',
#       'beach_trouser': 'lowerBody',
#       'bikini_combination': 'fullBody',
#       'bikini_top': 'upperBody',
#       'boots': 'feet',
#       'cardigan': 'upperBody',
#       'coat': 'upperBody',
#       'combination_clothing': 'fullBody',
#       'dress': 'fullBody',
#       'headgear': 'head',
#       'gloves': 'hand',
#       'jacket': 'fullBody',
#       'jewellery': 'finger',
#       'low_shoe': 'feet',
#       'nightdress': 'fullBody',
#       'night_shirt': 'upperBody',
#       'night_trouser': 'lowerBody',
#       'nightwear_combination': 'fullBody',
#       'one_piece_beachwear': 'fullBody',
#       'one_piece_nightwear': 'fullBody',
#       'one_piece_underwear': 'fullBody',
#       'one_piece_suit': 'fullBody',
#       'pullover': 'upperBody',
#       'pumps': 'feet',
#       'sandals': 'feet',
#       'shirt': 'upperBody',
#       'skirt': 'lowerBody',
#       'sneaker': 'feet',
#       'stocking': 'feet',
#       't_shirt_top': 'upperBody',
#       'trouser': 'lowerBody',
#       'underpant': 'lowerBody',
#       'undershirt': 'upperBody',
#       'vest': 'upperBody'}},
#     'bodyMeasurementTables': {'enabled': False},
#     'sizeFitsCG1': [2, 4, 8],
#     'sizeFits': {'matcher': '/{2,4,8}/{1,2}/**', 'enabled': True},
#     'experiments': ['SizePanel'],
#     'blackListFlags': [{'type': 'VIP', 'format': 'string'}],
#     'enableStretchLevelConceptTest': False,
#     'useLoginModal': True,
#     'useJimmyCartForAnonymous': False,
#     'enableRecos': True,
#     'enableReviews': True,
#     'enableShopTheLook': True,
#     'enableSizeTable': True,
#     'enableSvgPlaceholder': True,
#     'enableSupplierSize': True,
#     'sizeRecoSilhouette': ['ballerina_shoe',
#      'low_shoe',
#      'first_shoe',
#      'backless_slipper',
#      'pumps',
#      'sandals',
#      'shoe_accessoires',
#      'sneaker',
#      'boots',
#      'ankle_boots',
#      'jacket',
#      'shirt',
#      'cardigan',
#      'dress',
#      'coat',
#      'pullover',
#      't_shirt_top',
#      'trouser',
#      'skirt'],
#     'abSizeReco': {'algo_version': 'MD1'},
#     'sizeRecosOrder': 'flagFirst',
#     'delivery': {'deliveryPromise': {'enabled': False}},
#     'addToWishlistWithoutSize': False,
#     'maxSizeAvailabilityHint': 3,
#     'minSizeAvailabilityHint': 1,
#     'numOfProductAttributes': {'LARGE': 6, 'SMALL': 0},
#     'ellipsisText': {'brandName': {'LARGE': 26, 'SMALL': 36},
#      'articleName': {'LARGE': 36, 'SMALL': 40}},
#     'productDetailsCluster': ['MATERIAL_AND_CARE',
#      'PASSFORM',
#      'OTHER_DETAILS'],
#     'mockVideoSKU': [],
#     'socialIcon': [{'id': 'MESSENGER', 'param': 'link'},
#      {'id': 'WHATSAPP', 'param': 'text'}],
#     'selectedSizeFormat': 'LOCAL',
#     'queryString': {'SIZE': 'size',
#      'SIZES': 'selectedsizes',
#      'PRESELECT_SSKU': 'ssku',
#      'RECO_TRACKING': 'reco_t',
#      'OPEN_REVIEWS_MODAL': 'modalReview',
#      'REVIEWS_MODAL_STARRATING': 'starrating',
#      'OPEN_SHOP_THE_LOOK': 'openShopTheLook',
#      'OPEN_SOCIAL_SELECTION': 'openSocial',
#      'OPEN_COLOR_SELECTION': 'openColor',
#      'OPEN_PARTNER': 'openPartner',
#      'OPEN_SIZE_REMINDER': 'openSizeReminder',
#      'ZOOM': 'zoom',
#      'ADD_SIZE_TO_WISHLIST': 'addSizeToWishlist',
#      'RC': 'rc'},
#     'zatra_mapping': {'config_sku': 'sku'},
#     'csr_mapping': {'ocs95': ['T0NTIC0gT3JnYW5pYyBDb250ZW50IFN0YW5kYXJk'],
#      'ocs5': ['T0NTIC0gT3JnYW5pYyBCbGVuZGVkIENvbnRlbnQgU3RhbmRhcmQ='],
#      'eco_fibre': ['VW13ZWx0ZnJldW5kbGljaGUgTWF0ZXJpYWxpZW4=',
#       'RHV1cnphYW0gbWF0ZXJpYWFs',
#       'TWF0aehyZSDpY29sb2dpcXVl',
#       'RWNvLXNvc3RlbmliaWxl',
#       'RWNvLWZpYnJlIG1peA==',
#       'V0Lza25hIGVrb2xvZ2ljem5l',
#       'RmlicmFzIGVjb2zzZ2ljYXM=',
#       'SOVsbGJhcnQgbWF0ZXJpYWw=',
#       'WW1w5HJpc3T2eXN05HbkbGxpbmVu',
#       'QuZyZWR5Z3RpZ3QgbWF0ZXJpYWxl',
#       'QuZyZWtyYWZ0aWcgbWF0ZXJpYWxl'],
#      'oekotex100': ['1mtvLVRleCBTdGFuZGFyZCAxMDA=',
#       'T2Vrby1UZXggU3RhbmRhcmQgMTAw',
#       'RWtvLVRleCBTdGFuZGFyZCAxMDA=',
#       'T0VLTy1URViuIFN0YW5kYXJkIDEwMA==',
#       '1mtvLVRleCBzdGFuZGFyZCAxMDA=',
#       '1mtvIFRleCAtc3RhbmRhcmRpIDEwMA==',
#       '2GtvLVRleCBTdGFuZGFyZCAxMDA=',
#       '2BNrby1UZXggU3RhbmRhcmQgMTAw'],
#      'grs': ['R1JTIC0gR2xvYmFsIFJlY3ljbGUgU3RhbmRhcmQ='],
#      'terracare': ['VGVycmFjYXJl'],
#      'gots': ['RmFicmlxdekgYXZlYyBkZXMgbWF0aehyZXMgYmlvIChHT1RTKQ==',
#       'RmF0dG8gY29uIG1hdGVyaWFsZSBvcmdhbmljbyAoR09UUyk=',
#       'TWFkZSB3aXRoIG9yZ2FuaWMgbWF0ZXJpYWwgKEdPVFMp',
#       'R09UUyAtIGhlcmdlc3RlbGx0IGF1cyBCaW9mYXNlcm4=',
#       'd3lwcm9kdWtvd2FueSB6IHV8eWNpZW0gc3Vyb3dj83cgZWtvbG9naWN6bnljaCAoR09UUyk=',
#       'ZmFicmljYWRvIGNvbiBtYXRlcmlhbGVzIG9yZ+FuaWNvcyAoR09UUyk=',
#       'Z2VtYWFrdCB2YW4gYmlvbG9naXNjaCBtYXRlcmlhYWwgKEdPVFMta2V1cm1lcmsp',
#       'QXYgZWtvbG9naXNrdCBtYXRlcmlhbCAoR09UUyk=',
#       'VmFsbWlzdGV0dHUga+R5dHTkbeRsbOQgbHVvbXVtYXRlcmlhYWxpYSAoR09UUyk=',
#       'TGF2ZXQgYWYg+GtvbG9naXNrIG1hdGVyaWFsZSAoR09UUyk=',
#       'TGFnZXQgYXYg+GtvbG9naXNrIG1hdGVyaWFsZSAoR09UUyk='],
#      'organiccotton': ['QmlvLUJhdW13b2xsZQ==',
#       'T3JnYW5pYyBDb3R0b24=',
#       'YmlvbG9naXNjaCBrYXRvZW4=',
#       'Q290b24gYmlv',
#       'Q290b25lIG9yZ2FuaWNv',
#       'YmF3ZUJuYSBla29sb2dpY3puYQ==',
#       'ZWtvbG9naXNrIGJvbXVsbA==',
#       'bHVvbXVwdXV2aWxsYQ==',
#       '+GtvbG9naXNrIGJvbXVsZA==',
#       'YWxnb2TzbiBvcmfhbmljbw==',
#       '+GtvbG9naXNrIGJvbXVsbA=='],
#      'euecolabel': ['RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw=',
#       'RVUgRWNvbGFiZWw='],
#      'fairtradecotton': ['RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'cmVpbHVuIGthdXBhbiBwdXV2aWxsYQ==',
#       'RmFpcnRyYWRlIENlcnRpZmllZCBDb3R0b24=',
#       'Q2VydGlmaWNhY2nzbiBkZSBBbGdvZPNuIGRlIENvbWVyY2lvIEp1c3Rv',
#       'RmFpcnRyYWRlLXNlcnRpZmlzZXJ0IGJvbXVsbA=='],
#      'gots95': ['R09UUyAtIEJpbw==',
#       'R09UUyAtIE9yZ2FuaWM=',
#       'R09UUyAtIGJpb2xvZ2lzY2g=',
#       'R09UUyAtIE9yZ2FuaWNv',
#       'R09UUyAtIGVrb2xvZ2ljem55',
#       'R09UUyAtIGVrb2xvZ2lzaw==',
#       'R09UUyAtIGx1b211',
#       'R09UUyAtIPhrb2xvZ2lzaw==',
#       'R09UUyAtIG9yZ+FuaWNv'],
#      'naturleder': ['TmF0dXJsZWRlciBJVk4temVydGlmaXppZXJ0',
#       'SVZOIGNlcnRpZmllZCBOYXR1cmxlZGVy',
#       'SVZOIE5hdHVybGVkZXIta2V1cm1lcms=',
#       'TmF0dXJsZWRlciBjZXJ0aWZp6SBJVk4=',
#       'Q2VydGlmaWNhdG8gSVZO',
#       'Y2VydHlmaWthdCBJVk4gTmF0dXJsZWRlcg==',
#       'SVZOLWNlcnRpZmllcmF0IE5hdHVybGVkZXI=',
#       'SVZOLXNlcnRpZmlrYWF0dGkgTmF0dXJsZWRlcg==',
#       'SVZOIGNlcnRpZmljZXJldCBOYXR1cmxlZGVy',
#       'Q2VydGlmaWNhZG8gSVZOIE5hdHVybGVkZXI=',
#       'SVZOLWdvZGtqZW50IE5hdHVybGVkZXI=']},
#     'enableSizeFits': True,
#     'productDetailsClusterCategories': {'heading_measure_and_fitting': True,
#      'heading_details': True,
#      'heading_material': True,
#      'heading_about_this_product': True,
#      'heading_suggested_usage': True,
#      'heading_for_who': True,
#      'heading_beauty_details': True,
#      'heading_embrace_details': True,
#      'heading_key_features': True,
#      'heading_active_ingredients': True,
#      'heading_all_ingredients': True,
#      'heading_sustainability': True,
#      'heading_shipping': True},
#     'articleInfoFlags': {'BREAD_AND_BUTTER': True,
#      'SALE': True,
#      'PRIXZ': True,
#      'VIP': True,
#      'PREMIUM': True,
#      'SUSTAINABLE': True,
#      'PLUS_SIZE': True,
#      'PETITE': True,
#      'KIDS': True,
#      'EXCLUSIVE': True,
#      'WIDE_SHOES': True,
#      'MATERNITY': True,
#      'NEW': True,
#      'ORIGINAL': True,
#      'TALL': True},
#     'enableVideoTracking': True,
#     'productVideoAutoPlay': {'enabled': True,
#      'mediaTypes': ['tablet', 'desktop']},
#     'enablePremiumCTA': True,
#     'displayBrandLogo': False,
#     'displaySizeHint': True,
#     'enableHoverZoom': True,
#     'enableSizePanel': True,
#     'reviewTemplateId': 'advisor',
#     'reviewMessengerId': 'prodpres:strip-advisor',
#     'staticDeliveryImages': ['https://mosaic01.ztat.net/vgs/static/pdp_review_3.jpg'],
#     'enableAttributesTable': True,
#     'zet': {'enabled': False,
#      'membership': True,
#      'eligibilitySizeReminder': False,
#      'eligibility': True},
#     'zetLogoActiveType': 'PLUS',
#     'zetLogoTypeMap': {'ZET': 'zet', 'PLUS': 'plus'},
#     'thirdPartySizeReco': {'fitAnalytics': {'enabled': False,
#       'metrics': False,
#       'widgetSrc': '//widget.fitanalytics.com/widget.js',
#       'metricsSrc': '//widget.fitanalytics.com/metrics.js'},
#      'trueFit': {'enabled': False, 'environment': 'staging'},
#      'disabledGenders': ['KIDS'],
#      'disabledFlags': ['PLUS_SIZE', 'TALL', 'PETITE'],
#      'disabledCommodityGroup1': ['4'],
#      'enabledSilhouetteCodesForAll': ['trouser'],
#      'enabledSilhouetteCodesForWoman': ['dress'],
#      'enabledSilhouetteCodesForMan': ['t_shirt_top']},
#     'enableSet': False,
#     'enableStlPlaceholder': False,
#     'setTeleportId': 'set',
#     'setFragmentId': 'z-vegas-set',
#     'octopusVariantSkipper': {'stl': 'stl_no_ssr_test'},
#     'teleportConfig': {'stl': {'teleportId': 'stl',
#       'fragmentId': 'z-vegas-stl',
#       'type': 'row'},
#      'set': {'teleportId': 'set', 'fragmentId': 'z-vegas-set', 'type': 'set'}},
#     'enableSizeTableBoundsFilter': True,
#     'sizeTablesBoundsFilter': {'profiles': {'default': {'filterName': 'matchStrictEqual',
#        'targetGroups': ['MALE', 'FEMALE', 'UNISEX']},
#       'shoe': {'filterName': 'numericBounds',
#        'targetGroups': ['MALE', 'FEMALE']}},
#      'rules': {'ankle_boots': {'_profile_': 'shoe'},
#       'backless_slipper': {'_profile_': 'shoe'},
#       'ballerina_shoe': {'_profile_': 'shoe'},
#       'belt': {'filterName': 'matchStrictEqual',
#        'targetGroups': ['MALE', 'FEMALE']},
#       'boots': {'_profile_': 'shoe'},
#       'bra': {'filterName': 'splitByNumericAlphaAndMatchFirst',
#        'targetGroups': ['FEMALE']},
#       'coat': {'_profile_': 'default'},
#       'combination_clothing': {'_profile_': 'default'},
#       'dress': {'_profile_': 'default'},
#       'gloves': {'filterName': 'matchStrictEqual',
#        'targetGroups': ['MALE', 'FEMALE']},
#       'headgear': {'_profile_': 'default'},
#       'jacket': {'_profile_': 'default'},
#       'nightwear_combination': {'_profile_': 'default'},
#       'other_accessoires': {'_profile_': 'default'},
#       'pullover': {'_profile_': 'default'},
#       'low_shoe': {'_profile_': 'show'},
#       'one_piece_beachwear': {'_profile_': 'default'},
#       'one_piece_suit': {'filterName': 'matchStrictEqual',
#        'targetGroups': ['MALE', 'FEMALE']},
#       'shirt': {'_profile_': 'default'},
#       'skirt': {'_profile_': 'default'},
#       'sneaker': {'_profile_': 'shoe'},
#       'sandals': {'_profile_': 'shoe'},
#       't_shirt_top': {'_profile_': 'default'},
#       'pumps': {'filterName': 'numericBounds', 'targetGroups': ['FEMALE']},
#       'trouser': [{'filterName': 'splitByXAndMatchFirst',
#         'matchColumn': 'Jeans',
#         'targetGroups': ['MALE', 'FEMALE', 'UNISEX']},
#        {'_profile_': 'default'}],
#       'underpant': {'_profile_': 'default'}}},
#     'isOAuthEnabled': True,
#     'prefetchedBundles': ['client.top', 'client.details'],
#     'enableCTARelayout': False,
#     'enableBrandLogo': True,
#     'noReturnBannerId': 'no-return-banner-dest',
#     'incentivesBannerId': 'incentives-banner-dest',
#     'enablePrideWishlist': False,
#     'incentivesBannerNewPlacementId': 'incentives-banner-new-dest',
#     'enableComingSoon': True,
#     'enableReleaseReminder': True,
#     'enableSizeFinder': False,
#     'abAdd2CartBlackColor': False},
#    'developmentFlags': ['obama',
#     'bush',
#     'castro',
#     'zorro',
#     '13th',
#     'lama',
#     'thor',
#     'sizeAdviceV2',
#     ''],
#    'productDetailsInfo': {'sections': []},
#    'deliveryInfo': {'units': [{'id': 'ES421E0OL-A110320000'},
#      {'id': 'ES421E0OL-A110340000', 'deliveryPromises': []},
#      {'id': 'ES421E0OL-A110360000', 'deliveryPromises': []},
#      {'id': 'ES421E0OL-A110380000', 'deliveryPromises': []},
#      {'id': 'ES421E0OL-A110400000', 'deliveryPromises': []},
#      {'id': 'ES421E0OL-A110420000', 'deliveryPromises': []},
#      {'id': 'ES421E0OL-A110440000'}]},
#    'params': {},
#    'octopusVariantSkipper': 'if_gallery',
#    'customerProfile': {'loginState': 'GUEST'},
#    'liveExperiments': [],
#    'lookInfo': {'set': False, 'stl': False},
#    'isSetAvailable': False,
#    'isStlAvailable': False,
#    'externalFlags': {'zet': {'isZetChatEnabled': False}},
#    'appdomainId': 16,
#    'isNextGen': False,
#    'ifMigrationPhase': 2},
#   'bundle': 'client.top'}]

# %%
category_match = prod_json[0]['model']['articleInfo']['category_tag']

# %%
kind_cat_list = [word.lower() for word in category_match.split(' ') if word.lower() in kind_cats]

# %%
cat_list = kind_cat_list

# %%
len(cat_list) == 0
# Out:
# False

# %%
all_cat_list = [word.lower() for word in category_match.split(' ') if word.lower() in all_cats]

# %%
category = cat_list[0]

# %%
category
# Out:
# 'blouse'

# %%
prod_json[0]['model']['articleInfo']['media']['images']
# Out:
# [{'type': 'PREMIUM',
#   'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=30',
#    'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=66',
#    'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=102',
#    'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=78',
#    'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=336',
#    'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=765',
#    'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=1800',
#    'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?impolicy=detail'}},
#  {'type': 'STYLE',
#   'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=30',
#    'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=66',
#    'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=102',
#    'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=78',
#    'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=336',
#    'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=765',
#    'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?imwidth=1800',
#    'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@3.jpg?impolicy=detail'}},
#  {'type': 'PREMIUM',
#   'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=30',
#    'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=66',
#    'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=102',
#    'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=78',
#    'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=336',
#    'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=765',
#    'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=1800',
#    'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?impolicy=detail'}},
#  {'type': 'PACKSHOT',
#   'sources': {'color': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=30&filter=packshot',
#    'colorBig': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=66&filter=packshot',
#    'colorBig2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=102&filter=packshot',
#    'thumb': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=78&filter=packshot',
#    'reco2x': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=336&filter=packshot',
#    'gallery': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=765&filter=packshot',
#    'zoom': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?imwidth=1800&filter=packshot',
#    'detail': 'https://img02.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@7.png?impolicy=detail&filter=packshot'}},
#  {'type': 'DETAILED',
#   'sources': {'color': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=30',
#    'colorBig': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=66',
#    'colorBig2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=102',
#    'thumb': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=78',
#    'reco2x': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=336',
#    'gallery': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=765',
#    'zoom': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=1800',
#    'detail': 'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?impolicy=detail'}}]

# %%
image_urls = [img_dict['sources']['gallery'] for img_dict in prod_json[0]['model']['articleInfo']['media']['images'] if img_dict['type'] == 'PREMIUM' or img_dict['type'] == 'DETAILED']

# %%
image_urls
# Out:
# ['https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@8.jpg?imwidth=765',
#  'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@5.jpg?imwidth=765',
#  'https://img01.ztat.net/article/ES/42/1E/0O/LA/11/ES421E0OL-A11@6.jpg?imwidth=765']

# %%
color_string = prod_json[0]['model']['articleInfo']['color']

# %%
color_string
# Out:
# 'off white'

# %%
descr_match = prod_doc.xpath('.//div[@id="z-pdp-detailsSection"]/div/div/div/div/div/div/div/div/div')

# %%
descr_els = []
for el in descr_match:
    node = etree.tostring(el)
    node_str = str(node, 'utf-8')
    node_clean_1 = re.sub('class=\".*?\"', '', node_str)
    node_clean_1_1 = re.sub('as=\".*?\"', '', node_clean_1)
    node_clean_2 = re.sub('\<\!--', '', node_clean_1_1)
    node_clean_3 = re.sub('--\>', '', node_clean_2)
    descr_els.append(node_clean_3)

# %%
description = ' '.join(descr_els)

# %%
description
# Out:
# '<div style="margin-right:0;min-height:NaNpx;max-height:NaNpx" ><div ><div ><p  >Material &amp; care</p><div ><p  ><span  >Outer fabric material :&#160;</span><span  >100% viscose</span></p><p  ><span  >Care instructions :&#160;</span><span  >Do not tumble dry, machine wash at 30&#176;C, Machine wash on gentle cycle</span></p></div></div><div ><p  >Details</p><div ><p  ><span  >Collar :&#160;</span><span  >Standing collar</span></p><p  ><span  >Fastening :&#160;</span><span  >Button</span></p><p  ><span  >Sheer :&#160;</span><span  >Semi-sheer</span></p><p  ><span  >Pattern :&#160;</span><span  >Plain</span></p><p  ><span  >Article number :&#160;</span><span  >ES421E0OL-A11</span></p></div></div></div></div> <div style="display:none" ><div /></div> <div style="margin-right:0;min-height:NaNpx;max-height:NaNpx" ><div ><div ><div ><p  ><span  >Our model\'s height :&#160;</span><span  >Our model is 5\' 10"  tall and is wearing size 10</span></p><p  ><span  >Fit :&#160;</span><span  >Wide cut</span></p><p  ><span  >Length :&#160;</span><span  >Extra long</span></p><p  ><span  >Sleeve length :&#160;</span><span  >Extra long</span></p><p  ><span  >Sleeve length :&#160;</span><span  >25.5 " (Size 10)</span></p><p  ><span  >Back width :&#160;</span><span  >16.5 " (Size 10)</span></p><p  ><span  >Total length :&#160;</span><span  >32.5 " (Size 10)</span></p></div></div></div></div> <div style="display:none" ><div /></div> <div style="margin-right:0;min-height:NaNpx;max-height:NaNpx" ><div ><div ><div ><p  style="line-height:24px" ><span ><svg  focusable="false" viewbox="0 0 24 24" width="24px" height="24px" fill="currentColor" style="margin-bottom:-0.15em"><path d="M9.857 18L4.5 12.952 6 11.538l3.857 3.635L18 7.5l1.5 1.413z"/></svg></span>100 day return policy</p></div></div></div></div> <div style="display:none" ><div /></div> <div style="margin-right:0;min-height:NaNpx;max-height:NaNpx" ><div ><div ><div ><span >This product has no reviews, do you want be the first?</span><button   type="button"><div ><span >Write a review</span></div></button></div></div></div></div> <div style="display:none" ><div /></div>'

# %%
from lxml import etree

# %%
categories = prod_json[0]['model']['articleInfo']['categories']

# %%
categories_sex = [cat for cat in categories if cat == 'women' or cat == 'men']

# %%
categories_sex
# Out:
# ['women']

# %%
sex = categories_sex[0]

# %%
sex
# Out:
# 'women'

# %%
kind_cats = [
        'accessories',
        'activewear',
        'backpack',
        'bag',
        'bags',
        'beachwear',
        'beauty',
        'belt',
        'bikini',
        'blazer',
        'blazers',
        'blouse',
        'blouses',
        'bodycon',
        'bodysuit',
        'boot',
        'boots',
        'bottom',
        'bottoms',
        'bra',
        'bracelet',
        'bralet',
        'bralette',
        'bras',
        'brief',
        'briefs',
        'brogues',
        'cami',
        'camis',
        'cardigan',
        'cardigans',
        'chinos',
        'clutch',
        'coat',
        'coats',
        'corset',
        'dress',
        'dresses',
        'dungaree',
        'dungarees',
        'earrings',
        'espadrille',
        'espadrilles',
        'hat',
        'heel',
        'heels',
        'hoodie',
        'hoodies',
        'jacket',
        'jackets',
        'jean',
        'jeans',
        'jeggings',
        'jersey',
        'jewellery',
        'jogger',
        'joggers',
        'jumper',
        'jumpers',
        'jumpsuit',
        'jumpsuits',
        'kimono',
        'knickers',
        'legging',
        'leggings',
        'lingerie',
        'lipstick',
        'loafers',
        'makeup',
        'mules',
        'necklace',
        'nightwear',
        'pant',
        'pants',
        'parka',
        'playsuit',
        'playsuits',
        'polo',
        'pullover',
        'pyjama',
        'ring',
        'sandal',
        'sandals',
        'scarf',
        'shirt',
        'shirts',
        'shoes',
        'shorts',
        'skirt',
        'skirts',
        'sneakers',
        'sock',
        'socks',
        'suit',
        'suits',
        'sundress',
        'sunglasses',
        'sweater',
        'sweatpant',
        'sweatpants',
        'sweatshirt',
        'sweatshirts',
        'swim',
        'swimming',
        'swimsuit',
        'swimwear',
        't-shirt',
        't-shirts',
        'tee',
        'thong',
        'tie',
        'tights',
        'top',
        'tops',
        'tote',
        'tracksuit',
        'tracksuits',
        'trainer',
        'trainers',
        'trouser',
        'trousers',
        'trunks',
        'tuxedo',
        'underwear',
        'vest',
        'vests',
        'waistcoat',
        'watch',
        'watches',
        'windbreaker',
        'workwear'
         ]
color_pattern_cats = [
    'abstract',
    'acid',
    'animal',
    'apricot',
    'beige',
    'black',
    'blue',
    'bright',
    'brown',
    'burgundy',
    'cable',
    'camo',
    'charcoal',
    'check',
    'chevron',
    'circle',
    'clear',
    'contrast',
    'cream',
    'crochet',
    'dark',
    'dot',
    'dye',
    'embellished',
    'embellishment',
    'embroidered',
    'embroidery',
    'floral',
    'flower',
    'gingham',
    'gold',
    'green',
    'grey',
    'heart',
    'indigo',
    'jacquard',
    'khaki',
    'knot',
    'lace',
    'lattice',
    'leopard',
    'lettuce',
    'light',
    'lilac',
    'lime',
    'logo',
    'mango',
    'mesh',
    'monochrome',
    'mustard',
    'navy',
    'neon',
    'nude',
    'ombre',
    'orange',
    'paisley',
    'pale',
    'palm',
    'pattern',
    'peach',
    'pink',
    'pinstripe',
    'polka',
    'print',
    'printed',
    'purple',
    'rainbow',
    'red',
    'rib',
    'rose',
    'rust',
    'silver',
    'snake',
    'spot',
    'square',
    'star',
    'stitch',
    'straw',
    'stripe',
    'striped',
    'stripes',
    'tan',
    'tea',
    'textured',
    'tiger',
    'tortoiseshell',
    'triangle',
    'tropical',
    'vanilla',
    'wash',
    'washed',
    'white',
    'yellow',
    'zebra'
]
style_cats = [
    'asymmetric',
    'bandeau',
    'bardot',
    'basic',
    'beach',
    'biker',
    'body',
    'bomber',
    'boxy',
    'boyfriend',
    'bridal',
    'broderie',
    'cargo',
    'casual',
    'chelsea',
    'chunky',
    'classic',
    'club',
    'cord',
    'crop',
    'cropped',
    'cross',
    'curve',
    'curved',
    'curves',
    'ditsy',
    'festival',
    'flare',
    'flared',
    'flat',
    'fluffy',
    'formal',
    'french',
    'fringe',
    'glamorous',
    'gym',
    'high',
    'homme',
    'large',
    'long',
    'longline',
    'loose',
    'lounge',
    'low',
    'mamalicious',
    'maternity',
    'maxi',
    'mela',
    'midi',
    'mini',
    'mom',
    'muscle',
    'oversized',
    'oxford',
    'pencil',
    'peplum',
    'petite',
    'pinafore',
    'platform',
    'pleated',
    'plunge',
    'plus',
    'push-up',
    'quilted',
    'raw',
    'regular',
    'relaxed',
    'retro',
    'ribbed',
    'ripped',
    'ruched',
    'running',
    'shirred',
    'short',
    'skater',
    'skinny',
    'sleeveless',
    'slim',
    'slinky',
    'slip',
    'smart',
    'south',
    'sports',
    'sporty',
    'stiletto',
    'straight',
    'strappy',
    'tailored',
    'tall',
    'tank',
    'tapered',
    'track',
    'training',
    'trench',
    'unisex',
    'vintage',
    'wedding',
    'western',
    'wide',
    'wrap'
]
material_cats = [
    'beaded',
    'chiffon',
    'chino',
    'cotton',
    'denim',
    'down',
    'faux',
    'fishnet',
    'flannel',
    'glitter',
    'knit',
    'knitted',
    'leather',
    'linen',
    'merino',
    'metal',
    'metallic',
    'nylon',
    'paper',
    'pearl',
    'poplin',
    'puffer',
    'satin',
    'sequin',
    'studded',
    'suede',
    'suedette',
    'twill',
    'velour',
    'velvet',
    'viscose',
    'wool',
    'woven'
]
attribute_cats = [
    'ankle',
    'back',
    'backless',
    'belted',
    'block',
    'bow',
    'buckle',
    'bust',
    'button',
    'buttons',
    'cameo',
    'cap',
    'chain',
    'collar',
    'crinkle',
    'cup',
    'double',
    'frill',
    'heeled',
    'hem',
    'hood',
    'hooded',
    'insert',
    'knee',
    'leg',
    'mid',
    'neck',
    'open',
    'pack',
    'padded',
    'panel',
    'panelled',
    'pocket',
    'pockets',
    'ruffle',
    'shoulder',
    'sleeve',
    'sleeves',
    'soft',
    'strap',
    'straps',
    'stretch',
    'sweat',
    'tassel',
    'trim',
    'turtle',
    'turtleneck',
    'twist',
    'underwire',
    'underwired',
    'up',
    'v-neck',
    'waist',
    'waistband',
    'waisted',
    'zip'
]
filter_cats = [
    'curve',
    'curved',
    'curves',
    'tall',
    'plus',
    'petite',
    'mom',
    'mamalicious',
    'maternity',
    'bridal',
]
all_cats = kind_cats + color_pattern_cats + style_cats + material_cats + attribute_cats + filter_cats
